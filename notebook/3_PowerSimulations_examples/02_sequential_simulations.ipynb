# %% [markdown]
# # Sequential Simulations with [PowerSimulations.jl](https://github.com/NREL-SIIP/PowerSimulations.jl)

# %% [markdown]
# **Originally Contributed by**: Clayton Barrows

# %% [markdown]
# ## Introduction

# %% [markdown]
# PowerSimulations.jl supports simulations that consist of sequential optimization problems
# where results from previous problems inform subsequent problems in a variety of ways. This
# example demonstrates some of these capabilities to represent electricity market clearing.

# %% [markdown]
# ## Dependencies
# Since the `OperatiotnsProblem` is the fundamental building block of a sequential
# simulation in PowerSimulations, we will build on the [OperationsProblem example](../../notebook/3_PowerSimulations_examples/1_operations_problems.ipynb)
# by sourcing it as a dependency.

# %%
using SIIPExamples
pkgpath = dirname(dirname(pathof(SIIPExamples)))
include(joinpath(pkgpath, "test", "3_PowerSimulations_examples", "01_operations_problems.jl"))
# Out:
# ┌ Info: Parsing csv data in branch.csv ...
# └ @ PowerSystems /Users/cbarrows/.julia/packages/PowerSystems/eF3Pv/src/parsers/power_system_table_data.jl:143
# ┌ Info: Successfully parsed branch.csv
# └ @ PowerSystems /Users/cbarrows/.julia/packages/PowerSystems/eF3Pv/src/parsers/power_system_table_data.jl:148
# ┌ Info: Parsing csv data in bus.csv ...
# └ @ PowerSystems /Users/cbarrows/.julia/packages/PowerSystems/eF3Pv/src/parsers/power_system_table_data.jl:143
# ┌ Info: Successfully parsed bus.csv
# └ @ PowerSystems /Users/cbarrows/.julia/packages/PowerSystems/eF3Pv/src/parsers/power_system_table_data.jl:148
# ┌ Info: Parsing csv data in dc_branch.csv ...
# └ @ PowerSystems /Users/cbarrows/.julia/packages/PowerSystems/eF3Pv/src/parsers/power_system_table_data.jl:143
# ┌ Info: Successfully parsed dc_branch.csv
# └ @ PowerSystems /Users/cbarrows/.julia/packages/PowerSystems/eF3Pv/src/parsers/power_system_table_data.jl:148
# ┌ Info: Parsing csv data in gen.csv ...
# └ @ PowerSystems /Users/cbarrows/.julia/packages/PowerSystems/eF3Pv/src/parsers/power_system_table_data.jl:143
# ┌ Info: Successfully parsed gen.csv
# └ @ PowerSystems /Users/cbarrows/.julia/packages/PowerSystems/eF3Pv/src/parsers/power_system_table_data.jl:148
# ┌ Info: Parsing csv data in reserves.csv ...
# └ @ PowerSystems /Users/cbarrows/.julia/packages/PowerSystems/eF3Pv/src/parsers/power_system_table_data.jl:143
# ┌ Info: Successfully parsed reserves.csv
# └ @ PowerSystems /Users/cbarrows/.julia/packages/PowerSystems/eF3Pv/src/parsers/power_system_table_data.jl:148
# ┌ Info: Parsing csv data in simulation_objects.csv ...
# └ @ PowerSystems /Users/cbarrows/.julia/packages/PowerSystems/eF3Pv/src/parsers/power_system_table_data.jl:143
# ┌ Info: Successfully parsed simulation_objects.csv
# └ @ PowerSystems /Users/cbarrows/.julia/packages/PowerSystems/eF3Pv/src/parsers/power_system_table_data.jl:148
# ┌ Info: Parsing csv data in storage.csv ...
# └ @ PowerSystems /Users/cbarrows/.julia/packages/PowerSystems/eF3Pv/src/parsers/power_system_table_data.jl:143
# ┌ Info: Successfully parsed storage.csv
# └ @ PowerSystems /Users/cbarrows/.julia/packages/PowerSystems/eF3Pv/src/parsers/power_system_table_data.jl:148
# ┌ Info: Parsing csv data in timeseries_pointers.csv ...
# └ @ PowerSystems /Users/cbarrows/.julia/packages/PowerSystems/eF3Pv/src/parsers/power_system_table_data.jl:143
# ┌ Info: Successfully parsed timeseries_pointers.csv
# └ @ PowerSystems /Users/cbarrows/.julia/packages/PowerSystems/eF3Pv/src/parsers/power_system_table_data.jl:148
# ┌ Info: Unit System changed to DEVICE_BASE
# └ @ PowerSystems /Users/cbarrows/.julia/packages/PowerSystems/eF3Pv/src/base.jl:288
# ┌ Warning: Missing LOAD data.
# └ @ PowerSystems /Users/cbarrows/.julia/packages/PowerSystems/eF3Pv/src/parsers/power_system_table_data.jl:212
# ┌ Warning: User-defined column name Startup Ramp Rate MW/min is not in dataframe.
# └ @ PowerSystems /Users/cbarrows/.julia/packages/PowerSystems/eF3Pv/src/parsers/power_system_table_data.jl:1215
# ┌ Warning: User-defined column name Shutdown Ramp Rate MW/min is not in dataframe.
# └ @ PowerSystems /Users/cbarrows/.julia/packages/PowerSystems/eF3Pv/src/parsers/power_system_table_data.jl:1215
# ┌ Warning: User-defined column name Status at Start is not in dataframe.
# └ @ PowerSystems /Users/cbarrows/.julia/packages/PowerSystems/eF3Pv/src/parsers/power_system_table_data.jl:1215
# ┌ Warning: User-defined column name Time at Status is not in dataframe.
# └ @ PowerSystems /Users/cbarrows/.julia/packages/PowerSystems/eF3Pv/src/parsers/power_system_table_data.jl:1215
# ┌ Warning: User-defined column name Start Cost Cold is not in dataframe.
# └ @ PowerSystems /Users/cbarrows/.julia/packages/PowerSystems/eF3Pv/src/parsers/power_system_table_data.jl:1215
# ┌ Warning: User-defined column name Start Cost Warm is not in dataframe.
# └ @ PowerSystems /Users/cbarrows/.julia/packages/PowerSystems/eF3Pv/src/parsers/power_system_table_data.jl:1215
# ┌ Warning: User-defined column name Start Cost Hot is not in dataframe.
# └ @ PowerSystems /Users/cbarrows/.julia/packages/PowerSystems/eF3Pv/src/parsers/power_system_table_data.jl:1215
# ┌ Warning: User-defined column name Must Run is not in dataframe.
# └ @ PowerSystems /Users/cbarrows/.julia/packages/PowerSystems/eF3Pv/src/parsers/power_system_table_data.jl:1215
# ┌ Warning: Missing LOAD data.
# └ @ PowerSystems /Users/cbarrows/.julia/packages/PowerSystems/eF3Pv/src/parsers/power_system_table_data.jl:212
# ┌ Info: Adding contributing generators for Spin_Up_R1 by category
# └ @ PowerSystems /Users/cbarrows/.julia/packages/PowerSystems/eF3Pv/src/parsers/power_system_table_data.jl:656
# ┌ Warning: User-defined column name Startup Ramp Rate MW/min is not in dataframe.
# └ @ PowerSystems /Users/cbarrows/.julia/packages/PowerSystems/eF3Pv/src/parsers/power_system_table_data.jl:1215
# ┌ Warning: User-defined column name Shutdown Ramp Rate MW/min is not in dataframe.
# └ @ PowerSystems /Users/cbarrows/.julia/packages/PowerSystems/eF3Pv/src/parsers/power_system_table_data.jl:1215
# ┌ Warning: User-defined column name Status at Start is not in dataframe.
# └ @ PowerSystems /Users/cbarrows/.julia/packages/PowerSystems/eF3Pv/src/parsers/power_system_table_data.jl:1215
# ┌ Warning: User-defined column name Time at Status is not in dataframe.
# └ @ PowerSystems /Users/cbarrows/.julia/packages/PowerSystems/eF3Pv/src/parsers/power_system_table_data.jl:1215
# ┌ Warning: User-defined column name Start Cost Cold is not in dataframe.
# └ @ PowerSystems /Users/cbarrows/.julia/packages/PowerSystems/eF3Pv/src/parsers/power_system_table_data.jl:1215
# ┌ Warning: User-defined column name Start Cost Warm is not in dataframe.
# └ @ PowerSystems /Users/cbarrows/.julia/packages/PowerSystems/eF3Pv/src/parsers/power_system_table_data.jl:1215
# ┌ Warning: User-defined column name Start Cost Hot is not in dataframe.
# └ @ PowerSystems /Users/cbarrows/.julia/packages/PowerSystems/eF3Pv/src/parsers/power_system_table_data.jl:1215
# ┌ Warning: User-defined column name Must Run is not in dataframe.
# └ @ PowerSystems /Users/cbarrows/.julia/packages/PowerSystems/eF3Pv/src/parsers/power_system_table_data.jl:1215
# ┌ Info: Adding contributing generators for Spin_Up_R2 by category
# └ @ PowerSystems /Users/cbarrows/.julia/packages/PowerSystems/eF3Pv/src/parsers/power_system_table_data.jl:656
# ┌ Warning: User-defined column name Startup Ramp Rate MW/min is not in dataframe.
# └ @ PowerSystems /Users/cbarrows/.julia/packages/PowerSystems/eF3Pv/src/parsers/power_system_table_data.jl:1215
# ┌ Warning: User-defined column name Shutdown Ramp Rate MW/min is not in dataframe.
# └ @ PowerSystems /Users/cbarrows/.julia/packages/PowerSystems/eF3Pv/src/parsers/power_system_table_data.jl:1215
# ┌ Warning: User-defined column name Status at Start is not in dataframe.
# └ @ PowerSystems /Users/cbarrows/.julia/packages/PowerSystems/eF3Pv/src/parsers/power_system_table_data.jl:1215
# ┌ Warning: User-defined column name Time at Status is not in dataframe.
# └ @ PowerSystems /Users/cbarrows/.julia/packages/PowerSystems/eF3Pv/src/parsers/power_system_table_data.jl:1215
# ┌ Warning: User-defined column name Start Cost Cold is not in dataframe.
# └ @ PowerSystems /Users/cbarrows/.julia/packages/PowerSystems/eF3Pv/src/parsers/power_system_table_data.jl:1215
# ┌ Warning: User-defined column name Start Cost Warm is not in dataframe.
# └ @ PowerSystems /Users/cbarrows/.julia/packages/PowerSystems/eF3Pv/src/parsers/power_system_table_data.jl:1215
# ┌ Warning: User-defined column name Start Cost Hot is not in dataframe.
# └ @ PowerSystems /Users/cbarrows/.julia/packages/PowerSystems/eF3Pv/src/parsers/power_system_table_data.jl:1215
# ┌ Warning: User-defined column name Must Run is not in dataframe.
# └ @ PowerSystems /Users/cbarrows/.julia/packages/PowerSystems/eF3Pv/src/parsers/power_system_table_data.jl:1215
# ┌ Info: Adding contributing generators for Spin_Up_R3 by category
# └ @ PowerSystems /Users/cbarrows/.julia/packages/PowerSystems/eF3Pv/src/parsers/power_system_table_data.jl:656
# ┌ Warning: User-defined column name Startup Ramp Rate MW/min is not in dataframe.
# └ @ PowerSystems /Users/cbarrows/.julia/packages/PowerSystems/eF3Pv/src/parsers/power_system_table_data.jl:1215
# ┌ Warning: User-defined column name Shutdown Ramp Rate MW/min is not in dataframe.
# └ @ PowerSystems /Users/cbarrows/.julia/packages/PowerSystems/eF3Pv/src/parsers/power_system_table_data.jl:1215
# ┌ Warning: User-defined column name Status at Start is not in dataframe.
# └ @ PowerSystems /Users/cbarrows/.julia/packages/PowerSystems/eF3Pv/src/parsers/power_system_table_data.jl:1215
# ┌ Warning: User-defined column name Time at Status is not in dataframe.
# └ @ PowerSystems /Users/cbarrows/.julia/packages/PowerSystems/eF3Pv/src/parsers/power_system_table_data.jl:1215
# ┌ Warning: User-defined column name Start Cost Cold is not in dataframe.
# └ @ PowerSystems /Users/cbarrows/.julia/packages/PowerSystems/eF3Pv/src/parsers/power_system_table_data.jl:1215
# ┌ Warning: User-defined column name Start Cost Warm is not in dataframe.
# └ @ PowerSystems /Users/cbarrows/.julia/packages/PowerSystems/eF3Pv/src/parsers/power_system_table_data.jl:1215
# ┌ Warning: User-defined column name Start Cost Hot is not in dataframe.
# └ @ PowerSystems /Users/cbarrows/.julia/packages/PowerSystems/eF3Pv/src/parsers/power_system_table_data.jl:1215
# ┌ Warning: User-defined column name Must Run is not in dataframe.
# └ @ PowerSystems /Users/cbarrows/.julia/packages/PowerSystems/eF3Pv/src/parsers/power_system_table_data.jl:1215
# ┌ Info: Adding contributing generators for Flex_Up by category
# └ @ PowerSystems /Users/cbarrows/.julia/packages/PowerSystems/eF3Pv/src/parsers/power_system_table_data.jl:656
# ┌ Warning: User-defined column name Startup Ramp Rate MW/min is not in dataframe.
# └ @ PowerSystems /Users/cbarrows/.julia/packages/PowerSystems/eF3Pv/src/parsers/power_system_table_data.jl:1215
# ┌ Warning: User-defined column name Shutdown Ramp Rate MW/min is not in dataframe.
# └ @ PowerSystems /Users/cbarrows/.julia/packages/PowerSystems/eF3Pv/src/parsers/power_system_table_data.jl:1215
# ┌ Warning: User-defined column name Status at Start is not in dataframe.
# └ @ PowerSystems /Users/cbarrows/.julia/packages/PowerSystems/eF3Pv/src/parsers/power_system_table_data.jl:1215
# ┌ Warning: User-defined column name Time at Status is not in dataframe.
# └ @ PowerSystems /Users/cbarrows/.julia/packages/PowerSystems/eF3Pv/src/parsers/power_system_table_data.jl:1215
# ┌ Warning: User-defined column name Start Cost Cold is not in dataframe.
# └ @ PowerSystems /Users/cbarrows/.julia/packages/PowerSystems/eF3Pv/src/parsers/power_system_table_data.jl:1215
# ┌ Warning: User-defined column name Start Cost Warm is not in dataframe.
# └ @ PowerSystems /Users/cbarrows/.julia/packages/PowerSystems/eF3Pv/src/parsers/power_system_table_data.jl:1215
# ┌ Warning: User-defined column name Start Cost Hot is not in dataframe.
# └ @ PowerSystems /Users/cbarrows/.julia/packages/PowerSystems/eF3Pv/src/parsers/power_system_table_data.jl:1215
# ┌ Warning: User-defined column name Must Run is not in dataframe.
# └ @ PowerSystems /Users/cbarrows/.julia/packages/PowerSystems/eF3Pv/src/parsers/power_system_table_data.jl:1215
# ┌ Info: Adding contributing generators for Flex_Down by category
# └ @ PowerSystems /Users/cbarrows/.julia/packages/PowerSystems/eF3Pv/src/parsers/power_system_table_data.jl:656
# ┌ Warning: User-defined column name Startup Ramp Rate MW/min is not in dataframe.
# └ @ PowerSystems /Users/cbarrows/.julia/packages/PowerSystems/eF3Pv/src/parsers/power_system_table_data.jl:1215
# ┌ Warning: User-defined column name Shutdown Ramp Rate MW/min is not in dataframe.
# └ @ PowerSystems /Users/cbarrows/.julia/packages/PowerSystems/eF3Pv/src/parsers/power_system_table_data.jl:1215
# ┌ Warning: User-defined column name Status at Start is not in dataframe.
# └ @ PowerSystems /Users/cbarrows/.julia/packages/PowerSystems/eF3Pv/src/parsers/power_system_table_data.jl:1215
# ┌ Warning: User-defined column name Time at Status is not in dataframe.
# └ @ PowerSystems /Users/cbarrows/.julia/packages/PowerSystems/eF3Pv/src/parsers/power_system_table_data.jl:1215
# ┌ Warning: User-defined column name Start Cost Cold is not in dataframe.
# └ @ PowerSystems /Users/cbarrows/.julia/packages/PowerSystems/eF3Pv/src/parsers/power_system_table_data.jl:1215
# ┌ Warning: User-defined column name Start Cost Warm is not in dataframe.
# └ @ PowerSystems /Users/cbarrows/.julia/packages/PowerSystems/eF3Pv/src/parsers/power_system_table_data.jl:1215
# ┌ Warning: User-defined column name Start Cost Hot is not in dataframe.
# └ @ PowerSystems /Users/cbarrows/.julia/packages/PowerSystems/eF3Pv/src/parsers/power_system_table_data.jl:1215
# ┌ Warning: User-defined column name Must Run is not in dataframe.
# └ @ PowerSystems /Users/cbarrows/.julia/packages/PowerSystems/eF3Pv/src/parsers/power_system_table_data.jl:1215
# ┌ Info: Adding contributing generators for Reg_Up by category
# └ @ PowerSystems /Users/cbarrows/.julia/packages/PowerSystems/eF3Pv/src/parsers/power_system_table_data.jl:656
# ┌ Warning: User-defined column name Startup Ramp Rate MW/min is not in dataframe.
# └ @ PowerSystems /Users/cbarrows/.julia/packages/PowerSystems/eF3Pv/src/parsers/power_system_table_data.jl:1215
# ┌ Warning: User-defined column name Shutdown Ramp Rate MW/min is not in dataframe.
# └ @ PowerSystems /Users/cbarrows/.julia/packages/PowerSystems/eF3Pv/src/parsers/power_system_table_data.jl:1215
# ┌ Warning: User-defined column name Status at Start is not in dataframe.
# └ @ PowerSystems /Users/cbarrows/.julia/packages/PowerSystems/eF3Pv/src/parsers/power_system_table_data.jl:1215
# ┌ Warning: User-defined column name Time at Status is not in dataframe.
# └ @ PowerSystems /Users/cbarrows/.julia/packages/PowerSystems/eF3Pv/src/parsers/power_system_table_data.jl:1215
# ┌ Warning: User-defined column name Start Cost Cold is not in dataframe.
# └ @ PowerSystems /Users/cbarrows/.julia/packages/PowerSystems/eF3Pv/src/parsers/power_system_table_data.jl:1215
# ┌ Warning: User-defined column name Start Cost Warm is not in dataframe.
# └ @ PowerSystems /Users/cbarrows/.julia/packages/PowerSystems/eF3Pv/src/parsers/power_system_table_data.jl:1215
# ┌ Warning: User-defined column name Start Cost Hot is not in dataframe.
# └ @ PowerSystems /Users/cbarrows/.julia/packages/PowerSystems/eF3Pv/src/parsers/power_system_table_data.jl:1215
# ┌ Warning: User-defined column name Must Run is not in dataframe.
# └ @ PowerSystems /Users/cbarrows/.julia/packages/PowerSystems/eF3Pv/src/parsers/power_system_table_data.jl:1215
# ┌ Info: Adding contributing generators for Reg_Down by category
# └ @ PowerSystems /Users/cbarrows/.julia/packages/PowerSystems/eF3Pv/src/parsers/power_system_table_data.jl:656
# ┌ Warning: User-defined column name Startup Ramp Rate MW/min is not in dataframe.
# └ @ PowerSystems /Users/cbarrows/.julia/packages/PowerSystems/eF3Pv/src/parsers/power_system_table_data.jl:1215
# ┌ Warning: User-defined column name Shutdown Ramp Rate MW/min is not in dataframe.
# └ @ PowerSystems /Users/cbarrows/.julia/packages/PowerSystems/eF3Pv/src/parsers/power_system_table_data.jl:1215
# ┌ Warning: User-defined column name Status at Start is not in dataframe.
# └ @ PowerSystems /Users/cbarrows/.julia/packages/PowerSystems/eF3Pv/src/parsers/power_system_table_data.jl:1215
# ┌ Warning: User-defined column name Time at Status is not in dataframe.
# └ @ PowerSystems /Users/cbarrows/.julia/packages/PowerSystems/eF3Pv/src/parsers/power_system_table_data.jl:1215
# ┌ Warning: User-defined column name Start Cost Cold is not in dataframe.
# └ @ PowerSystems /Users/cbarrows/.julia/packages/PowerSystems/eF3Pv/src/parsers/power_system_table_data.jl:1215
# ┌ Warning: User-defined column name Start Cost Warm is not in dataframe.
# └ @ PowerSystems /Users/cbarrows/.julia/packages/PowerSystems/eF3Pv/src/parsers/power_system_table_data.jl:1215
# ┌ Warning: User-defined column name Start Cost Hot is not in dataframe.
# └ @ PowerSystems /Users/cbarrows/.julia/packages/PowerSystems/eF3Pv/src/parsers/power_system_table_data.jl:1215
# ┌ Warning: User-defined column name Must Run is not in dataframe.
# └ @ PowerSystems /Users/cbarrows/.julia/packages/PowerSystems/eF3Pv/src/parsers/power_system_table_data.jl:1215
# ┌ Info: Unit System changed to SYSTEM_BASE
# └ @ PowerSystems /Users/cbarrows/.julia/packages/PowerSystems/eF3Pv/src/base.jl:282
# ┌ Warning: The data doesn't include devices of type InterruptibleLoad, consider changing the device models
# └ @ PowerSimulations /Users/cbarrows/.julia/packages/PowerSimulations/0nHyl/src/devices_models/device_constructors/common/constructor_validations.jl:3
# ┌ Warning: Data doesn't contain generators with ramp limits, consider adjusting your formulation
# └ @ PowerSimulations /Users/cbarrows/.julia/packages/PowerSimulations/0nHyl/src/devices_models/devices/thermal_generation.jl:568
# Operations Problem Specification
# ============================================
#
#   transmission:  CopperPlatePowerModel
# ============================================
#   devices:
#       ILoads:
#         device_type = InterruptibleLoad
#         formulation = InterruptiblePowerLoad
#       HydroROR:
#         device_type = HydroDispatch
#         formulation = FixedOutput
#       Generators:
#         device_type = ThermalStandard
#         formulation = ThermalStandardUnitCommitment
#       Ren:
#         device_type = RenewableDispatch
#         formulation = RenewableFullDispatch
#       Hydro:
#         device_type = HydroEnergyReservoir
#         formulation = HydroDispatchRunOfRiver
#       Loads:
#         device_type = PowerLoad
#         formulation = StaticPowerLoad
#       RenFx:
#         device_type = RenewableFix
#         formulation = FixedOutput
# ============================================
#   branches:
#       T:
#         device_type = Transformer2W
#         formulation = StaticTransformer
#       TT:
#         device_type = TapTransformer
#         formulation = StaticTransformer
#       L:
#         device_type = Line
#         formulation = StaticLine
# ============================================
#   services:
#       ReserveDown:
#         service_type = VariableReserve{ReserveDown}
#         formulation = RangeReserve
#       ReserveUp:
#         service_type = VariableReserve{ReserveUp}
#         formulation = RangeReserve
# ============================================

# %% [markdown]
# ### 5-Minute system
# We had already created a `sys::System` from hourly RTS data in the OperationsProblem example.
# The RTS data also includes 5-minute resolution time series data. So, we can create another
# `System`:

# %%
sys_RT = System(rawsys; time_series_resolution = Dates.Minute(5))
transform_single_time_series!(sys_RT, 12, Hour(1))
# Out:
# ┌ Info: Unit System changed to DEVICE_BASE
# └ @ PowerSystems /Users/cbarrows/.julia/packages/PowerSystems/eF3Pv/src/base.jl:288
# ┌ Warning: Missing LOAD data.
# └ @ PowerSystems /Users/cbarrows/.julia/packages/PowerSystems/eF3Pv/src/parsers/power_system_table_data.jl:212
# ┌ Warning: User-defined column name Startup Ramp Rate MW/min is not in dataframe.
# └ @ PowerSystems /Users/cbarrows/.julia/packages/PowerSystems/eF3Pv/src/parsers/power_system_table_data.jl:1215
# ┌ Warning: User-defined column name Shutdown Ramp Rate MW/min is not in dataframe.
# └ @ PowerSystems /Users/cbarrows/.julia/packages/PowerSystems/eF3Pv/src/parsers/power_system_table_data.jl:1215
# ┌ Warning: User-defined column name Status at Start is not in dataframe.
# └ @ PowerSystems /Users/cbarrows/.julia/packages/PowerSystems/eF3Pv/src/parsers/power_system_table_data.jl:1215
# ┌ Warning: User-defined column name Time at Status is not in dataframe.
# └ @ PowerSystems /Users/cbarrows/.julia/packages/PowerSystems/eF3Pv/src/parsers/power_system_table_data.jl:1215
# ┌ Warning: User-defined column name Start Cost Cold is not in dataframe.
# └ @ PowerSystems /Users/cbarrows/.julia/packages/PowerSystems/eF3Pv/src/parsers/power_system_table_data.jl:1215
# ┌ Warning: User-defined column name Start Cost Warm is not in dataframe.
# └ @ PowerSystems /Users/cbarrows/.julia/packages/PowerSystems/eF3Pv/src/parsers/power_system_table_data.jl:1215
# ┌ Warning: User-defined column name Start Cost Hot is not in dataframe.
# └ @ PowerSystems /Users/cbarrows/.julia/packages/PowerSystems/eF3Pv/src/parsers/power_system_table_data.jl:1215
# ┌ Warning: User-defined column name Must Run is not in dataframe.
# └ @ PowerSystems /Users/cbarrows/.julia/packages/PowerSystems/eF3Pv/src/parsers/power_system_table_data.jl:1215
# ┌ Warning: Missing LOAD data.
# └ @ PowerSystems /Users/cbarrows/.julia/packages/PowerSystems/eF3Pv/src/parsers/power_system_table_data.jl:212
# ┌ Info: Adding contributing generators for Spin_Up_R1 by category
# └ @ PowerSystems /Users/cbarrows/.julia/packages/PowerSystems/eF3Pv/src/parsers/power_system_table_data.jl:656
# ┌ Warning: User-defined column name Startup Ramp Rate MW/min is not in dataframe.
# └ @ PowerSystems /Users/cbarrows/.julia/packages/PowerSystems/eF3Pv/src/parsers/power_system_table_data.jl:1215
# ┌ Warning: User-defined column name Shutdown Ramp Rate MW/min is not in dataframe.
# └ @ PowerSystems /Users/cbarrows/.julia/packages/PowerSystems/eF3Pv/src/parsers/power_system_table_data.jl:1215
# ┌ Warning: User-defined column name Status at Start is not in dataframe.
# └ @ PowerSystems /Users/cbarrows/.julia/packages/PowerSystems/eF3Pv/src/parsers/power_system_table_data.jl:1215
# ┌ Warning: User-defined column name Time at Status is not in dataframe.
# └ @ PowerSystems /Users/cbarrows/.julia/packages/PowerSystems/eF3Pv/src/parsers/power_system_table_data.jl:1215
# ┌ Warning: User-defined column name Start Cost Cold is not in dataframe.
# └ @ PowerSystems /Users/cbarrows/.julia/packages/PowerSystems/eF3Pv/src/parsers/power_system_table_data.jl:1215
# ┌ Warning: User-defined column name Start Cost Warm is not in dataframe.
# └ @ PowerSystems /Users/cbarrows/.julia/packages/PowerSystems/eF3Pv/src/parsers/power_system_table_data.jl:1215
# ┌ Warning: User-defined column name Start Cost Hot is not in dataframe.
# └ @ PowerSystems /Users/cbarrows/.julia/packages/PowerSystems/eF3Pv/src/parsers/power_system_table_data.jl:1215
# ┌ Warning: User-defined column name Must Run is not in dataframe.
# └ @ PowerSystems /Users/cbarrows/.julia/packages/PowerSystems/eF3Pv/src/parsers/power_system_table_data.jl:1215
# ┌ Info: Adding contributing generators for Spin_Up_R2 by category
# └ @ PowerSystems /Users/cbarrows/.julia/packages/PowerSystems/eF3Pv/src/parsers/power_system_table_data.jl:656
# ┌ Warning: User-defined column name Startup Ramp Rate MW/min is not in dataframe.
# └ @ PowerSystems /Users/cbarrows/.julia/packages/PowerSystems/eF3Pv/src/parsers/power_system_table_data.jl:1215
# ┌ Warning: User-defined column name Shutdown Ramp Rate MW/min is not in dataframe.
# └ @ PowerSystems /Users/cbarrows/.julia/packages/PowerSystems/eF3Pv/src/parsers/power_system_table_data.jl:1215
# ┌ Warning: User-defined column name Status at Start is not in dataframe.
# └ @ PowerSystems /Users/cbarrows/.julia/packages/PowerSystems/eF3Pv/src/parsers/power_system_table_data.jl:1215
# ┌ Warning: User-defined column name Time at Status is not in dataframe.
# └ @ PowerSystems /Users/cbarrows/.julia/packages/PowerSystems/eF3Pv/src/parsers/power_system_table_data.jl:1215
# ┌ Warning: User-defined column name Start Cost Cold is not in dataframe.
# └ @ PowerSystems /Users/cbarrows/.julia/packages/PowerSystems/eF3Pv/src/parsers/power_system_table_data.jl:1215
# ┌ Warning: User-defined column name Start Cost Warm is not in dataframe.
# └ @ PowerSystems /Users/cbarrows/.julia/packages/PowerSystems/eF3Pv/src/parsers/power_system_table_data.jl:1215
# ┌ Warning: User-defined column name Start Cost Hot is not in dataframe.
# └ @ PowerSystems /Users/cbarrows/.julia/packages/PowerSystems/eF3Pv/src/parsers/power_system_table_data.jl:1215
# ┌ Warning: User-defined column name Must Run is not in dataframe.
# └ @ PowerSystems /Users/cbarrows/.julia/packages/PowerSystems/eF3Pv/src/parsers/power_system_table_data.jl:1215
# ┌ Info: Adding contributing generators for Spin_Up_R3 by category
# └ @ PowerSystems /Users/cbarrows/.julia/packages/PowerSystems/eF3Pv/src/parsers/power_system_table_data.jl:656
# ┌ Warning: User-defined column name Startup Ramp Rate MW/min is not in dataframe.
# └ @ PowerSystems /Users/cbarrows/.julia/packages/PowerSystems/eF3Pv/src/parsers/power_system_table_data.jl:1215
# ┌ Warning: User-defined column name Shutdown Ramp Rate MW/min is not in dataframe.
# └ @ PowerSystems /Users/cbarrows/.julia/packages/PowerSystems/eF3Pv/src/parsers/power_system_table_data.jl:1215
# ┌ Warning: User-defined column name Status at Start is not in dataframe.
# └ @ PowerSystems /Users/cbarrows/.julia/packages/PowerSystems/eF3Pv/src/parsers/power_system_table_data.jl:1215
# ┌ Warning: User-defined column name Time at Status is not in dataframe.
# └ @ PowerSystems /Users/cbarrows/.julia/packages/PowerSystems/eF3Pv/src/parsers/power_system_table_data.jl:1215
# ┌ Warning: User-defined column name Start Cost Cold is not in dataframe.
# └ @ PowerSystems /Users/cbarrows/.julia/packages/PowerSystems/eF3Pv/src/parsers/power_system_table_data.jl:1215
# ┌ Warning: User-defined column name Start Cost Warm is not in dataframe.
# └ @ PowerSystems /Users/cbarrows/.julia/packages/PowerSystems/eF3Pv/src/parsers/power_system_table_data.jl:1215
# ┌ Warning: User-defined column name Start Cost Hot is not in dataframe.
# └ @ PowerSystems /Users/cbarrows/.julia/packages/PowerSystems/eF3Pv/src/parsers/power_system_table_data.jl:1215
# ┌ Warning: User-defined column name Must Run is not in dataframe.
# └ @ PowerSystems /Users/cbarrows/.julia/packages/PowerSystems/eF3Pv/src/parsers/power_system_table_data.jl:1215
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Nov  9 2020
#
# command line - Cbc_C_Interface -ratioGap 0.5 -logLevel 1 -solve -quit (default strategy 1)
# ratioGap was changed from 0 to 0.5
# Continuous objective value is 1.0694e+06 - 0.42 seconds
# Cgl0003I 295 fixed, 0 tightened bounds, 1961 strengthened rows, 61 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 107 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 1866 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 1750 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 1607 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 878 strengthened rows, 0 substitutions
# Cgl0003I 2 fixed, 0 tightened bounds, 720 strengthened rows, 0 substitutions
# Cgl0003I 1 fixed, 0 tightened bounds, 651 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 563 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 495 strengthened rows, 0 substitutions
# Cgl0004I processed model has 12080 rows, 23701 columns (5077 integer (5077 of which binary)) and 73068 elements
# Cbc0045I Trying just fixing integer variables (and fixingish SOS).
# Cbc0045I Warning: mipstart values could not be used to build a solution.
# Cbc0012I Integer solution of 1090238.2 found by DiveCoefficient after 0 iterations and 0 nodes (3.46 seconds)
# Cbc0011I Exiting as integer gap of 20836.17 less than 1e-10 or 50%
# Cbc0001I Search completed - best objective 1090238.193193515, took 0 iterations and 0 nodes (3.47 seconds)
# Cbc0035I Maximum depth 0, 0 variables fixed on reduced cost
# Cuts at root node changed objective from 1.0694e+06 to 1.0694e+06
# Probing was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found (within gap tolerance)
#
# Objective value:                1090238.19319715
# Lower bound:                    1069402.024
# Gap:                            0.02
# Enumerated nodes:               0
# Total iterations:               0
# Time (CPU seconds):             3.91
# Time (Wallclock seconds):       4.36
#
# Total time (CPU seconds):       3.91   (Wallclock seconds):       4.36
#
# ┌ Info: Adding contributing generators for Flex_Up by category
# └ @ PowerSystems /Users/cbarrows/.julia/packages/PowerSystems/eF3Pv/src/parsers/power_system_table_data.jl:656
# ┌ Warning: User-defined column name Startup Ramp Rate MW/min is not in dataframe.
# └ @ PowerSystems /Users/cbarrows/.julia/packages/PowerSystems/eF3Pv/src/parsers/power_system_table_data.jl:1215
# ┌ Warning: User-defined column name Shutdown Ramp Rate MW/min is not in dataframe.
# └ @ PowerSystems /Users/cbarrows/.julia/packages/PowerSystems/eF3Pv/src/parsers/power_system_table_data.jl:1215
# ┌ Warning: User-defined column name Status at Start is not in dataframe.
# └ @ PowerSystems /Users/cbarrows/.julia/packages/PowerSystems/eF3Pv/src/parsers/power_system_table_data.jl:1215
# ┌ Warning: User-defined column name Time at Status is not in dataframe.
# └ @ PowerSystems /Users/cbarrows/.julia/packages/PowerSystems/eF3Pv/src/parsers/power_system_table_data.jl:1215
# ┌ Warning: User-defined column name Start Cost Cold is not in dataframe.
# └ @ PowerSystems /Users/cbarrows/.julia/packages/PowerSystems/eF3Pv/src/parsers/power_system_table_data.jl:1215
# ┌ Warning: User-defined column name Start Cost Warm is not in dataframe.
# └ @ PowerSystems /Users/cbarrows/.julia/packages/PowerSystems/eF3Pv/src/parsers/power_system_table_data.jl:1215
# ┌ Warning: User-defined column name Start Cost Hot is not in dataframe.
# └ @ PowerSystems /Users/cbarrows/.julia/packages/PowerSystems/eF3Pv/src/parsers/power_system_table_data.jl:1215
# ┌ Warning: User-defined column name Must Run is not in dataframe.
# └ @ PowerSystems /Users/cbarrows/.julia/packages/PowerSystems/eF3Pv/src/parsers/power_system_table_data.jl:1215
# ┌ Info: Adding contributing generators for Flex_Down by category
# └ @ PowerSystems /Users/cbarrows/.julia/packages/PowerSystems/eF3Pv/src/parsers/power_system_table_data.jl:656
# ┌ Warning: User-defined column name Startup Ramp Rate MW/min is not in dataframe.
# └ @ PowerSystems /Users/cbarrows/.julia/packages/PowerSystems/eF3Pv/src/parsers/power_system_table_data.jl:1215
# ┌ Warning: User-defined column name Shutdown Ramp Rate MW/min is not in dataframe.
# └ @ PowerSystems /Users/cbarrows/.julia/packages/PowerSystems/eF3Pv/src/parsers/power_system_table_data.jl:1215
# ┌ Warning: User-defined column name Status at Start is not in dataframe.
# └ @ PowerSystems /Users/cbarrows/.julia/packages/PowerSystems/eF3Pv/src/parsers/power_system_table_data.jl:1215
# ┌ Warning: User-defined column name Time at Status is not in dataframe.
# └ @ PowerSystems /Users/cbarrows/.julia/packages/PowerSystems/eF3Pv/src/parsers/power_system_table_data.jl:1215
# ┌ Warning: User-defined column name Start Cost Cold is not in dataframe.
# └ @ PowerSystems /Users/cbarrows/.julia/packages/PowerSystems/eF3Pv/src/parsers/power_system_table_data.jl:1215
# ┌ Warning: User-defined column name Start Cost Warm is not in dataframe.
# └ @ PowerSystems /Users/cbarrows/.julia/packages/PowerSystems/eF3Pv/src/parsers/power_system_table_data.jl:1215
# ┌ Warning: User-defined column name Start Cost Hot is not in dataframe.
# └ @ PowerSystems /Users/cbarrows/.julia/packages/PowerSystems/eF3Pv/src/parsers/power_system_table_data.jl:1215
# ┌ Warning: User-defined column name Must Run is not in dataframe.
# └ @ PowerSystems /Users/cbarrows/.julia/packages/PowerSystems/eF3Pv/src/parsers/power_system_table_data.jl:1215
# ┌ Info: Adding contributing generators for Reg_Up by category
# └ @ PowerSystems /Users/cbarrows/.julia/packages/PowerSystems/eF3Pv/src/parsers/power_system_table_data.jl:656
# ┌ Warning: User-defined column name Startup Ramp Rate MW/min is not in dataframe.
# └ @ PowerSystems /Users/cbarrows/.julia/packages/PowerSystems/eF3Pv/src/parsers/power_system_table_data.jl:1215
# ┌ Warning: User-defined column name Shutdown Ramp Rate MW/min is not in dataframe.
# └ @ PowerSystems /Users/cbarrows/.julia/packages/PowerSystems/eF3Pv/src/parsers/power_system_table_data.jl:1215
# ┌ Warning: User-defined column name Status at Start is not in dataframe.
# └ @ PowerSystems /Users/cbarrows/.julia/packages/PowerSystems/eF3Pv/src/parsers/power_system_table_data.jl:1215
# ┌ Warning: User-defined column name Time at Status is not in dataframe.
# └ @ PowerSystems /Users/cbarrows/.julia/packages/PowerSystems/eF3Pv/src/parsers/power_system_table_data.jl:1215
# ┌ Warning: User-defined column name Start Cost Cold is not in dataframe.
# └ @ PowerSystems /Users/cbarrows/.julia/packages/PowerSystems/eF3Pv/src/parsers/power_system_table_data.jl:1215
# ┌ Warning: User-defined column name Start Cost Warm is not in dataframe.
# └ @ PowerSystems /Users/cbarrows/.julia/packages/PowerSystems/eF3Pv/src/parsers/power_system_table_data.jl:1215
# ┌ Warning: User-defined column name Start Cost Hot is not in dataframe.
# └ @ PowerSystems /Users/cbarrows/.julia/packages/PowerSystems/eF3Pv/src/parsers/power_system_table_data.jl:1215
# ┌ Warning: User-defined column name Must Run is not in dataframe.
# └ @ PowerSystems /Users/cbarrows/.julia/packages/PowerSystems/eF3Pv/src/parsers/power_system_table_data.jl:1215
# ┌ Info: Adding contributing generators for Reg_Down by category
# └ @ PowerSystems /Users/cbarrows/.julia/packages/PowerSystems/eF3Pv/src/parsers/power_system_table_data.jl:656
# ┌ Warning: User-defined column name Startup Ramp Rate MW/min is not in dataframe.
# └ @ PowerSystems /Users/cbarrows/.julia/packages/PowerSystems/eF3Pv/src/parsers/power_system_table_data.jl:1215
# ┌ Warning: User-defined column name Shutdown Ramp Rate MW/min is not in dataframe.
# └ @ PowerSystems /Users/cbarrows/.julia/packages/PowerSystems/eF3Pv/src/parsers/power_system_table_data.jl:1215
# ┌ Warning: User-defined column name Status at Start is not in dataframe.
# └ @ PowerSystems /Users/cbarrows/.julia/packages/PowerSystems/eF3Pv/src/parsers/power_system_table_data.jl:1215
# ┌ Warning: User-defined column name Time at Status is not in dataframe.
# └ @ PowerSystems /Users/cbarrows/.julia/packages/PowerSystems/eF3Pv/src/parsers/power_system_table_data.jl:1215
# ┌ Warning: User-defined column name Start Cost Cold is not in dataframe.
# └ @ PowerSystems /Users/cbarrows/.julia/packages/PowerSystems/eF3Pv/src/parsers/power_system_table_data.jl:1215
# ┌ Warning: User-defined column name Start Cost Warm is not in dataframe.
# └ @ PowerSystems /Users/cbarrows/.julia/packages/PowerSystems/eF3Pv/src/parsers/power_system_table_data.jl:1215
# ┌ Warning: User-defined column name Start Cost Hot is not in dataframe.
# └ @ PowerSystems /Users/cbarrows/.julia/packages/PowerSystems/eF3Pv/src/parsers/power_system_table_data.jl:1215
# ┌ Warning: User-defined column name Must Run is not in dataframe.
# └ @ PowerSystems /Users/cbarrows/.julia/packages/PowerSystems/eF3Pv/src/parsers/power_system_table_data.jl:1215

# %% [markdown]
# ## `OperationsProblemTemplate`s define `Stage`s
# Sequential simulations in PowerSimulations are created by defining `OperationsProblems`
# that represent `Stages`, and how information flows between executions of a `Stage` and
# between different `Stage`s.
#
# Let's start by defining a two stage simulation that might look like a typical day-Ahead
# and real-time electricity market clearing process.

# %% [markdown]
# ### Define the reference model for the day-ahead unit commitment

# %%
devices = Dict(
    :Generators => DeviceModel(ThermalStandard, ThermalStandardUnitCommitment),
    :Ren => DeviceModel(RenewableDispatch, RenewableFullDispatch),
    :Loads => DeviceModel(PowerLoad, StaticPowerLoad),
    :HydroROR => DeviceModel(HydroDispatch, FixedOutput),
    :Hydro => DeviceModel(HydroEnergyReservoir, HydroDispatchRunOfRiver),
    :RenFx => DeviceModel(RenewableFix, FixedOutput),
)
template_uc = template_unit_commitment(devices = devices)
# Out:
# Operations Problem Specification
# ============================================
#
#   transmission:  CopperPlatePowerModel
# ============================================
#   devices:
#       HydroROR:
#         device_type = HydroDispatch
#         formulation = FixedOutput
#       Generators:
#         device_type = ThermalStandard
#         formulation = ThermalStandardUnitCommitment
#       Ren:
#         device_type = RenewableDispatch
#         formulation = RenewableFullDispatch
#       Hydro:
#         device_type = HydroEnergyReservoir
#         formulation = HydroDispatchRunOfRiver
#       Loads:
#         device_type = PowerLoad
#         formulation = StaticPowerLoad
#       RenFx:
#         device_type = RenewableFix
#         formulation = FixedOutput
# ============================================
#   branches:
#       T:
#         device_type = Transformer2W
#         formulation = StaticTransformer
#       TT:
#         device_type = TapTransformer
#         formulation = StaticTransformer
#       L:
#         device_type = Line
#         formulation = StaticLine
#       DC:
#         device_type = HVDCLine
#         formulation = HVDCDispatch
# ============================================
#   services:
#       ReserveDown:
#         service_type = VariableReserve{ReserveDown}
#         formulation = RangeReserve
#       ReserveUp:
#         service_type = VariableReserve{ReserveUp}
#         formulation = RangeReserve
# ============================================

# %% [markdown]
# ### Define the reference model for the real-time economic dispatch

# %%
devices = Dict(
    :Generators => DeviceModel(ThermalStandard, ThermalDispatch),
    :Ren => DeviceModel(RenewableDispatch, RenewableFullDispatch),
    :Loads => DeviceModel(PowerLoad, StaticPowerLoad),
    :HydroROR => DeviceModel(HydroDispatch, FixedOutput),
    :Hydro => DeviceModel(HydroEnergyReservoir, HydroDispatchRunOfRiver),
    :RenFx => DeviceModel(RenewableFix, FixedOutput),
)
template_ed = template_economic_dispatch(devices = devices)
# Out:
# Operations Problem Specification
# ============================================
#
#   transmission:  CopperPlatePowerModel
# ============================================
#   devices:
#       HydroROR:
#         device_type = HydroDispatch
#         formulation = FixedOutput
#       Generators:
#         device_type = ThermalStandard
#         formulation = ThermalDispatch
#       Ren:
#         device_type = RenewableDispatch
#         formulation = RenewableFullDispatch
#       Hydro:
#         device_type = HydroEnergyReservoir
#         formulation = HydroDispatchRunOfRiver
#       Loads:
#         device_type = PowerLoad
#         formulation = StaticPowerLoad
#       RenFx:
#         device_type = RenewableFix
#         formulation = FixedOutput
# ============================================
#   branches:
#       T:
#         device_type = Transformer2W
#         formulation = StaticTransformer
#       TT:
#         device_type = TapTransformer
#         formulation = StaticTransformer
#       L:
#         device_type = Line
#         formulation = StaticLine
#       DC:
#         device_type = HVDCLine
#         formulation = HVDCDispatch
# ============================================
#   services:
# ============================================

# %% [markdown]
# ### Define the `Stage`s
# Stages define models. The actual problem will change as the stage gets updated to represent
# different time periods, but the formulations applied to the components is constant within
# a stage. In this case, we want to define two stages with the `OperationsProblemTemplate`s
# and the `System`s that we've already created.

# %%
stages_definition = Dict(
    "UC" => Stage(GenericOpProblem, template_uc, sys, solver),
    "ED" => Stage(
        GenericOpProblem,
        template_ed,
        sys_RT,
        solver,
        balance_slack_variables = true,
    ),
)
# Out:
# Dict{String,Stage{GenericOpProblem}} with 2 entries:
#   "ED" => Stage()…
#   "UC" => Stage()…

# %% [markdown]
# Note that the "ED" stage has a `balance_slack_variables = true` argument. This adds slack
# variables with a default penalty of 1e6 to the nodal energy balance constraint and helps
# ensure feasibility with some performance impacts.

# %% [markdown]
# ### `SimulationSequence`
# Similar to an `OperationsProblemTemplate`, the `SimulationSequence` provides a template of
# how to execute a sequential set of operations problems.

# %% [markdown]
# print_struct(SimulationSequence)

# %% [markdown]
# Let's review some of the `SimulationSequence` arguments.

# %% [markdown]
# ### Chronologies
# In PowerSimulations, chronologies define where information is flowing. There are two types
# of chronologies.
#  - inter-stage chronologies: Define how information flows between stages. e.g. day-ahead
# solutions are used to inform economic dispatch problems
#  - intra-stage chronologies: Define how information flows between multiple executions of a
# single stage. e.g. the dispatch setpoints of the first period of an economic dispatch problem
# are constrained by the ramping limits from setpoints in the final period of the previous problem.

# %% [markdown]
# Let's define an inter-stage chronology that synchronizes information from 24 periods of
# the first stage with a set of executions of the second stage:

# %%
feedforward_chronologies = Dict(("UC" => "ED") => Synchronize(periods = 24))
# Out:
# Dict{Pair{String,String},Synchronize} with 1 entry:
#   "UC"=>"ED" => Synchronize(24, 0, UpdateTrigger(-1, -1))

# %% [markdown]
# ### `FeedForward` and `Cache`
# The definition of exactly what information is passed using the defined chronologies is
# accomplished with `FeedForward` and `Cache` objects. Specifically, `FeedForward` is used
# to define what to do with information being passed with an inter-stage chronology. Let's
# define a `FeedForward` that affects the semi-continuous range constraints of thermal generators
# in the economic dispatch problems based on the value of the unit-commitment variables.

# %%
feedforward = Dict(
    ("ED", :devices, :Generators) => SemiContinuousFF(
        binary_source_stage = PSI.ON,
        affected_variables = [PSI.ACTIVE_POWER],
    ),
)
# Out:
# Dict{Tuple{String,Symbol,Symbol},SemiContinuousFF} with 1 entry:
#   ("ED", :devices, :Generators) => SemiContinuousFF(:On, [:P], nothing)

# %% [markdown]
# ### Sequencing
# The stage problem length, look-ahead, and other details surrounding the temporal Sequencing
# of stages are controlled using the `order`, `horizons`, and `intervals` arguments.
#  - order::Dict(Int, String) : the hierarchical order of stages in the simulation
#  - horizons::Dict(String, Int) : defines the number of time periods in each stage (problem length)
#  - intervals::Dict(String, Dates.Period) : defines the interval with which stage problems
# advance after each execution. e.g. day-ahead problems have an interval of 24-hours
#
# So, to define a typical day-ahead - real-time sequence, we can define the following:
#  - Day ahead problems should represent 48 hours, advancing 24 hours after each execution (24-hour look-ahead)
#  - Real time problems should represent 1 hour (12 5-minute periods), advancing 1 hour after each execution (no look-ahead)

# %%
order = Dict(1 => "UC", 2 => "ED")
horizons = Dict("UC" => 24, "ED" => 12)
intervals = Dict("UC" => (Hour(24), Consecutive()), "ED" => (Hour(1), Consecutive()))
# Out:
# Dict{String,Tuple{Hour,Consecutive}} with 2 entries:
#   "ED" => (Hour(1), Consecutive(UpdateTrigger(-1, -1)))
#   "UC" => (Hour(24), Consecutive(UpdateTrigger(-1, -1)))

# %% [markdown]
# Finally, we can put it all together:

# %%
DA_RT_sequence = SimulationSequence(
    step_resolution = Hour(24),
    order = order,
    horizons = horizons,
    intervals = intervals,
    ini_cond_chronology = InterStageChronology(),
    feedforward_chronologies = feedforward_chronologies,
    feedforward = feedforward,
)
# Out:
# Feed Forward Chronology
# -----------------------
#
# ED: SemiContinuousFF -> Generators
#
#                      UC--┐ from : On
#                          |
# ┌----┬----┬----┬----┬----┼----┬----┬----┬----┬----┬----┐
# |    |    |    |    |    |    |    |    |    |    |    |
# |    |    |    |    |    |    |    |    |    |    |    |
# └─ED └─ED └─ED └─ED └─ED └─ED └─ED └─ED └─ED └─ED └─ED └─ED ... (x24) to : ["P"]
#
# Initial Condition Chronology
# ----------------------------
#
# 1
# |
# |
# 2 --> 2 ... (x24)

# %% [markdown]
# ## `Simulation`
# Now, we can build and execute a simulation using the `SimulationSequence` and `Stage`s
# that we've defined.

# %%
sim = Simulation(
    name = "rts-test",
    steps = 1,
    stages = stages_definition,
    stages_sequence = DA_RT_sequence,
    simulation_folder = rts_dir,
)
# Out:
# Simulation()

# %% [markdown]
# ### Build simulation

# %%
build!(sim)

# %% [markdown]
# ### Execute simulation

# %%
sim_results = execute!(sim)
# Out:
# Executing Step 1
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Nov  9 2020
#
# command line - Cbc_C_Interface -ratioGap 0.5 -logLevel 1 -solve -quit (default strategy 1)
# ratioGap was changed from 0 to 0.5
# Continuous objective value is 1.0694e+06 - 0.42 seconds
# Cgl0003I 58 fixed, 0 tightened bounds, 1450 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 112 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 1392 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 1309 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 1194 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 550 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 483 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 466 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 455 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 404 strengthened rows, 0 substitutions
# Cgl0004I processed model has 11660 rows, 23629 columns (5005 integer (5005 of which binary)) and 67426 elements
# Cbc0045I Trying just fixing integer variables (and fixingish SOS).
# Cbc0045I Warning: mipstart values could not be used to build a solution.
# Cbc0012I Integer solution of 1089799.8 found by DiveCoefficient after 0 iterations and 0 nodes (3.10 seconds)
# Cbc0011I Exiting as integer gap of 20397.797 less than 1e-10 or 50%
# Cbc0001I Search completed - best objective 1089799.820941764, took 0 iterations and 0 nodes (3.12 seconds)
# Cbc0035I Maximum depth 0, 0 variables fixed on reduced cost
# Cuts at root node changed objective from 1.0694e+06 to 1.0694e+06
# Probing was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found (within gap tolerance)
#
# Objective value:                1089799.82094535
# Lower bound:                    1069402.024
# Gap:                            0.02
# Enumerated nodes:               0
# Total iterations:               0
# Time (CPU seconds):             3.56
# Time (Wallclock seconds):       4.01
#
# Total time (CPU seconds):       3.56   (Wallclock seconds):       4.01
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Nov  9 2020
#
# command line - Cbc_C_Interface -ratioGap 0.5 -logLevel 1 -solve -quit (default strategy 1)
# ratioGap was changed from 0 to 0.5
# Presolve 180 (-3120) rows, 816 (-4212) columns and 984 (-7332) elements
# Perturbing problem by 0.001% of 1000000 - largest nonzero change 0.10690343 ( 0.0082657072%) - largest zero change 0.092441989
# 0  Obj 5.8622404 Primal inf 99.839832 (168)
# 78  Obj 10916.863 Primal inf 32.75991 (90)
# 156  Obj 15454.435 Primal inf 3.599988 (12)
# 168  Obj 15961.597
# Optimal - objective value 15955.018
# After Postsolve, objective 15955.018, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 15955.0182 - 168 iterations time 0.002, Presolve 0.00
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Nov  9 2020
#
# command line - Cbc_C_Interface -ratioGap 0.5 -logLevel 1 -solve -quit (default strategy 1)
# ratioGap was changed from 0 to 0.5
# Presolve 180 (-3120) rows, 816 (-4212) columns and 984 (-7332) elements
# Perturbing problem by 0.001% of 1000000 - largest nonzero change 0.10690343 ( 0.0082657072%) - largest zero change 0.092441989
# 0  Obj 5.8622404 Primal inf 99.839832 (168)
# 78  Obj 10916.863 Primal inf 32.75991 (90)
# 156  Obj 15454.435 Primal inf 3.599988 (12)
# 168  Obj 15961.597
# Optimal - objective value 15955.018
# After Postsolve, objective 15955.018, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 15955.0182 - 168 iterations time 0.002, Presolve 0.00
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Nov  9 2020
#
# command line - Cbc_C_Interface -ratioGap 0.5 -logLevel 1 -solve -quit (default strategy 1)
# ratioGap was changed from 0 to 0.5
# Presolve 180 (-3120) rows, 816 (-4212) columns and 984 (-7332) elements
# Perturbing problem by 0.001% of 1000000 - largest nonzero change 0.10690343 ( 0.0082657072%) - largest zero change 0.092441989
# 0  Obj 5.8622404 Primal inf 99.839832 (168)
# 78  Obj 10916.863 Primal inf 32.75991 (90)
# 156  Obj 15454.435 Primal inf 3.599988 (12)
# 168  Obj 15961.597
# Optimal - objective value 15955.018
# After Postsolve, objective 15955.018, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 15955.0182 - 168 iterations time 0.002, Presolve 0.00
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Nov  9 2020
#
# command line - Cbc_C_Interface -ratioGap 0.5 -logLevel 1 -solve -quit (default strategy 1)
# ratioGap was changed from 0 to 0.5
# Presolve 180 (-3120) rows, 816 (-4212) columns and 984 (-7332) elements
# Perturbing problem by 0.001% of 1000000 - largest nonzero change 0.10690343 ( 0.0082657072%) - largest zero change 0.092441989
# 0  Obj 5.8622404 Primal inf 99.839832 (168)
# 78  Obj 10916.863 Primal inf 32.75991 (90)
# 156  Obj 15454.435 Primal inf 3.599988 (12)
# 168  Obj 15961.597
# Optimal - objective value 15955.018
# After Postsolve, objective 15955.018, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 15955.0182 - 168 iterations time 0.002, Presolve 0.00
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.01
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Nov  9 2020
#
# command line - Cbc_C_Interface -ratioGap 0.5 -logLevel 1 -solve -quit (default strategy 1)
# ratioGap was changed from 0 to 0.5
# Presolve 180 (-3120) rows, 816 (-4212) columns and 984 (-7332) elements
# Perturbing problem by 0.001% of 1000000 - largest nonzero change 0.10690343 ( 0.0082657072%) - largest zero change 0.092441989
# 0  Obj 5.8622404 Primal inf 99.839832 (168)
# 78  Obj 10916.863 Primal inf 32.75991 (90)
# 156  Obj 15454.435 Primal inf 3.599988 (12)
# 168  Obj 15961.597
# Optimal - objective value 15955.018
# After Postsolve, objective 15955.018, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 15955.0182 - 168 iterations time 0.002, Presolve 0.00
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.01
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Nov  9 2020
#
# command line - Cbc_C_Interface -ratioGap 0.5 -logLevel 1 -solve -quit (default strategy 1)
# ratioGap was changed from 0 to 0.5
# Presolve 180 (-3120) rows, 816 (-4212) columns and 984 (-7332) elements
# Perturbing problem by 0.001% of 1000000 - largest nonzero change 0.10690343 ( 0.0082657072%) - largest zero change 0.092441989
# 0  Obj 5.8622404 Primal inf 99.839832 (168)
# 78  Obj 10916.863 Primal inf 32.75991 (90)
# 156  Obj 15454.435 Primal inf 3.599988 (12)
# 168  Obj 15961.597
# Optimal - objective value 15955.018
# After Postsolve, objective 15955.018, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 15955.0182 - 168 iterations time 0.002, Presolve 0.00
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Nov  9 2020
#
# command line - Cbc_C_Interface -ratioGap 0.5 -logLevel 1 -solve -quit (default strategy 1)
# ratioGap was changed from 0 to 0.5
# Presolve 180 (-3120) rows, 816 (-4212) columns and 984 (-7332) elements
# Perturbing problem by 0.001% of 1000000 - largest nonzero change 0.10690343 ( 0.0082657072%) - largest zero change 0.092441989
# 0  Obj 5.8622404 Primal inf 106.69483 (178)
# 78  Obj 9382.7677 Primal inf 65.274434 (125)
# 156  Obj 15020.407 Primal inf 19.326303 (60)
# 230  Obj 16882.386
# Optimal - objective value 16875.37
# After Postsolve, objective 16875.37, infeasibilities - dual 33640.487 (231), primal 0 (0)
# Presolved model was optimal, full model needs cleaning up
# 0  Obj 16875.37
# Optimal - objective value 16875.37
# Optimal objective 16875.37012 - 230 iterations time 0.012, Presolve 0.00
# Total time (CPU seconds):       0.01   (Wallclock seconds):       0.01
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Nov  9 2020
#
# command line - Cbc_C_Interface -ratioGap 0.5 -logLevel 1 -solve -quit (default strategy 1)
# ratioGap was changed from 0 to 0.5
# Presolve 180 (-3120) rows, 816 (-4212) columns and 984 (-7332) elements
# Perturbing problem by 0.001% of 1000000 - largest nonzero change 0.10690343 ( 0.0082657072%) - largest zero change 0.092441989
# 0  Obj 5.8622404 Primal inf 101.98387 (172)
# 78  Obj 9991.0184 Primal inf 42.121187 (104)
# 156  Obj 15224.591 Primal inf 8.6740016 (31)
# 190  Obj 16247.747
# Optimal - objective value 16241.026
# After Postsolve, objective 16241.026, infeasibilities - dual 17044.996 (122), primal 0 (0)
# Presolved model was optimal, full model needs cleaning up
# 0  Obj 16241.026
# Optimal - objective value 16241.026
# Optimal objective 16241.0262 - 190 iterations time 0.012, Presolve 0.00
# Total time (CPU seconds):       0.01   (Wallclock seconds):       0.01
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Nov  9 2020
#
# command line - Cbc_C_Interface -ratioGap 0.5 -logLevel 1 -solve -quit (default strategy 1)
# ratioGap was changed from 0 to 0.5
# Presolve 180 (-3120) rows, 816 (-4212) columns and 984 (-7332) elements
# Perturbing problem by 0.001% of 1000000 - largest nonzero change 0.10690343 ( 0.0082657072%) - largest zero change 0.092441989
# 0  Obj 5.8622404 Primal inf 99.839832 (168)
# 78  Obj 10916.863 Primal inf 32.75991 (90)
# 156  Obj 15454.435 Primal inf 3.599988 (12)
# 168  Obj 15961.597
# Optimal - objective value 15955.018
# After Postsolve, objective 15955.018, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 15955.0182 - 168 iterations time 0.002, Presolve 0.00
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Nov  9 2020
#
# command line - Cbc_C_Interface -ratioGap 0.5 -logLevel 1 -solve -quit (default strategy 1)
# ratioGap was changed from 0 to 0.5
# Presolve 180 (-3120) rows, 816 (-4212) columns and 984 (-7332) elements
# Perturbing problem by 0.001% of 1000000 - largest nonzero change 0.10690343 ( 0.0082657072%) - largest zero change 0.092441989
# 0  Obj 5.8622404 Primal inf 99.839832 (168)
# 78  Obj 10916.863 Primal inf 32.75991 (90)
# 156  Obj 15454.435 Primal inf 3.599988 (12)
# 168  Obj 15961.597
# Optimal - objective value 15955.018
# After Postsolve, objective 15955.018, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 15955.0182 - 168 iterations time 0.002, Presolve 0.00
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Nov  9 2020
#
# command line - Cbc_C_Interface -ratioGap 0.5 -logLevel 1 -solve -quit (default strategy 1)
# ratioGap was changed from 0 to 0.5
# Presolve 180 (-3120) rows, 816 (-4212) columns and 984 (-7332) elements
# Perturbing problem by 0.001% of 1000000 - largest nonzero change 0.10690343 ( 0.0082657072%) - largest zero change 0.092441989
# 0  Obj 5.8622404 Primal inf 99.839832 (168)
# 78  Obj 10916.863 Primal inf 32.75991 (90)
# 156  Obj 15454.435 Primal inf 3.599988 (12)
# 168  Obj 15961.597
# Optimal - objective value 15955.018
# After Postsolve, objective 15955.018, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 15955.0182 - 168 iterations time 0.002, Presolve 0.00
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Nov  9 2020
#
# command line - Cbc_C_Interface -ratioGap 0.5 -logLevel 1 -solve -quit (default strategy 1)
# ratioGap was changed from 0 to 0.5
# Presolve 180 (-3120) rows, 816 (-4212) columns and 984 (-7332) elements
# Perturbing problem by 0.001% of 1000000 - largest nonzero change 0.10690343 ( 0.0082657072%) - largest zero change 0.092441989
# 0  Obj 5.8622404 Primal inf 108.15439 (175)
# 78  Obj 9097.6649 Primal inf 61.277043 (121)
# 156  Obj 15487.502 Primal inf 13.508449 (46)
# 206  Obj 17149.315
# Optimal - objective value 17142.191
# After Postsolve, objective 17142.191, infeasibilities - dual 50587.922 (342), primal 0 (0)
# Presolved model was optimal, full model needs cleaning up
# 0  Obj 17142.191
# Optimal - objective value 17142.191
# Optimal objective 17142.19078 - 206 iterations time 0.012, Presolve 0.00
# Total time (CPU seconds):       0.01   (Wallclock seconds):       0.01
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Nov  9 2020
#
# command line - Cbc_C_Interface -ratioGap 0.5 -logLevel 1 -solve -quit (default strategy 1)
# ratioGap was changed from 0 to 0.5
# Presolve 180 (-3120) rows, 817 (-4211) columns and 985 (-7331) elements
# Perturbing problem by 0.001% of 1000000 - largest nonzero change 0.10690343 ( 0.0082657072%) - largest zero change 0.092441989
# 0  Obj 5.8622404 Primal inf 150.89719 (180)
# 78  Obj 7370.8643 Primal inf 129.99427 (130)
# 156  Obj 19054.075 Primal inf 57.392518 (82)
# 234  Obj 23848.45 Primal inf 10.496927 (19)
# 266  Obj 23888.151
# Optimal - objective value 23878.192
# After Postsolve, objective 23878.192, infeasibilities - dual 96363.275 (576), primal 0 (0)
# Presolved model was optimal, full model needs cleaning up
# 0  Obj 23878.192
# Optimal - objective value 23878.192
# Optimal objective 23878.19153 - 266 iterations time 0.012, Presolve 0.00
# Total time (CPU seconds):       0.01   (Wallclock seconds):       0.01
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Nov  9 2020
#
# command line - Cbc_C_Interface -ratioGap 0.5 -logLevel 1 -solve -quit (default strategy 1)
# ratioGap was changed from 0 to 0.5
# Presolve 180 (-3120) rows, 817 (-4211) columns and 985 (-7331) elements
# Perturbing problem by 0.001% of 1000000 - largest nonzero change 0.10690343 ( 0.0082657072%) - largest zero change 0.092441989
# 0  Obj 5.8622404 Primal inf 174.8868 (180)
# 78  Obj 10767.929 Primal inf 135.24237 (129)
# 156  Obj 22286.185 Primal inf 65.674401 (83)
# 234  Obj 27968.632 Primal inf 13.835217 (23)
# 270  Obj 28007.598
# Optimal - objective value 27996.002
# After Postsolve, objective 27996.002, infeasibilities - dual 101467.29 (576), primal 0 (0)
# Presolved model was optimal, full model needs cleaning up
# 0  Obj 27996.002
# Optimal - objective value 27996.002
# Optimal objective 27996.00203 - 270 iterations time 0.012, Presolve 0.00
# Total time (CPU seconds):       0.01   (Wallclock seconds):       0.01
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Nov  9 2020
#
# command line - Cbc_C_Interface -ratioGap 0.5 -logLevel 1 -solve -quit (default strategy 1)
# ratioGap was changed from 0 to 0.5
# Presolve 192 (-3108) rows, 876 (-4152) columns and 1056 (-7260) elements
# Perturbing problem by 0.001% of 1000000 - largest nonzero change 0.10515435 ( 0.0084526381%) - largest zero change 0.08601695
# 0  Obj 6.2713483 Primal inf 182.60786 (192)
# 78  Obj 8583.6683 Primal inf 150.01125 (151)
# 156  Obj 20454.828 Primal inf 74.66274 (101)
# 234  Obj 28036.968 Primal inf 30.53891 (44)
# 284  Obj 28179.208
# Optimal - objective value 28168.277
# After Postsolve, objective 28168.277, infeasibilities - dual 97109.936 (576), primal 0 (0)
# Presolved model was optimal, full model needs cleaning up
# 0  Obj 28168.277
# Optimal - objective value 28168.277
# Optimal objective 28168.27722 - 284 iterations time 0.012, Presolve 0.00
# Total time (CPU seconds):       0.01   (Wallclock seconds):       0.01
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Nov  9 2020
#
# command line - Cbc_C_Interface -ratioGap 0.5 -logLevel 1 -solve -quit (default strategy 1)
# ratioGap was changed from 0 to 0.5
# Presolve 204 (-3096) rows, 924 (-4104) columns and 1116 (-7200) elements
# Perturbing problem by 0.001% of 1000000 - largest nonzero change 0.10572368 ( 0.0084526381%) - largest zero change 0.082153987
# 0  Obj 834.84589 Primal inf 207.78754 (204)
# 79  Obj 10737.951 Primal inf 172.3377 (158)
# 158  Obj 25222.274 Primal inf 99.144305 (115)
# 237  Obj 31364.366 Primal inf 36.507762 (59)
# 311  Obj 33676.369
# Optimal - objective value 33664.184
# After Postsolve, objective 33664.184, infeasibilities - dual 99205.323 (576), primal 0 (0)
# Presolved model was optimal, full model needs cleaning up
# 0  Obj 33664.184
# Optimal - objective value 33664.184
# Optimal objective 33664.18357 - 311 iterations time 0.012, Presolve 0.00
# Total time (CPU seconds):       0.01   (Wallclock seconds):       0.01
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Nov  9 2020
#
# command line - Cbc_C_Interface -ratioGap 0.5 -logLevel 1 -solve -quit (default strategy 1)
# ratioGap was changed from 0 to 0.5
# Presolve 228 (-3072) rows, 1044 (-3984) columns and 1260 (-7056) elements
# Perturbing problem by 0.001% of 1000000 - largest nonzero change 0.10963206 ( 0.0083908538%) - largest zero change 0.07283754
# 0  Obj 835.72554 Primal inf 293.52002 (228)
# 79  Obj 18772.225 Primal inf 225.72564 (183)
# 158  Obj 36311.435 Primal inf 127.73332 (134)
# 237  Obj 44588.36 Primal inf 53.332322 (77)
# 316  Obj 49552.061 Primal inf 2.3484988 (7)
# 323  Obj 49554.755
# Optimal - objective value 49539.608
# After Postsolve, objective 49539.608, infeasibilities - dual 69205.589 (373), primal 0 (0)
# Presolved model was optimal, full model needs cleaning up
# 0  Obj 49539.608
# Optimal - objective value 49539.608
# Optimal objective 49539.60846 - 323 iterations time 0.012, Presolve 0.00
# Total time (CPU seconds):       0.01   (Wallclock seconds):       0.01
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Nov  9 2020
#
# command line - Cbc_C_Interface -ratioGap 0.5 -logLevel 1 -solve -quit (default strategy 1)
# ratioGap was changed from 0 to 0.5
# Presolve 252 (-3048) rows, 1165 (-3863) columns and 1405 (-6911) elements
# Perturbing problem by 0.001% of 1000000 - largest nonzero change 0.10809688 ( 0.0083908538%) - largest zero change 0.065185311
# 0  Obj 835.04399 Primal inf 344.87043 (252)
# 80  Obj 23863.427 Primal inf 268.53282 (206)
# 160  Obj 44404.883 Primal inf 129.66343 (154)
# 240  Obj 51425.598 Primal inf 71.493829 (104)
# 320  Obj 59021.13 Primal inf 3.830564 (21)
# 342  Obj 60742.021
# Optimal - objective value 60725.737
# After Postsolve, objective 60725.737, infeasibilities - dual 57912.38 (276), primal 0 (0)
# Presolved model was optimal, full model needs cleaning up
# 0  Obj 60725.737
# Optimal - objective value 60725.737
# Optimal objective 60725.737 - 342 iterations time 0.012, Presolve 0.00
# Total time (CPU seconds):       0.01   (Wallclock seconds):       0.01
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Nov  9 2020
#
# command line - Cbc_C_Interface -ratioGap 0.5 -logLevel 1 -solve -quit (default strategy 1)
# ratioGap was changed from 0 to 0.5
# Presolve 228 (-3072) rows, 1044 (-3984) columns and 1260 (-7056) elements
# Perturbing problem by 0.001% of 1000000 - largest nonzero change 0.10963206 ( 0.0083908538%) - largest zero change 0.07283754
# 0  Obj 835.72554 Primal inf 340.9209 (228)
# 79  Obj 24112.438 Primal inf 271.04134 (187)
# 158  Obj 45771.015 Primal inf 123.49244 (125)
# 237  Obj 52343.22 Primal inf 60.322403 (73)
# 303  Obj 58733.536
# Optimal - objective value 58716.05
# After Postsolve, objective 58716.05, infeasibilities - dual 57857.171 (276), primal 0 (0)
# Presolved model was optimal, full model needs cleaning up
# 0  Obj 58716.05
# Optimal - objective value 58716.05
# Optimal objective 58716.0498 - 303 iterations time 0.012, Presolve 0.00
# Total time (CPU seconds):       0.01   (Wallclock seconds):       0.01
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Nov  9 2020
#
# command line - Cbc_C_Interface -ratioGap 0.5 -logLevel 1 -solve -quit (default strategy 1)
# ratioGap was changed from 0 to 0.5
# Presolve 228 (-3072) rows, 1044 (-3984) columns and 1260 (-7056) elements
# Perturbing problem by 0.001% of 1000000 - largest nonzero change 0.10963206 ( 0.0083908538%) - largest zero change 0.07283754
# 0  Obj 835.72554 Primal inf 318.42596 (228)
# 79  Obj 18048.391 Primal inf 254.27283 (182)
# 158  Obj 40180.586 Primal inf 141.44345 (134)
# 237  Obj 48667.868 Primal inf 64.165841 (79)
# 316  Obj 54256.413 Primal inf 5.8567286 (9)
# 326  Obj 54269.352
# Optimal - objective value 54252.978
# After Postsolve, objective 54252.978, infeasibilities - dual 53583.503 (276), primal 0 (0)
# Presolved model was optimal, full model needs cleaning up
# 0  Obj 54252.978
# Optimal - objective value 54252.978
# Optimal objective 54252.97781 - 326 iterations time 0.012, Presolve 0.00
# Total time (CPU seconds):       0.01   (Wallclock seconds):       0.01
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Nov  9 2020
#
# command line - Cbc_C_Interface -ratioGap 0.5 -logLevel 1 -solve -quit (default strategy 1)
# ratioGap was changed from 0 to 0.5
# Presolve 228 (-3072) rows, 1044 (-3984) columns and 1260 (-7056) elements
# Perturbing problem by 0.001% of 1000000 - largest nonzero change 0.10963206 ( 0.0083908538%) - largest zero change 0.07283754
# 0  Obj 835.72554 Primal inf 287.77357 (228)
# 79  Obj 17665.133 Primal inf 229.78486 (181)
# 158  Obj 34126.873 Primal inf 133.44153 (132)
# 237  Obj 42820.928 Primal inf 57.340831 (83)
# 316  Obj 48414.191 Primal inf 8.7703977 (18)
# 333  Obj 48436.082
# Optimal - objective value 48421.284
# After Postsolve, objective 48421.284, infeasibilities - dual 51369.066 (276), primal 0 (0)
# Presolved model was optimal, full model needs cleaning up
# 0  Obj 48421.284
# Optimal - objective value 48421.284
# Optimal objective 48421.28404 - 333 iterations time 0.012, Presolve 0.00
# Total time (CPU seconds):       0.01   (Wallclock seconds):       0.01
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Nov  9 2020
#
# command line - Cbc_C_Interface -ratioGap 0.5 -logLevel 1 -solve -quit (default strategy 1)
# ratioGap was changed from 0 to 0.5
# Presolve 180 (-3120) rows, 828 (-4200) columns and 996 (-7320) elements
# Perturbing problem by 0.001% of 1000000 - largest nonzero change 0.10690343 ( 0.008458935%) - largest zero change 0.091301468
# 0  Obj 836.63961 Primal inf 251.63101 (180)
# 78  Obj 18982.885 Primal inf 181.20852 (137)
# 156  Obj 36337.188 Primal inf 78.257647 (88)
# 234  Obj 42508.571 Primal inf 20.640001 (27)
# 265  Obj 42640.537
# Optimal - objective value 42623.599
# After Postsolve, objective 42623.599, infeasibilities - dual 53504.088 (276), primal 0 (0)
# Presolved model was optimal, full model needs cleaning up
# 0  Obj 42623.599
# Optimal - objective value 42623.599
# Optimal objective 42623.59859 - 265 iterations time 0.012, Presolve 0.00
# Total time (CPU seconds):       0.01   (Wallclock seconds):       0.01
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Nov  9 2020
#
# command line - Cbc_C_Interface -ratioGap 0.5 -logLevel 1 -solve -quit (default strategy 1)
# ratioGap was changed from 0 to 0.5
# Presolve 168 (-3132) rows, 768 (-4260) columns and 924 (-7392) elements
# Perturbing problem by 0.001% of 1000000 - largest nonzero change 0.10854379 ( 0.0083908538%) - largest zero change 0.098045255
# 0  Obj 836.16249 Primal inf 237.9198 (168)
# 78  Obj 22360.115 Primal inf 144.56457 (122)
# 156  Obj 36481.142 Primal inf 55.78687 (71)
# 224  Obj 41827.736
# Optimal - objective value 41810.315
# After Postsolve, objective 41810.315, infeasibilities - dual 56257.237 (276), primal 0 (0)
# Presolved model was optimal, full model needs cleaning up
# 0  Obj 41810.315
# Optimal - objective value 41810.315
# Optimal objective 41810.31455 - 224 iterations time 0.012, Presolve 0.00
# Total time (CPU seconds):       0.01   (Wallclock seconds):       0.01
# Simulation Results Reference
#
# Results Folder: /Users/cbarrows/Documents/repos/SIIPExamples.jl/RTS-GMLC-master/rts-test/6/results
#
# Reference Tables
#
# ________________
#
# stage-UC
#
# P__ThermalStandard: dataframe size (1, 3)
#
# P__RenewableDispatch: dataframe size (1, 3)
#
# Reg_Down__VariableReserve_ReserveDown: dataframe size (1, 3)
#
# parameter_P_PowerLoad: dataframe size (1, 3)
#
# P__HydroEnergyReservoir: dataframe size (1, 3)
#
# Flex_Down__VariableReserve_ReserveDown: dataframe size (1, 3)
#
# parameter_service_requirement_VariableReserve_ReserveDown: dataframe size (1, 3)
#
# Reg_Up__VariableReserve_ReserveUp: dataframe size (1, 3)
#
# parameter_P_RenewableDispatch: dataframe size (1, 3)
#
# Spin_Up_R2__VariableReserve_ReserveUp: dataframe size (1, 3)
#
# parameter_service_requirement_VariableReserve_ReserveUp: dataframe size (1, 3)
#
# parameter_P_HydroEnergyReservoir: dataframe size (1, 3)
#
# parameter_P_RenewableFix: dataframe size (1, 3)
#
# On__ThermalStandard: dataframe size (1, 3)
#
# parameter_P_HydroDispatch: dataframe size (1, 3)
#
# start__ThermalStandard: dataframe size (1, 3)
#
# Flex_Up__VariableReserve_ReserveUp: dataframe size (1, 3)
#
# stop__ThermalStandard: dataframe size (1, 3)
#
# Spin_Up_R1__VariableReserve_ReserveUp: dataframe size (1, 3)
#
# Spin_Up_R3__VariableReserve_ReserveUp: dataframe size (1, 3)
#
# stage-ED
#
# parameter_P_HydroDispatch: dataframe size (24, 3)
#
# parameter_P_RenewableDispatch: dataframe size (24, 3)
#
# P__ThermalStandard: dataframe size (24, 3)
#
# P__RenewableDispatch: dataframe size (24, 3)
#
# parameter_P_HydroEnergyReservoir: dataframe size (24, 3)
#
# parameter_P_RenewableFix: dataframe size (24, 3)
#
# parameter_P_PowerLoad: dataframe size (24, 3)
#
# P__HydroEnergyReservoir: dataframe size (24, 3)
#
# γ⁺__P: dataframe size (24, 3)
#
# γ⁻__P: dataframe size (24, 3)
#
# stage-UC
#
# time length: 24
#
# stage-ED
#
# time length: 12

# %% [markdown]
# ## Results

# %%
uc_results = load_simulation_results(sim_results, "UC");
ed_results = load_simulation_results(sim_results, "ED");

# %% [markdown]
# ## Plotting
# Take a look at the examples in [the plotting folder.](../../notebook/3_PowerSimulations_examples/Plotting)

# %% [markdown]
# ---
#
# *This notebook was generated using [Literate.jl](https://github.com/fredrikekre/Literate.jl).*
