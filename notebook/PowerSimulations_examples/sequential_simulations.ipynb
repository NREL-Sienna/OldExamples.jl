# %% [markdown]
# # Sequential Simulations with [PowerSimulations.jl](https://github.com/NREL/PowerSimulations.jl)

# %% [markdown]
# **Originally Contributed by**: Clayton Barrows

# %% [markdown]
# ## Introduction

# %% [markdown]
# PowerSimulations.jl supports simulations that consist of sequential optimization problems
# where results from previous problems inform subsequent problems in a variety of ways. This
# example demonstrates some of these capabilities to represent electricitty market clearing.

# %% [markdown]
# ## Dependencies
# Since the `OperatiotnsProblem` is the fundamental building block of a sequential
# simulation in PowerSimulations, we will build on the [OperationsProblem example](../../notebook/PowerSimulations_examples/operations_problems.ipynb)
# by sourcing it as a dependency.

# %%
using SIIPExamples
pkgpath = dirname(dirname(pathof(SIIPExamples)))
include(joinpath(pkgpath,"test/PowerSimulations_examples/operations_problems.jl"))
# Out:
# ┌ Info: Parsing csv data in branch.csv ...
# └ @ PowerSystems /Users/cbarrows/.julia/packages/PowerSystems/N15Uk/src/parsers/power_system_table_data.jl:148
# ┌ Info: Successfully parsed branch.csv
# └ @ PowerSystems /Users/cbarrows/.julia/packages/PowerSystems/N15Uk/src/parsers/power_system_table_data.jl:153
# ┌ Info: Parsing csv data in bus.csv ...
# └ @ PowerSystems /Users/cbarrows/.julia/packages/PowerSystems/N15Uk/src/parsers/power_system_table_data.jl:148
# ┌ Info: Successfully parsed bus.csv
# └ @ PowerSystems /Users/cbarrows/.julia/packages/PowerSystems/N15Uk/src/parsers/power_system_table_data.jl:153
# ┌ Info: Parsing csv data in dc_branch.csv ...
# └ @ PowerSystems /Users/cbarrows/.julia/packages/PowerSystems/N15Uk/src/parsers/power_system_table_data.jl:148
# ┌ Info: Successfully parsed dc_branch.csv
# └ @ PowerSystems /Users/cbarrows/.julia/packages/PowerSystems/N15Uk/src/parsers/power_system_table_data.jl:153
# ┌ Info: Parsing csv data in gen.csv ...
# └ @ PowerSystems /Users/cbarrows/.julia/packages/PowerSystems/N15Uk/src/parsers/power_system_table_data.jl:148
# ┌ Info: Successfully parsed gen.csv
# └ @ PowerSystems /Users/cbarrows/.julia/packages/PowerSystems/N15Uk/src/parsers/power_system_table_data.jl:153
# ┌ Info: Parsing csv data in reserves.csv ...
# └ @ PowerSystems /Users/cbarrows/.julia/packages/PowerSystems/N15Uk/src/parsers/power_system_table_data.jl:148
# ┌ Info: Successfully parsed reserves.csv
# └ @ PowerSystems /Users/cbarrows/.julia/packages/PowerSystems/N15Uk/src/parsers/power_system_table_data.jl:153
# ┌ Info: Parsing csv data in simulation_objects.csv ...
# └ @ PowerSystems /Users/cbarrows/.julia/packages/PowerSystems/N15Uk/src/parsers/power_system_table_data.jl:148
# ┌ Info: Successfully parsed simulation_objects.csv
# └ @ PowerSystems /Users/cbarrows/.julia/packages/PowerSystems/N15Uk/src/parsers/power_system_table_data.jl:153
# ┌ Info: Parsing csv data in storage.csv ...
# └ @ PowerSystems /Users/cbarrows/.julia/packages/PowerSystems/N15Uk/src/parsers/power_system_table_data.jl:148
# ┌ Info: Successfully parsed storage.csv
# └ @ PowerSystems /Users/cbarrows/.julia/packages/PowerSystems/N15Uk/src/parsers/power_system_table_data.jl:153
# ┌ Info: Parsing csv data in timeseries_pointers.csv ...
# └ @ PowerSystems /Users/cbarrows/.julia/packages/PowerSystems/N15Uk/src/parsers/power_system_table_data.jl:148
# ┌ Info: Successfully parsed timeseries_pointers.csv
# └ @ PowerSystems /Users/cbarrows/.julia/packages/PowerSystems/N15Uk/src/parsers/power_system_table_data.jl:153
# ┌ Info: Adding contributing generators for Spin_Up_R1 by category
# └ @ PowerSystems /Users/cbarrows/.julia/packages/PowerSystems/N15Uk/src/parsers/power_system_table_data.jl:640
# ┌ Info: Adding contributing generators for Spin_Up_R2 by category
# └ @ PowerSystems /Users/cbarrows/.julia/packages/PowerSystems/N15Uk/src/parsers/power_system_table_data.jl:640
# ┌ Info: Adding contributing generators for Spin_Up_R3 by category
# └ @ PowerSystems /Users/cbarrows/.julia/packages/PowerSystems/N15Uk/src/parsers/power_system_table_data.jl:640
# ┌ Info: Adding contributing generators for Flex_Up by category
# └ @ PowerSystems /Users/cbarrows/.julia/packages/PowerSystems/N15Uk/src/parsers/power_system_table_data.jl:640
# ┌ Info: Adding contributing generators for Flex_Down by category
# └ @ PowerSystems /Users/cbarrows/.julia/packages/PowerSystems/N15Uk/src/parsers/power_system_table_data.jl:640
# ┌ Info: Adding contributing generators for Reg_Up by category
# └ @ PowerSystems /Users/cbarrows/.julia/packages/PowerSystems/N15Uk/src/parsers/power_system_table_data.jl:640
# ┌ Info: Adding contributing generators for Reg_Down by category
# └ @ PowerSystems /Users/cbarrows/.julia/packages/PowerSystems/N15Uk/src/parsers/power_system_table_data.jl:640
# ┌ Warning: The data doesn't include devices of type InterruptibleLoad, consider changing the device models
# └ @ PowerSimulations /Users/cbarrows/.julia/packages/PowerSimulations/TTXVL/src/devices_models/device_constructors/common/constructor_validations.jl:4
# ┌ Warning: Data doesn't contain generators with ramp limits, consider adjusting your formulation
# └ @ PowerSimulations /Users/cbarrows/.julia/packages/PowerSimulations/TTXVL/src/devices_models/devices/thermal_generation.jl:369
# ┌ Info: Generator 202_CT_2 has a nonbinding time limits. Constraints Skipped
# └ @ PowerSimulations /Users/cbarrows/.julia/packages/PowerSimulations/TTXVL/src/devices_models/devices/thermal_generation.jl:435
# ┌ Info: Generator 302_CT_1 has a nonbinding time limits. Constraints Skipped
# └ @ PowerSimulations /Users/cbarrows/.julia/packages/PowerSimulations/TTXVL/src/devices_models/devices/thermal_generation.jl:435
# ┌ Info: Generator 202_CT_1 has a nonbinding time limits. Constraints Skipped
# └ @ PowerSimulations /Users/cbarrows/.julia/packages/PowerSimulations/TTXVL/src/devices_models/devices/thermal_generation.jl:435
# ┌ Info: Generator 114_SYNC_COND_1 has a nonbinding time limits. Constraints Skipped
# └ @ PowerSimulations /Users/cbarrows/.julia/packages/PowerSimulations/TTXVL/src/devices_models/devices/thermal_generation.jl:435
# ┌ Info: Generator 302_CT_2 has a nonbinding time limits. Constraints Skipped
# └ @ PowerSimulations /Users/cbarrows/.julia/packages/PowerSimulations/TTXVL/src/devices_models/devices/thermal_generation.jl:435
# ┌ Info: Generator 101_CT_1 has a nonbinding time limits. Constraints Skipped
# └ @ PowerSimulations /Users/cbarrows/.julia/packages/PowerSimulations/TTXVL/src/devices_models/devices/thermal_generation.jl:435
# ┌ Info: Generator 314_SYNC_COND_1 has a nonbinding time limits. Constraints Skipped
# └ @ PowerSimulations /Users/cbarrows/.julia/packages/PowerSimulations/TTXVL/src/devices_models/devices/thermal_generation.jl:435
# ┌ Info: Generator 101_CT_2 has a nonbinding time limits. Constraints Skipped
# └ @ PowerSimulations /Users/cbarrows/.julia/packages/PowerSimulations/TTXVL/src/devices_models/devices/thermal_generation.jl:435
# ┌ Info: Generator 214_SYNC_COND_1 has a nonbinding time limits. Constraints Skipped
# └ @ PowerSimulations /Users/cbarrows/.julia/packages/PowerSimulations/TTXVL/src/devices_models/devices/thermal_generation.jl:435
# ┌ Info: Generator 301_CT_1 has a nonbinding time limits. Constraints Skipped
# └ @ PowerSimulations /Users/cbarrows/.julia/packages/PowerSimulations/TTXVL/src/devices_models/devices/thermal_generation.jl:435
# ┌ Info: Generator 102_CT_2 has a nonbinding time limits. Constraints Skipped
# └ @ PowerSimulations /Users/cbarrows/.julia/packages/PowerSimulations/TTXVL/src/devices_models/devices/thermal_generation.jl:435
# ┌ Info: Generator 102_CT_1 has a nonbinding time limits. Constraints Skipped
# └ @ PowerSimulations /Users/cbarrows/.julia/packages/PowerSimulations/TTXVL/src/devices_models/devices/thermal_generation.jl:435
# ┌ Info: Generator 201_CT_2 has a nonbinding time limits. Constraints Skipped
# └ @ PowerSimulations /Users/cbarrows/.julia/packages/PowerSimulations/TTXVL/src/devices_models/devices/thermal_generation.jl:435
# ┌ Info: Generator 201_CT_1 has a nonbinding time limits. Constraints Skipped
# └ @ PowerSimulations /Users/cbarrows/.julia/packages/PowerSimulations/TTXVL/src/devices_models/devices/thermal_generation.jl:435
# ┌ Info: Generator 301_CT_2 has a nonbinding time limits. Constraints Skipped
# └ @ PowerSimulations /Users/cbarrows/.julia/packages/PowerSimulations/TTXVL/src/devices_models/devices/thermal_generation.jl:435
# mutable struct PowerSimulations.PSIContainer
#     JuMPmodel::AbstractModel
#     optimizer_factory::Union{Nothing, MathOptInterface.OptimizerWithAttributes}
#     time_steps::UnitRange{Int64}
#     resolution::TimePeriod
#     use_forecast_data::Bool
#     initial_time::DateTime
#     variables::Dict{Symbol,JuMP.Containers.DenseAxisArray}
#     constraints::Dict{Symbol,JuMP.Containers.DenseAxisArray}
#     cost_function::AbstractJuMPScalar
#     expressions::Dict{Symbol,JuMP.Containers.DenseAxisArray}
#     parameters::Union{Nothing, Dict{Symbol,PowerSimulations.ParameterContainer}}
#     initial_conditions::Dict{PowerSimulations.ICKey,Array{InitialCondition,N} where N}
#     pm::Union{Nothing, PowerModels.AbstractPowerModel}
# end
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Oct  7 2019
#
# command line - Cbc_C_Interface -ratioGap 0.5 -logLevel 1 -solve -quit (default strategy 1)
# ratioGap was changed from 0 to 0.5
# Continuous objective value is 305848 - 0.14 seconds
# Cgl0003I 207 fixed, 0 tightened bounds, 653 strengthened rows, 48 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 745 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 633 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 512 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 288 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 219 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 173 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 144 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 135 strengthened rows, 0 substitutions
# Cgl0004I processed model has 5694 rows, 11881 columns (2419 integer (2419 of which binary)) and 32117 elements
# Cbc0045I Trying just fixing integer variables (and fixingish SOS).
# Cbc0045I MIPStart solution provided values for 3228 of 2419 integer variables, 77 variables are still fractional.
# Cbc0038I Full problem 5694 rows 11881 columns, reduced to 5687 rows 11881 columns
# Cbc0038I Probing was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Cbc0045I Mini branch and bound defined values for remaining variables in 5.48 seconds.
# Cbc0045I MIPStart provided solution with cost 308696
# Cbc0012I Integer solution of 308695.72 found by Reduced search after 0 iterations and 0 nodes (7.17 seconds)
# Cbc0038I Full problem 5694 rows 11881 columns, reduced to 964 rows 2695 columns
# Cbc0011I Exiting as integer gap of 2847.8543 less than 1e-10 or 50%
# Cbc0001I Search completed - best objective 308695.7165395001, took 0 iterations and 0 nodes (7.37 seconds)
# Cbc0035I Maximum depth 0, 0 variables fixed on reduced cost
# Cuts at root node changed objective from 305848 to 305848
# Probing was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found (within gap tolerance)
#
# Objective value:                308695.71653950
# Lower bound:                    305847.862
# Gap:                            0.01
# Enumerated nodes:               0
# Total iterations:               0
# Time (CPU seconds):             7.62
# Time (Wallclock seconds):       9.30
#
# Total time (CPU seconds):       7.62   (Wallclock seconds):       9.30
#
# ┌ Warning: SolveTime() property not supported by COIN Branch-and-Cut (Cbc)
# └ @ PowerSimulations /Users/cbarrows/.julia/packages/PowerSimulations/TTXVL/src/core/operations_problem.jl:642
#  struct PowerSimulations.SimulationResults
#     variables::Dict{Symbol,DataFrame}
#     total_cost::Dict
#     optimizer_log::Dict
#     time_stamp::DataFrame
#     results_folder::Union{Nothing, String}
# end

# %% [markdown]
# ### 5-Minute system
# We had already created a `sys::System` from hourly RTS data in the OperationsProblem example.
# The RTS data also includes 5-minute resolution time series data. So, we can create another
# `System`:

# %%
sys_RT = System(rawsys; forecast_resolution = Dates.Minute(5))
# Out:
# ┌ Info: Adding contributing generators for Spin_Up_R1 by category
# └ @ PowerSystems /Users/cbarrows/.julia/packages/PowerSystems/N15Uk/src/parsers/power_system_table_data.jl:640
# ┌ Info: Adding contributing generators for Spin_Up_R2 by category
# └ @ PowerSystems /Users/cbarrows/.julia/packages/PowerSystems/N15Uk/src/parsers/power_system_table_data.jl:640
# ┌ Info: Adding contributing generators for Spin_Up_R3 by category
# └ @ PowerSystems /Users/cbarrows/.julia/packages/PowerSystems/N15Uk/src/parsers/power_system_table_data.jl:640
# ┌ Info: Adding contributing generators for Flex_Up by category
# └ @ PowerSystems /Users/cbarrows/.julia/packages/PowerSystems/N15Uk/src/parsers/power_system_table_data.jl:640
# ┌ Info: Adding contributing generators for Flex_Down by category
# └ @ PowerSystems /Users/cbarrows/.julia/packages/PowerSystems/N15Uk/src/parsers/power_system_table_data.jl:640
# ┌ Info: Adding contributing generators for Reg_Up by category
# └ @ PowerSystems /Users/cbarrows/.julia/packages/PowerSystems/N15Uk/src/parsers/power_system_table_data.jl:640
# ┌ Info: Adding contributing generators for Reg_Down by category
# └ @ PowerSystems /Users/cbarrows/.julia/packages/PowerSystems/N15Uk/src/parsers/power_system_table_data.jl:640
# System
# ======
# Base Power: 100.0
#
# Components
# ==========
# Num components: 434
#
# 15×3 DataFrame. Omitted printing of 2 columns
# │ Row │ ConcreteType                 │
# │     │ String                       │
# ├─────┼──────────────────────────────┤
# │ 1   │ Area                         │
# │ 2   │ Bus                          │
# │ 3   │ GenericBattery               │
# │ 4   │ HVDCLine                     │
# │ 5   │ HydroDispatch                │
# │ 6   │ Line                         │
# │ 7   │ LoadZone                     │
# │ 8   │ PowerLoad                    │
# │ 9   │ RenewableDispatch            │
# │ 10  │ RenewableFix                 │
# │ 11  │ TapTransformer               │
# │ 12  │ ThermalStandard              │
# │ 13  │ Transformer2W                │
# │ 14  │ VariableReserve{ReserveDown} │
# │ 15  │ VariableReserve{ReserveUp}   │
#
# Forecasts
# =========
# Resolution: 5 minutes
# Horizon: 105408
# Initial Times: 2020-01-01T00:00:00
# Interval: 0 seconds
# Components with Forecasts: 137
# Total Forecasts: 188

# %% [markdown]
# The RTS dataset has some large RE and load forecast errors that create infeasible
# simulations. Until we enable formulations with slack variables, we need to increase the
# amount of reserve held to handle the forecast error.

# %%
get_component(VariableReserve{ReserveUp}, sys, "Flex_Up").requirement = 5.0
# Out:
# 5.0

# %% [markdown]
# ## `OperationsProblemTemplate`s define `Stage`s
# Sequential simulations in PowerSimulations are created by defining `OperationsProblems`
# that represent `Stages`, and how information flows between executions of a `Stage` and
# between different `Stage`s.
#
# Let's start by defining a two stage simulation that might look like a typical day-Ahead
# and real-time electricity market clearing process.

# %% [markdown]
# ### Define the reference model for the day-ahead unit commitment

# %%
devices = Dict(
    :Generators => DeviceModel(ThermalStandard, ThermalStandardUnitCommitment),
    :Ren => DeviceModel(RenewableDispatch, RenewableFullDispatch),
    :Loads => DeviceModel(PowerLoad, StaticPowerLoad),
    :HydroROR => DeviceModel(HydroDispatch, HydroDispatchRunOfRiver),
    :RenFx => DeviceModel(RenewableFix, RenewableFixed),
)
template_uc = template_unit_commitment(devices = devices)
# Out:
# Operations Problem Specification
# ============================================
#
#   transmission:  CopperPlatePowerModel
# ============================================
#   devices:
#       HydroROR:
#         device_type = HydroDispatch
#         formulation = HydroDispatchRunOfRiver
#       Generators:
#         device_type = ThermalStandard
#         formulation = ThermalStandardUnitCommitment
#       Ren:
#         device_type = RenewableDispatch
#         formulation = RenewableFullDispatch
#       Loads:
#         device_type = PowerLoad
#         formulation = StaticPowerLoad
#       RenFx:
#         device_type = RenewableFix
#         formulation = RenewableFixed
# ============================================
#   branches:
#       T:
#         device_type = Transformer2W
#         formulation = StaticTransformer
#       TT:
#         device_type = TapTransformer
#         formulation = StaticTransformer
#       L:
#         device_type = Line
#         formulation = StaticLine
#       DC:
#         device_type = HVDCLine
#         formulation = HVDCDispatch
# ============================================
#   services:
#       ReserveDown:
#         service_type = VariableReserve{ReserveDown}
#         formulation = RangeReserve
#       ReserveUp:
#         service_type = VariableReserve{ReserveUp}
#         formulation = RangeReserve
# ============================================

# %% [markdown]
# ### Define the reference model for the real-time economic dispatch

# %%
devices = Dict(
    :Generators => DeviceModel(ThermalStandard, ThermalDispatch),
    :Ren => DeviceModel(RenewableDispatch, RenewableFullDispatch),
    :Loads => DeviceModel(PowerLoad, StaticPowerLoad),
    :HydroROR => DeviceModel(HydroDispatch, HydroDispatchRunOfRiver),
    :RenFx => DeviceModel(RenewableFix, RenewableFixed),
)
template_ed= template_economic_dispatch(devices = devices)
# Out:
# Operations Problem Specification
# ============================================
#
#   transmission:  CopperPlatePowerModel
# ============================================
#   devices:
#       HydroROR:
#         device_type = HydroDispatch
#         formulation = HydroDispatchRunOfRiver
#       Generators:
#         device_type = ThermalStandard
#         formulation = ThermalDispatch
#       Ren:
#         device_type = RenewableDispatch
#         formulation = RenewableFullDispatch
#       Loads:
#         device_type = PowerLoad
#         formulation = StaticPowerLoad
#       RenFx:
#         device_type = RenewableFix
#         formulation = RenewableFixed
# ============================================
#   branches:
#       T:
#         device_type = Transformer2W
#         formulation = StaticTransformer
#       TT:
#         device_type = TapTransformer
#         formulation = StaticTransformer
#       L:
#         device_type = Line
#         formulation = StaticLine
#       DC:
#         device_type = HVDCLine
#         formulation = HVDCDispatch
# ============================================
#   services:
# ============================================

# %% [markdown]
# ### Define the `Stage`s
# Stages define models. The actual problem will change as the stage gets updated to represent
# different time periods, but the formulations applied to the components is constant within
# a stage. In this case, we want to define two stages with the `OperationsProblemTemplate`s
# and the `System`s that we've already created.

# %%
stages_definition = Dict("UC" => Stage(GenericOpProblem, template_uc, sys, solver),
                         "ED" => Stage(GenericOpProblem, template_ed, sys_RT, solver))
# Out:
# Dict{String,Stage{GenericOpProblem}} with 2 entries:
#   "ED" => Stage()…
#   "UC" => Stage()…

# %% [markdown]
# ### `SimulationSequence`
# Similar to an `OperationsProblemTemplate`, the `SimulationSequence` provides a template of
# how to execute a sequential set of operations problems.

# %% [markdown]
# print_struct(SimulationSequence)

# %% [markdown]
# Let's review some of the `SimulationSequence` arguments.

# %% [markdown]
# ### Chrologies
# In PowerSimulations, chronologies define where information is flowing. There are two types
# of chronogies.
#  - inter-stage chronologies: Define how information flows between stages. e.g. day-ahead
# solutions are used to inform economic dispatch problems
#  - intra-stage chronologies: Define how information flows between multiple executions of a
# single stage. e.g. the dispatch setpoints of the first period of an economic dispatch problem
# are constrained by the ramping limits from setpoints in the final period of the previous problem.

# %% [markdown]
# Let's define an inter-stage chronolgy that synchronizes information from 24 periods of
# the first stage with a set of executions of the second stage:

# %%
feedforward_chronologies = Dict(("UC" => "ED") => Synchronize(periods = 24))
# Out:
# Dict{Pair{String,String},Synchronize} with 1 entry:
#   "UC"=>"ED" => Synchronize(24)

# %% [markdown]
# ### `FeedForward` and `Cache`
# The definition of exactly what information is passed using the defined chronologies is
# accomplished with `FeedForward` and `Cache` objects. Specifically, `FeedForward` is used
# to define what to do with information being passed with an inter-stage chronology. Let's
# define a `FeedForward` that affects the semi-continus range constraints of thermal generators
# in the economic dispatch problems based on the value of the unit-commitment variables.

# %%
feedforward = Dict(("ED", :devices, :Generators) => SemiContinuousFF(binary_from_stage = PSI.ON,
                                                         affected_variables = [PSI.ACTIVE_POWER]))
# Out:
# Dict{Tuple{String,Symbol,Symbol},SemiContinuousFF} with 1 entry:
#   ("ED", :devices, :Generators) => SemiContinuousFF(:On, Symbol[:P], nothing)

# %% [markdown]
# The `Cache` is simply a way to preserve needed information for later use. In the case of
# a typical day-ahead - real-time market simulaiton, there are many economic dispatch executions
# in between each unit-commitment execution. Rather than keeping the full set of results from
# previous unit-commitment simulations in memory to be used in later executions, we can define
# exactly which results will be needed and carry them through a cache in the economic dispatch
# problems for later use.

# %%
cache = Dict("UC" => [TimeStatusChange(PSY.ThermalStandard, PSI.ON)])
# Out:
# Dict{String,Array{TimeStatusChange,1}} with 1 entry:
#   "UC" => TimeStatusChange[TimeStatusChange(ThermalStandard, 1-dimensional Dens…

# %% [markdown]
# ### Sequencing
# The stage problem length, look-ahead, and other details surrounding the temporal Sequencing
# of stages are controled using the `order`, `horizons`, and `intervals` arguments.
#  - order::Dictt(Int, String) : the hierarchical order of stages in the simulation
#  - horizons::Dict(String, Int) : defines the number of time periods in each stage (problem length)
#  - intervals::Dict(String, Dates.Period) : defines the interval with which stage problems
# advance after each execution. e.g. day-ahead problems have an interval of 24-hours
#
# So, to define a typical day-ahead - real-time sequence, we can define the following:
#  - Day ahead problems should represent 48 hours, advancing 24 hours after each execution (24-hour look-ahead)
#  - Real time problems should represent 1 hour (12 5-minute periods), advancing 1 hour after each execution (no look-ahead)

# %%
order = Dict(1 => "UC", 2 => "ED")
horizons = Dict("UC" => 24, "ED" =>12)
intervals = Dict("UC" => (Hour(24), Consecutive()),
                 "ED" => (Hour(1), Consecutive()))
# Out:
# Dict{String,Tuple{Hour,Consecutive}} with 2 entries:
#   "ED" => (1 hour, Consecutive())
#   "UC" => (24 hours, Consecutive())

# %% [markdown]
# Finally, we can put it all together:

# %%
DA_RT_sequence = SimulationSequence(step_resolution = Hour(24),
                                    order = order,
                                    horizons = horizons,
                                    intervals = intervals,
                                    ini_cond_chronology = InterStageChronology(),
                                    feedforward_chronologies = feedforward_chronologies,
                                    feedforward = feedforward,
                                    cache = cache,
                                    )
# Out:
# Feed Forward Chronology
# -----------------------
#
# ED: SemiContinuousFF -> Generators
#
#                      UC--┐ from : On
#                          |
# ┌----┬----┬----┬----┬----┼----┬----┬----┬----┬----┬----┐
# |    |    |    |    |    |    |    |    |    |    |    |
# |    |    |    |    |    |    |    |    |    |    |    |
# └─ED └─ED └─ED └─ED └─ED └─ED └─ED └─ED └─ED └─ED └─ED └─ED ... (x24) to : ["P"]
#
# Initial Condition Chronology
# ----------------------------
#
# 1
# |
# |
# 2 --> 2 ... (x24)

# %% [markdown]
# ## `Simulation`
# Now, we can build and executte a simulation using the `SimulationSequence` and `Stage`s
# that we've defined.

# %%
file_path = tempdir()
sim = Simulation(name = "rts-test",
                steps = 1,
                stages = stages_definition,
                stages_sequence = DA_RT_sequence,
                simulation_folder = file_path)
# Out:
# Simulation()

# %% [markdown]
# ### Build simulaiton

# %%
build!(sim)
# Out:
# ┌ Info: Building Stage 2-ED
# └ @ PowerSimulations /Users/cbarrows/.julia/packages/PowerSimulations/TTXVL/src/core/simulation.jl:317
# ┌ Info: Building Stage 1-UC
# └ @ PowerSimulations /Users/cbarrows/.julia/packages/PowerSimulations/TTXVL/src/core/simulation.jl:317
# ┌ Warning: Data doesn't contain generators with ramp limits, consider adjusting your formulation
# └ @ PowerSimulations /Users/cbarrows/.julia/packages/PowerSimulations/TTXVL/src/devices_models/devices/thermal_generation.jl:369
# ┌ Info: Generator 202_CT_2 has a nonbinding time limits. Constraints Skipped
# └ @ PowerSimulations /Users/cbarrows/.julia/packages/PowerSimulations/TTXVL/src/devices_models/devices/thermal_generation.jl:435
# ┌ Info: Generator 302_CT_1 has a nonbinding time limits. Constraints Skipped
# └ @ PowerSimulations /Users/cbarrows/.julia/packages/PowerSimulations/TTXVL/src/devices_models/devices/thermal_generation.jl:435
# ┌ Info: Generator 202_CT_1 has a nonbinding time limits. Constraints Skipped
# └ @ PowerSimulations /Users/cbarrows/.julia/packages/PowerSimulations/TTXVL/src/devices_models/devices/thermal_generation.jl:435
# ┌ Info: Generator 114_SYNC_COND_1 has a nonbinding time limits. Constraints Skipped
# └ @ PowerSimulations /Users/cbarrows/.julia/packages/PowerSimulations/TTXVL/src/devices_models/devices/thermal_generation.jl:435
# ┌ Info: Generator 302_CT_2 has a nonbinding time limits. Constraints Skipped
# └ @ PowerSimulations /Users/cbarrows/.julia/packages/PowerSimulations/TTXVL/src/devices_models/devices/thermal_generation.jl:435
# ┌ Info: Generator 101_CT_1 has a nonbinding time limits. Constraints Skipped
# └ @ PowerSimulations /Users/cbarrows/.julia/packages/PowerSimulations/TTXVL/src/devices_models/devices/thermal_generation.jl:435
# ┌ Info: Generator 314_SYNC_COND_1 has a nonbinding time limits. Constraints Skipped
# └ @ PowerSimulations /Users/cbarrows/.julia/packages/PowerSimulations/TTXVL/src/devices_models/devices/thermal_generation.jl:435
# ┌ Info: Generator 101_CT_2 has a nonbinding time limits. Constraints Skipped
# └ @ PowerSimulations /Users/cbarrows/.julia/packages/PowerSimulations/TTXVL/src/devices_models/devices/thermal_generation.jl:435
# ┌ Info: Generator 214_SYNC_COND_1 has a nonbinding time limits. Constraints Skipped
# └ @ PowerSimulations /Users/cbarrows/.julia/packages/PowerSimulations/TTXVL/src/devices_models/devices/thermal_generation.jl:435
# ┌ Info: Generator 301_CT_1 has a nonbinding time limits. Constraints Skipped
# └ @ PowerSimulations /Users/cbarrows/.julia/packages/PowerSimulations/TTXVL/src/devices_models/devices/thermal_generation.jl:435
# ┌ Info: Generator 102_CT_2 has a nonbinding time limits. Constraints Skipped
# └ @ PowerSimulations /Users/cbarrows/.julia/packages/PowerSimulations/TTXVL/src/devices_models/devices/thermal_generation.jl:435
# ┌ Info: Generator 102_CT_1 has a nonbinding time limits. Constraints Skipped
# └ @ PowerSimulations /Users/cbarrows/.julia/packages/PowerSimulations/TTXVL/src/devices_models/devices/thermal_generation.jl:435
# ┌ Info: Generator 201_CT_2 has a nonbinding time limits. Constraints Skipped
# └ @ PowerSimulations /Users/cbarrows/.julia/packages/PowerSimulations/TTXVL/src/devices_models/devices/thermal_generation.jl:435
# ┌ Info: Generator 201_CT_1 has a nonbinding time limits. Constraints Skipped
# └ @ PowerSimulations /Users/cbarrows/.julia/packages/PowerSimulations/TTXVL/src/devices_models/devices/thermal_generation.jl:435
# ┌ Info: Generator 301_CT_2 has a nonbinding time limits. Constraints Skipped
# └ @ PowerSimulations /Users/cbarrows/.julia/packages/PowerSimulations/TTXVL/src/devices_models/devices/thermal_generation.jl:435
# ┌ Info:
# │  ───────────────────────────────────────────────────────────────────────────
# │                                     Time                   Allocations
# │                             ──────────────────────   ───────────────────────
# │       Tot / % measured:          3.13s / 100%             276MiB / 100%
# │
# │  Section            ncalls     time   %tot     avg     alloc   %tot      avg
# │  ───────────────────────────────────────────────────────────────────────────
# │  Build Simulation        1    3.13s   100%   3.13s    276MiB  100%    276MiB
# │    Build Stage UC        1    1.82s  58.1%   1.82s    172MiB  62.3%   172MiB
# │    Build Stage ED        1    1.18s  37.8%   1.18s   96.7MiB  35.0%  96.7MiB
# │  ───────────────────────────────────────────────────────────────────────────
# └ @ PowerSimulations /Users/cbarrows/.julia/packages/PowerSimulations/TTXVL/src/core/simulation.jl:388

# %% [markdown]
# ### Execute simulation

# %%
sim_results = execute!(sim)
# Out:
# ┌ Info: Serialized time series data to /var/folders/27/2jr8c7gn4j72fvrg4qt81zrw8w_711/T/rts-test/2020-02-27T14-20-00/models_json/stage_ED_model/ED_sys_data_time_series_storage.h5.
# └ @ InfrastructureSystems /Users/cbarrows/.julia/packages/InfrastructureSystems/MfQlN/src/time_series_storage.jl:47
# ┌ Info: Serialized System to /var/folders/27/2jr8c7gn4j72fvrg4qt81zrw8w_711/T/rts-test/2020-02-27T14-20-00/models_json/stage_ED_model/ED_sys_data.json
# └ @ InfrastructureSystems /Users/cbarrows/.julia/packages/InfrastructureSystems/MfQlN/src/serialization.jl:8
# ┌ Info: Serialized time series data to /var/folders/27/2jr8c7gn4j72fvrg4qt81zrw8w_711/T/rts-test/2020-02-27T14-20-00/models_json/stage_UC_model/UC_sys_data_time_series_storage.h5.
# └ @ InfrastructureSystems /Users/cbarrows/.julia/packages/InfrastructureSystems/MfQlN/src/time_series_storage.jl:47
# ┌ Info: Serialized System to /var/folders/27/2jr8c7gn4j72fvrg4qt81zrw8w_711/T/rts-test/2020-02-27T14-20-00/models_json/stage_UC_model/UC_sys_data.json
# └ @ InfrastructureSystems /Users/cbarrows/.julia/packages/InfrastructureSystems/MfQlN/src/serialization.jl:8
# Executing Step 1
# ┌ Info: Starting run step-1-stage-UC 2020-01-01T00:00:00
# └ @ PowerSimulations /Users/cbarrows/.julia/packages/PowerSimulations/TTXVL/src/core/simulation.jl:615
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Oct  7 2019
#
# command line - Cbc_C_Interface -ratioGap 0.5 -logLevel 1 -solve -quit (default strategy 1)
# ratioGap was changed from 0 to 0.5
# Continuous objective value is 1.09972e+06 - 0.47 seconds
# Cgl0003I 46 fixed, 0 tightened bounds, 1150 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 49 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 1104 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 1037 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 928 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 435 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 405 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 371 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 360 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 323 strengthened rows, 0 substitutions
# Cgl0004I processed model has 11678 rows, 23853 columns (5085 integer (5085 of which binary)) and 64353 elements
# Cbc0045I Trying just fixing integer variables (and fixingish SOS).
# Cbc0045I MIPStart solution provided values for 6456 of 5085 integer variables, 111 variables are still fractional.
# Cbc0038I Full problem 11678 rows 23853 columns, reduced to 11674 rows 23853 columns
# Cbc0038I Probing was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Cbc0045I Mini branch and bound defined values for remaining variables in 10.12 seconds.
# Cbc0045I MIPStart provided solution with cost 1.119e+06
# Cbc0012I Integer solution of 1118996.6 found by Reduced search after 0 iterations and 0 nodes (15.47 seconds)
# Cbc0038I Full problem 11678 rows 23853 columns, reduced to 2192 rows 6238 columns
# Cbc0011I Exiting as integer gap of 19276.132 less than 1e-10 or 50%
# Cbc0001I Search completed - best objective 1118996.560103663, took 0 iterations and 0 nodes (16.11 seconds)
# Cbc0035I Maximum depth 0, 0 variables fixed on reduced cost
# Cuts at root node changed objective from 1.09972e+06 to 1.09972e+06
# Probing was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found (within gap tolerance)
#
# Objective value:                1118996.56010366
# Lower bound:                    1099720.429
# Gap:                            0.02
# Enumerated nodes:               0
# Total iterations:               0
# Time (CPU seconds):             16.73
# Time (Wallclock seconds):       20.36
#
# Total time (CPU seconds):       16.73   (Wallclock seconds):       20.36
#
# ┌ Info: JuMP.optimize! completed
# │   timed_log = Dict{Symbol,Any}(:timed_solve_time => 21.656971181,:solve_bytes_alloc => 177757616,:sec_in_gc => 0.0)
# └ @ PowerSimulations /Users/cbarrows/.julia/packages/PowerSimulations/TTXVL/src/core/simulation_stages.jl:105
# ┌ Warning: SolveTime() property not supported by the Solver
# └ @ PowerSimulations /Users/cbarrows/.julia/packages/PowerSimulations/TTXVL/src/core/psi_container.jl:526
# ┌ Info: Starting run step-1-stage-ED 2020-01-01T00:00:00
# └ @ PowerSimulations /Users/cbarrows/.julia/packages/PowerSimulations/TTXVL/src/core/simulation.jl:615
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Oct  7 2019
#
# command line - Cbc_C_Interface -ratioGap 0.5 -logLevel 1 -solve -quit (default strategy 1)
# ratioGap was changed from 0 to 0.5
# Presolve 192 (-3120) rows, 673 (-4343) columns and 673 (-7643) elements
# Perturbing problem by 0.001% of 275.29435 - largest nonzero change 3.0098984e-05 ( 1.3113264e-05%) - largest zero change 0
# 0  Obj 0 Primal inf 110.87981 (192)
# 78  Obj 10895.209 Primal inf 43.799886 (114)
# 156  Obj 16197.386 Primal inf 10.799964 (36)
# 192  Obj 17841.109
# Optimal - objective value 17841.107
# After Postsolve, objective 17841.107, infeasibilities - dual 30584.785 (192), primal 0 (0)
# Presolved model was optimal, full model needs cleaning up
# 0  Obj 17841.107
# Optimal - objective value 17841.107
# Optimal objective 17841.10739 - 192 iterations time 0.012, Presolve 0.01
# Total time (CPU seconds):       0.01   (Wallclock seconds):       0.02
#
# ┌ Info: JuMP.optimize! completed
# │   timed_log = Dict{Symbol,Any}(:timed_solve_time => 0.15000279,:solve_bytes_alloc => 28697584,:sec_in_gc => 0.0)
# └ @ PowerSimulations /Users/cbarrows/.julia/packages/PowerSimulations/TTXVL/src/core/simulation_stages.jl:105
# ┌ Warning: SolveTime() property not supported by the Solver
# └ @ PowerSimulations /Users/cbarrows/.julia/packages/PowerSimulations/TTXVL/src/core/psi_container.jl:526
# ┌ Info: Starting run step-1-stage-ED 2020-01-01T01:00:00
# └ @ PowerSimulations /Users/cbarrows/.julia/packages/PowerSimulations/TTXVL/src/core/simulation.jl:615
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Oct  7 2019
#
# command line - Cbc_C_Interface -ratioGap 0.5 -logLevel 1 -solve -quit (default strategy 1)
# ratioGap was changed from 0 to 0.5
# Presolve 192 (-3120) rows, 673 (-4343) columns and 673 (-7643) elements
# Perturbing problem by 0.001% of 275.29435 - largest nonzero change 3.0098984e-05 ( 1.3113264e-05%) - largest zero change 0
# 0  Obj 0 Primal inf 110.87981 (192)
# 78  Obj 10895.209 Primal inf 43.799886 (114)
# 156  Obj 16197.386 Primal inf 10.799964 (36)
# 192  Obj 17841.109
# Optimal - objective value 17841.107
# After Postsolve, objective 17841.107, infeasibilities - dual 30584.785 (192), primal 0 (0)
# Presolved model was optimal, full model needs cleaning up
# 0  Obj 17841.107
# Optimal - objective value 17841.107
# Optimal objective 17841.10739 - 192 iterations time 0.012, Presolve 0.01
# Total time (CPU seconds):       0.01   (Wallclock seconds):       0.01
#
# ┌ Info: JuMP.optimize! completed
# │   timed_log = Dict{Symbol,Any}(:timed_solve_time => 0.39607768,:solve_bytes_alloc => 36495664,:sec_in_gc => 0.0)
# └ @ PowerSimulations /Users/cbarrows/.julia/packages/PowerSimulations/TTXVL/src/core/simulation_stages.jl:105
# ┌ Warning: SolveTime() property not supported by the Solver
# └ @ PowerSimulations /Users/cbarrows/.julia/packages/PowerSimulations/TTXVL/src/core/psi_container.jl:526
# ┌ Info: Starting run step-1-stage-ED 2020-01-01T02:00:00
# └ @ PowerSimulations /Users/cbarrows/.julia/packages/PowerSimulations/TTXVL/src/core/simulation.jl:615
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Oct  7 2019
#
# command line - Cbc_C_Interface -ratioGap 0.5 -logLevel 1 -solve -quit (default strategy 1)
# ratioGap was changed from 0 to 0.5
# Presolve 192 (-3120) rows, 673 (-4343) columns and 673 (-7643) elements
# Perturbing problem by 0.001% of 275.29435 - largest nonzero change 3.0098984e-05 ( 1.3113264e-05%) - largest zero change 0
# 0  Obj 0 Primal inf 110.87981 (192)
# 78  Obj 10895.209 Primal inf 43.799886 (114)
# 156  Obj 16197.386 Primal inf 10.799964 (36)
# 192  Obj 17841.109
# Optimal - objective value 17841.107
# After Postsolve, objective 17841.107, infeasibilities - dual 30584.785 (192), primal 0 (0)
# Presolved model was optimal, full model needs cleaning up
# 0  Obj 17841.107
# Optimal - objective value 17841.107
# Optimal objective 17841.10739 - 192 iterations time 0.012, Presolve 0.01
# Total time (CPU seconds):       0.01   (Wallclock seconds):       0.01
#
# ┌ Info: JuMP.optimize! completed
# │   timed_log = Dict{Symbol,Any}(:timed_solve_time => 0.073713193,:solve_bytes_alloc => 15456576,:sec_in_gc => 0.0)
# └ @ PowerSimulations /Users/cbarrows/.julia/packages/PowerSimulations/TTXVL/src/core/simulation_stages.jl:105
# ┌ Warning: SolveTime() property not supported by the Solver
# └ @ PowerSimulations /Users/cbarrows/.julia/packages/PowerSimulations/TTXVL/src/core/psi_container.jl:526
# ┌ Info: Starting run step-1-stage-ED 2020-01-01T03:00:00
# └ @ PowerSimulations /Users/cbarrows/.julia/packages/PowerSimulations/TTXVL/src/core/simulation.jl:615
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Oct  7 2019
#
# command line - Cbc_C_Interface -ratioGap 0.5 -logLevel 1 -solve -quit (default strategy 1)
# ratioGap was changed from 0 to 0.5
# Presolve 192 (-3120) rows, 673 (-4343) columns and 673 (-7643) elements
# Perturbing problem by 0.001% of 275.29435 - largest nonzero change 3.0098984e-05 ( 1.3113264e-05%) - largest zero change 0
# 0  Obj 0 Primal inf 110.87981 (192)
# 78  Obj 10895.209 Primal inf 43.799886 (114)
# 156  Obj 16197.386 Primal inf 10.799964 (36)
# 192  Obj 17841.109
# Optimal - objective value 17841.107
# After Postsolve, objective 17841.107, infeasibilities - dual 30584.785 (192), primal 0 (0)
# Presolved model was optimal, full model needs cleaning up
# 0  Obj 17841.107
# Optimal - objective value 17841.107
# Optimal objective 17841.10739 - 192 iterations time 0.012, Presolve 0.01
# Total time (CPU seconds):       0.01   (Wallclock seconds):       0.01
#
# ┌ Info: JuMP.optimize! completed
# │   timed_log = Dict{Symbol,Any}(:timed_solve_time => 0.08365262,:solve_bytes_alloc => 15457360,:sec_in_gc => 0.0)
# └ @ PowerSimulations /Users/cbarrows/.julia/packages/PowerSimulations/TTXVL/src/core/simulation_stages.jl:105
# ┌ Warning: SolveTime() property not supported by the Solver
# └ @ PowerSimulations /Users/cbarrows/.julia/packages/PowerSimulations/TTXVL/src/core/psi_container.jl:526
# ┌ Info: Starting run step-1-stage-ED 2020-01-01T04:00:00
# └ @ PowerSimulations /Users/cbarrows/.julia/packages/PowerSimulations/TTXVL/src/core/simulation.jl:615
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Oct  7 2019
#
# command line - Cbc_C_Interface -ratioGap 0.5 -logLevel 1 -solve -quit (default strategy 1)
# ratioGap was changed from 0 to 0.5
# Presolve 192 (-3120) rows, 673 (-4343) columns and 673 (-7643) elements
# Perturbing problem by 0.001% of 275.29435 - largest nonzero change 3.0098984e-05 ( 1.3113264e-05%) - largest zero change 0
# 0  Obj 0 Primal inf 110.87981 (192)
# 78  Obj 10895.209 Primal inf 43.799886 (114)
# 156  Obj 16197.386 Primal inf 10.799964 (36)
# 192  Obj 17841.109
# Optimal - objective value 17841.107
# After Postsolve, objective 17841.107, infeasibilities - dual 30584.785 (192), primal 0 (0)
# Presolved model was optimal, full model needs cleaning up
# 0  Obj 17841.107
# Optimal - objective value 17841.107
# Optimal objective 17841.10739 - 192 iterations time 0.012, Presolve 0.00
# Total time (CPU seconds):       0.01   (Wallclock seconds):       0.01
#
# ┌ Info: JuMP.optimize! completed
# │   timed_log = Dict{Symbol,Any}(:timed_solve_time => 0.073194622,:solve_bytes_alloc => 15456576,:sec_in_gc => 0.0)
# └ @ PowerSimulations /Users/cbarrows/.julia/packages/PowerSimulations/TTXVL/src/core/simulation_stages.jl:105
# ┌ Warning: SolveTime() property not supported by the Solver
# └ @ PowerSimulations /Users/cbarrows/.julia/packages/PowerSimulations/TTXVL/src/core/psi_container.jl:526
# ┌ Info: Starting run step-1-stage-ED 2020-01-01T05:00:00
# └ @ PowerSimulations /Users/cbarrows/.julia/packages/PowerSimulations/TTXVL/src/core/simulation.jl:615
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Oct  7 2019
#
# command line - Cbc_C_Interface -ratioGap 0.5 -logLevel 1 -solve -quit (default strategy 1)
# ratioGap was changed from 0 to 0.5
# Presolve 204 (-3108) rows, 721 (-4295) columns and 721 (-7595) elements
# Perturbing problem by 0.001% of 275.29435 - largest nonzero change 3.0472167e-05 ( 1.3113264e-05%) - largest zero change 0
# 0  Obj 0 Primal inf 113.5198 (204)
# 79  Obj 11032.611 Primal inf 45.819875 (125)
# 158  Obj 16349.398 Primal inf 12.839954 (46)
# 204  Obj 18354.479
# Optimal - objective value 18354.477
# After Postsolve, objective 18354.477, infeasibilities - dual 32918.283 (204), primal 0 (0)
# Presolved model was optimal, full model needs cleaning up
# 0  Obj 18354.477
# Optimal - objective value 18354.477
# Optimal objective 18354.47699 - 204 iterations time 0.012, Presolve 0.00
# Total time (CPU seconds):       0.01   (Wallclock seconds):       0.01
#
# ┌ Info: JuMP.optimize! completed
# │   timed_log = Dict{Symbol,Any}(:timed_solve_time => 0.225677463,:solve_bytes_alloc => 23214503,:sec_in_gc => 0.0)
# └ @ PowerSimulations /Users/cbarrows/.julia/packages/PowerSimulations/TTXVL/src/core/simulation_stages.jl:105
# ┌ Warning: SolveTime() property not supported by the Solver
# └ @ PowerSimulations /Users/cbarrows/.julia/packages/PowerSimulations/TTXVL/src/core/psi_container.jl:526
# ┌ Info: Starting run step-1-stage-ED 2020-01-01T06:00:00
# └ @ PowerSimulations /Users/cbarrows/.julia/packages/PowerSimulations/TTXVL/src/core/simulation.jl:615
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Oct  7 2019
#
# command line - Cbc_C_Interface -ratioGap 0.5 -logLevel 1 -solve -quit (default strategy 1)
# ratioGap was changed from 0 to 0.5
# Presolve 216 (-3096) rows, 768 (-4248) columns and 768 (-7548) elements
# Perturbing problem by 0.001% of 878.06035 - largest nonzero change 9.6431411e-05 ( 1.7982675e-05%) - largest zero change 0
# 0  Obj 0 Primal inf 114.47978 (216)
# 79  Obj 10997.573 Primal inf 46.779863 (137)
# 158  Obj 16398.755 Primal inf 13.799942 (58)
# 216  Obj 19052.526
# Optimal - objective value 19052.523
# After Postsolve, objective 19052.523, infeasibilities - dual 41643.862 (216), primal 0 (0)
# Presolved model was optimal, full model needs cleaning up
# 0  Obj 19052.523
# Optimal - objective value 19052.523
# Optimal objective 19052.52332 - 216 iterations time 0.012, Presolve 0.01
# Total time (CPU seconds):       0.01   (Wallclock seconds):       0.01
#
# ┌ Info: JuMP.optimize! completed
# │   timed_log = Dict{Symbol,Any}(:timed_solve_time => 0.624477683,:solve_bytes_alloc => 15460160,:sec_in_gc => 0.528318322)
# └ @ PowerSimulations /Users/cbarrows/.julia/packages/PowerSimulations/TTXVL/src/core/simulation_stages.jl:105
# ┌ Warning: SolveTime() property not supported by the Solver
# └ @ PowerSimulations /Users/cbarrows/.julia/packages/PowerSimulations/TTXVL/src/core/psi_container.jl:526
# ┌ Info: Starting run step-1-stage-ED 2020-01-01T07:00:00
# └ @ PowerSimulations /Users/cbarrows/.julia/packages/PowerSimulations/TTXVL/src/core/simulation.jl:615
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Oct  7 2019
#
# command line - Cbc_C_Interface -ratioGap 0.5 -logLevel 1 -solve -quit (default strategy 1)
# ratioGap was changed from 0 to 0.5
# Presolve 204 (-3108) rows, 720 (-4296) columns and 720 (-7596) elements
# Perturbing problem by 0.001% of 275.29435 - largest nonzero change 3.0227331e-05 ( 1.2965996e-05%) - largest zero change 0
# 0  Obj 0 Primal inf 113.5198 (204)
# 79  Obj 11032.611 Primal inf 45.819875 (125)
# 158  Obj 16356.031 Primal inf 12.839954 (46)
# 204  Obj 18354.479
# Optimal - objective value 18354.477
# After Postsolve, objective 18354.477, infeasibilities - dual 32918.283 (204), primal 0 (0)
# Presolved model was optimal, full model needs cleaning up
# 0  Obj 18354.477
# Optimal - objective value 18354.477
# Optimal objective 18354.47699 - 204 iterations time 0.012, Presolve 0.01
# Total time (CPU seconds):       0.01   (Wallclock seconds):       0.01
#
# ┌ Info: JuMP.optimize! completed
# │   timed_log = Dict{Symbol,Any}(:timed_solve_time => 0.080080905,:solve_bytes_alloc => 15483232,:sec_in_gc => 0.0)
# └ @ PowerSimulations /Users/cbarrows/.julia/packages/PowerSimulations/TTXVL/src/core/simulation_stages.jl:105
# ┌ Warning: SolveTime() property not supported by the Solver
# └ @ PowerSimulations /Users/cbarrows/.julia/packages/PowerSimulations/TTXVL/src/core/psi_container.jl:526
# ┌ Info: Starting run step-1-stage-ED 2020-01-01T08:00:00
# └ @ PowerSimulations /Users/cbarrows/.julia/packages/PowerSimulations/TTXVL/src/core/simulation.jl:615
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Oct  7 2019
#
# command line - Cbc_C_Interface -ratioGap 0.5 -logLevel 1 -solve -quit (default strategy 1)
# ratioGap was changed from 0 to 0.5
# Presolve 192 (-3120) rows, 672 (-4344) columns and 672 (-7644) elements
# Perturbing problem by 0.001% of 275.29435 - largest nonzero change 3.0098984e-05 ( 1.3026813e-05%) - largest zero change 0
# 0  Obj 0 Primal inf 110.87981 (192)
# 78  Obj 10908.01 Primal inf 43.799886 (114)
# 156  Obj 16197.386 Primal inf 10.799964 (36)
# 192  Obj 17841.109
# Optimal - objective value 17841.107
# After Postsolve, objective 17841.107, infeasibilities - dual 30584.785 (192), primal 0 (0)
# Presolved model was optimal, full model needs cleaning up
# 0  Obj 17841.107
# Optimal - objective value 17841.107
# Optimal objective 17841.10739 - 192 iterations time 0.012, Presolve 0.01
# Total time (CPU seconds):       0.01   (Wallclock seconds):       0.01
#
# ┌ Info: JuMP.optimize! completed
# │   timed_log = Dict{Symbol,Any}(:timed_solve_time => 0.074731088,:solve_bytes_alloc => 15493984,:sec_in_gc => 0.0)
# └ @ PowerSimulations /Users/cbarrows/.julia/packages/PowerSimulations/TTXVL/src/core/simulation_stages.jl:105
# ┌ Warning: SolveTime() property not supported by the Solver
# └ @ PowerSimulations /Users/cbarrows/.julia/packages/PowerSimulations/TTXVL/src/core/psi_container.jl:526
# ┌ Info: Starting run step-1-stage-ED 2020-01-01T09:00:00
# └ @ PowerSimulations /Users/cbarrows/.julia/packages/PowerSimulations/TTXVL/src/core/simulation.jl:615
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Oct  7 2019
#
# command line - Cbc_C_Interface -ratioGap 0.5 -logLevel 1 -solve -quit (default strategy 1)
# ratioGap was changed from 0 to 0.5
# Presolve 192 (-3120) rows, 672 (-4344) columns and 672 (-7644) elements
# Perturbing problem by 0.001% of 275.29435 - largest nonzero change 3.0098984e-05 ( 1.3026813e-05%) - largest zero change 0
# 0  Obj 0 Primal inf 110.87981 (192)
# 78  Obj 10908.01 Primal inf 43.799886 (114)
# 156  Obj 16197.386 Primal inf 10.799964 (36)
# 192  Obj 17841.109
# Optimal - objective value 17841.107
# After Postsolve, objective 17841.107, infeasibilities - dual 30584.785 (192), primal 0 (0)
# Presolved model was optimal, full model needs cleaning up
# 0  Obj 17841.107
# Optimal - objective value 17841.107
# Optimal objective 17841.10739 - 192 iterations time 0.012, Presolve 0.01
# Total time (CPU seconds):       0.01   (Wallclock seconds):       0.01
#
# ┌ Info: JuMP.optimize! completed
# │   timed_log = Dict{Symbol,Any}(:timed_solve_time => 0.072865152,:solve_bytes_alloc => 15483792,:sec_in_gc => 0.0)
# └ @ PowerSimulations /Users/cbarrows/.julia/packages/PowerSimulations/TTXVL/src/core/simulation_stages.jl:105
# ┌ Warning: SolveTime() property not supported by the Solver
# └ @ PowerSimulations /Users/cbarrows/.julia/packages/PowerSimulations/TTXVL/src/core/psi_container.jl:526
# ┌ Info: Starting run step-1-stage-ED 2020-01-01T10:00:00
# └ @ PowerSimulations /Users/cbarrows/.julia/packages/PowerSimulations/TTXVL/src/core/simulation.jl:615
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Oct  7 2019
#
# command line - Cbc_C_Interface -ratioGap 0.5 -logLevel 1 -solve -quit (default strategy 1)
# ratioGap was changed from 0 to 0.5
# Presolve 192 (-3120) rows, 672 (-4344) columns and 672 (-7644) elements
# Perturbing problem by 0.001% of 275.29435 - largest nonzero change 3.0098984e-05 ( 1.3026813e-05%) - largest zero change 0
# 0  Obj 0 Primal inf 110.87981 (192)
# 78  Obj 10908.01 Primal inf 43.799886 (114)
# 156  Obj 16197.386 Primal inf 10.799964 (36)
# 192  Obj 17841.109
# Optimal - objective value 17841.107
# After Postsolve, objective 17841.107, infeasibilities - dual 30584.785 (192), primal 0 (0)
# Presolved model was optimal, full model needs cleaning up
# 0  Obj 17841.107
# Optimal - objective value 17841.107
# Optimal objective 17841.10739 - 192 iterations time 0.012, Presolve 0.01
# Total time (CPU seconds):       0.01   (Wallclock seconds):       0.01
#
# ┌ Info: JuMP.optimize! completed
# │   timed_log = Dict{Symbol,Any}(:timed_solve_time => 0.156032841,:solve_bytes_alloc => 15484912,:sec_in_gc => 0.0)
# └ @ PowerSimulations /Users/cbarrows/.julia/packages/PowerSimulations/TTXVL/src/core/simulation_stages.jl:105
# ┌ Warning: SolveTime() property not supported by the Solver
# └ @ PowerSimulations /Users/cbarrows/.julia/packages/PowerSimulations/TTXVL/src/core/psi_container.jl:526
# ┌ Info: Starting run step-1-stage-ED 2020-01-01T11:00:00
# └ @ PowerSimulations /Users/cbarrows/.julia/packages/PowerSimulations/TTXVL/src/core/simulation.jl:615
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Oct  7 2019
#
# command line - Cbc_C_Interface -ratioGap 0.5 -logLevel 1 -solve -quit (default strategy 1)
# ratioGap was changed from 0 to 0.5
# Presolve 196 (-3116) rows, 737 (-4279) columns and 801 (-7515) elements
# Perturbing problem by 0.001% of 275.29435 - largest nonzero change 3.0430128e-05 ( 1.3113264e-05%) - largest zero change 3.021794e-05
# 0  Obj 0.00075914205 Primal inf 113.38951 (196)
# 78  Obj 10397.206 Primal inf 51.952916 (124)
# 156  Obj 15997.188 Primal inf 16.525697 (57)
# 217  Obj 18175.415
# Optimal - objective value 18175.413
# After Postsolve, objective 18175.413, infeasibilities - dual 48029.641 (327), primal 0 (0)
# Presolved model was optimal, full model needs cleaning up
# 0  Obj 18175.413
# Optimal - objective value 18175.413
# Optimal objective 18175.41289 - 217 iterations time 0.012, Presolve 0.01
# Total time (CPU seconds):       0.01   (Wallclock seconds):       0.01
#
# ┌ Info: JuMP.optimize! completed
# │   timed_log = Dict{Symbol,Any}(:timed_solve_time => 0.073292486,:solve_bytes_alloc => 15483680,:sec_in_gc => 0.0)
# └ @ PowerSimulations /Users/cbarrows/.julia/packages/PowerSimulations/TTXVL/src/core/simulation_stages.jl:105
# ┌ Warning: SolveTime() property not supported by the Solver
# └ @ PowerSimulations /Users/cbarrows/.julia/packages/PowerSimulations/TTXVL/src/core/psi_container.jl:526
# ┌ Info: Starting run step-1-stage-ED 2020-01-01T12:00:00
# └ @ PowerSimulations /Users/cbarrows/.julia/packages/PowerSimulations/TTXVL/src/core/simulation.jl:615
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Oct  7 2019
#
# command line - Cbc_C_Interface -ratioGap 0.5 -logLevel 1 -solve -quit (default strategy 1)
# ratioGap was changed from 0 to 0.5
# Presolve 204 (-3108) rows, 864 (-4152) columns and 1056 (-7260) elements
# Perturbing problem by 0.001% of 275.29435 - largest nonzero change 2.8475265e-05 ( 1.2860614e-05%) - largest zero change 2.8285383e-05
# 0  Obj 0.00219612 Primal inf 148.89889 (204)
# 79  Obj 4452.9989 Primal inf 158.14558 (176)
# 158  Obj 16344.885 Primal inf 91.718968 (121)
# 237  Obj 23435.93 Primal inf 36.378919 (55)
# 297  Obj 23614.699
# Optimal - objective value 23614.694
# After Postsolve, objective 23614.694, infeasibilities - dual 94964.606 (588), primal 0 (0)
# Presolved model was optimal, full model needs cleaning up
# 0  Obj 23614.694
# Optimal - objective value 23614.694
# Optimal objective 23614.69371 - 297 iterations time 0.012, Presolve 0.00
# Total time (CPU seconds):       0.01   (Wallclock seconds):       0.01
#
# ┌ Info: JuMP.optimize! completed
# │   timed_log = Dict{Symbol,Any}(:timed_solve_time => 0.068713118,:solve_bytes_alloc => 15483344,:sec_in_gc => 0.0)
# └ @ PowerSimulations /Users/cbarrows/.julia/packages/PowerSimulations/TTXVL/src/core/simulation_stages.jl:105
# ┌ Warning: SolveTime() property not supported by the Solver
# └ @ PowerSimulations /Users/cbarrows/.julia/packages/PowerSimulations/TTXVL/src/core/psi_container.jl:526
# ┌ Info: Starting run step-1-stage-ED 2020-01-01T13:00:00
# └ @ PowerSimulations /Users/cbarrows/.julia/packages/PowerSimulations/TTXVL/src/core/simulation.jl:615
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Oct  7 2019
#
# command line - Cbc_C_Interface -ratioGap 0.5 -logLevel 1 -solve -quit (default strategy 1)
# ratioGap was changed from 0 to 0.5
# Presolve 204 (-3108) rows, 864 (-4152) columns and 1056 (-7260) elements
# Perturbing problem by 0.001% of 275.29435 - largest nonzero change 2.8475265e-05 ( 1.2860614e-05%) - largest zero change 2.8285383e-05
# 0  Obj 0.00219612 Primal inf 173.04949 (204)
# 79  Obj 5788.4388 Primal inf 172.84258 (172)
# 158  Obj 20026.925 Primal inf 113.27872 (127)
# 237  Obj 26434.787 Primal inf 46.834117 (57)
# 312  Obj 27618.977
# Optimal - objective value 27618.971
# After Postsolve, objective 27618.971, infeasibilities - dual 100407.16 (588), primal 0 (0)
# Presolved model was optimal, full model needs cleaning up
# 0  Obj 27618.971
# Optimal - objective value 27618.971
# Optimal objective 27618.9706 - 312 iterations time 0.012, Presolve 0.00
# Total time (CPU seconds):       0.01   (Wallclock seconds):       0.01
#
# ┌ Info: JuMP.optimize! completed
# │   timed_log = Dict{Symbol,Any}(:timed_solve_time => 0.074617695,:solve_bytes_alloc => 15490624,:sec_in_gc => 0.0)
# └ @ PowerSimulations /Users/cbarrows/.julia/packages/PowerSimulations/TTXVL/src/core/simulation_stages.jl:105
# ┌ Warning: SolveTime() property not supported by the Solver
# └ @ PowerSimulations /Users/cbarrows/.julia/packages/PowerSimulations/TTXVL/src/core/psi_container.jl:526
# ┌ Info: Starting run step-1-stage-ED 2020-01-01T14:00:00
# └ @ PowerSimulations /Users/cbarrows/.julia/packages/PowerSimulations/TTXVL/src/core/simulation.jl:615
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Oct  7 2019
#
# command line - Cbc_C_Interface -ratioGap 0.5 -logLevel 1 -solve -quit (default strategy 1)
# ratioGap was changed from 0 to 0.5
# Presolve 204 (-3108) rows, 864 (-4152) columns and 1056 (-7260) elements
# Perturbing problem by 0.001% of 275.29435 - largest nonzero change 2.8475265e-05 ( 1.2860614e-05%) - largest zero change 2.8285383e-05
# 0  Obj 0.00219612 Primal inf 180.96334 (204)
# 79  Obj 5586.9099 Primal inf 181.54029 (174)
# 158  Obj 20595.36 Primal inf 118.96435 (121)
# 237  Obj 27309.012 Primal inf 48.203528 (60)
# 316  Obj 28964.937
# Optimal - objective value 28964.931
# After Postsolve, objective 28964.931, infeasibilities - dual 101779.67 (588), primal 0 (0)
# Presolved model was optimal, full model needs cleaning up
# 0  Obj 28964.931
# Optimal - objective value 28964.931
# Optimal objective 28964.93115 - 316 iterations time 0.012, Presolve 0.00
# Total time (CPU seconds):       0.01   (Wallclock seconds):       0.01
#
# ┌ Info: JuMP.optimize! completed
# │   timed_log = Dict{Symbol,Any}(:timed_solve_time => 0.069892253,:solve_bytes_alloc => 15477296,:sec_in_gc => 0.0)
# └ @ PowerSimulations /Users/cbarrows/.julia/packages/PowerSimulations/TTXVL/src/core/simulation_stages.jl:105
# ┌ Warning: SolveTime() property not supported by the Solver
# └ @ PowerSimulations /Users/cbarrows/.julia/packages/PowerSimulations/TTXVL/src/core/psi_container.jl:526
# ┌ Info: Starting run step-1-stage-ED 2020-01-01T15:00:00
# └ @ PowerSimulations /Users/cbarrows/.julia/packages/PowerSimulations/TTXVL/src/core/simulation.jl:615
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Oct  7 2019
#
# command line - Cbc_C_Interface -ratioGap 0.5 -logLevel 1 -solve -quit (default strategy 1)
# ratioGap was changed from 0 to 0.5
# Presolve 216 (-3096) rows, 912 (-4104) columns and 1116 (-7200) elements
# Perturbing problem by 0.001% of 275.29435 - largest nonzero change 3.0948699e-05 ( 1.2860614e-05%) - largest zero change 3.0828844e-05
# 0  Obj 827.82525 Primal inf 205.9922 (216)
# 79  Obj 8557.1971 Primal inf 194.55183 (182)
# 158  Obj 24293.816 Primal inf 121.45431 (128)
# 237  Obj 30984.404 Primal inf 51.520905 (72)
# 316  Obj 34455.044 Primal inf 7.4927557 (17)
# 337  Obj 34465.486
# Optimal - objective value 34465.478
# After Postsolve, objective 34465.478, infeasibilities - dual 103339.14 (588), primal 0 (0)
# Presolved model was optimal, full model needs cleaning up
# 0  Obj 34465.478
# Optimal - objective value 34465.478
# Optimal objective 34465.47827 - 337 iterations time 0.012, Presolve 0.01
# Total time (CPU seconds):       0.01   (Wallclock seconds):       0.02
#
# ┌ Info: JuMP.optimize! completed
# │   timed_log = Dict{Symbol,Any}(:timed_solve_time => 0.082130312,:solve_bytes_alloc => 15481104,:sec_in_gc => 0.0)
# └ @ PowerSimulations /Users/cbarrows/.julia/packages/PowerSimulations/TTXVL/src/core/simulation_stages.jl:105
# ┌ Warning: SolveTime() property not supported by the Solver
# └ @ PowerSimulations /Users/cbarrows/.julia/packages/PowerSimulations/TTXVL/src/core/psi_container.jl:526
# ┌ Info: Starting run step-1-stage-ED 2020-01-01T16:00:00
# └ @ PowerSimulations /Users/cbarrows/.julia/packages/PowerSimulations/TTXVL/src/core/simulation.jl:615
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Oct  7 2019
#
# command line - Cbc_C_Interface -ratioGap 0.5 -logLevel 1 -solve -quit (default strategy 1)
# ratioGap was changed from 0 to 0.5
# Presolve 252 (-3060) rows, 1092 (-3924) columns and 1332 (-6984) elements
# Perturbing problem by 0.001% of 301.0328 - largest nonzero change 3.2084216e-05 ( 1.327102e-05%) - largest zero change 3.2051146e-05
# 0  Obj 827.82671 Primal inf 291.61349 (252)
# 80  Obj 12644.309 Primal inf 280.10542 (216)
# 160  Obj 27275.024 Primal inf 171.87644 (156)
# 240  Obj 40352.118 Primal inf 92.611502 (109)
# 320  Obj 47869.181 Primal inf 32.055581 (47)
# 382  Obj 48922.875
# Optimal - objective value 48922.864
# After Postsolve, objective 48922.864, infeasibilities - dual 69172.642 (385), primal 0 (0)
# Presolved model was optimal, full model needs cleaning up
# 0  Obj 48922.864
# Optimal - objective value 48922.864
# Optimal objective 48922.86384 - 382 iterations time 0.012, Presolve 0.00
# Total time (CPU seconds):       0.01   (Wallclock seconds):       0.01
#
# ┌ Info: JuMP.optimize! completed
# │   timed_log = Dict{Symbol,Any}(:timed_solve_time => 0.074995104,:solve_bytes_alloc => 15500144,:sec_in_gc => 0.0)
# └ @ PowerSimulations /Users/cbarrows/.julia/packages/PowerSimulations/TTXVL/src/core/simulation_stages.jl:105
# ┌ Warning: SolveTime() property not supported by the Solver
# └ @ PowerSimulations /Users/cbarrows/.julia/packages/PowerSimulations/TTXVL/src/core/psi_container.jl:526
# ┌ Info: Starting run step-1-stage-ED 2020-01-01T17:00:00
# └ @ PowerSimulations /Users/cbarrows/.julia/packages/PowerSimulations/TTXVL/src/core/simulation.jl:615
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Oct  7 2019
#
# command line - Cbc_C_Interface -ratioGap 0.5 -logLevel 1 -solve -quit (default strategy 1)
# ratioGap was changed from 0 to 0.5
# Presolve 288 (-3024) rows, 1272 (-3744) columns and 1548 (-6768) elements
# Perturbing problem by 0.001% of 892.80824 - largest nonzero change 9.7657937e-05 ( 1.8378076e-05%) - largest zero change 9.7330404e-05
# 0  Obj 827.83606 Primal inf 342.92802 (288)
# 80  Obj 13724.212 Primal inf 298.67987 (242)
# 160  Obj 33204.295 Primal inf 187.05371 (203)
# 240  Obj 45801.899 Primal inf 102.71747 (155)
# 320  Obj 54680.854 Primal inf 47.668157 (83)
# 400  Obj 58096.813 Primal inf 7.0722695 (28)
# 432  Obj 59871.659
# Optimal - objective value 59871.628
# After Postsolve, objective 59871.628, infeasibilities - dual 55709.391 (288), primal 0 (0)
# Presolved model was optimal, full model needs cleaning up
# 0  Obj 59871.628
# Optimal - objective value 59871.628
# Optimal objective 59871.62765 - 432 iterations time 0.012, Presolve 0.00
# Total time (CPU seconds):       0.01   (Wallclock seconds):       0.01
#
# ┌ Info: JuMP.optimize! completed
# │   timed_log = Dict{Symbol,Any}(:timed_solve_time => 0.074868221,:solve_bytes_alloc => 15475616,:sec_in_gc => 0.0)
# └ @ PowerSimulations /Users/cbarrows/.julia/packages/PowerSimulations/TTXVL/src/core/simulation_stages.jl:105
# ┌ Warning: SolveTime() property not supported by the Solver
# └ @ PowerSimulations /Users/cbarrows/.julia/packages/PowerSimulations/TTXVL/src/core/psi_container.jl:526
# ┌ Info: Starting run step-1-stage-ED 2020-01-01T18:00:00
# └ @ PowerSimulations /Users/cbarrows/.julia/packages/PowerSimulations/TTXVL/src/core/simulation.jl:615
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Oct  7 2019
#
# command line - Cbc_C_Interface -ratioGap 0.5 -logLevel 1 -solve -quit (default strategy 1)
# ratioGap was changed from 0 to 0.5
# Presolve 264 (-3048) rows, 1155 (-3861) columns and 1407 (-6909) elements
# Perturbing problem by 0.001% of 364.52406 - largest nonzero change 4.088209e-05 ( 1.3763107e-05%) - largest zero change 4.0841327e-05
# 0  Obj 827.82807 Primal inf 339.1342 (264)
# 80  Obj 13717.219 Primal inf 330.32175 (226)
# 160  Obj 34747.347 Primal inf 178.36962 (171)
# 240  Obj 46473.08 Primal inf 89.350425 (124)
# 320  Obj 56277.823 Primal inf 41.770025 (49)
# 389  Obj 57940.701
# Optimal - objective value 57940.686
# After Postsolve, objective 57940.686, infeasibilities - dual 55462.313 (288), primal 0 (0)
# Presolved model was optimal, full model needs cleaning up
# 0  Obj 57940.686
# Optimal - objective value 57940.686
# Optimal objective 57940.68579 - 389 iterations time 0.012, Presolve 0.01
# Total time (CPU seconds):       0.01   (Wallclock seconds):       0.01
#
# ┌ Info: JuMP.optimize! completed
# │   timed_log = Dict{Symbol,Any}(:timed_solve_time => 0.074283145,:solve_bytes_alloc => 15463856,:sec_in_gc => 0.0)
# └ @ PowerSimulations /Users/cbarrows/.julia/packages/PowerSimulations/TTXVL/src/core/simulation_stages.jl:105
# ┌ Warning: SolveTime() property not supported by the Solver
# └ @ PowerSimulations /Users/cbarrows/.julia/packages/PowerSimulations/TTXVL/src/core/psi_container.jl:526
# ┌ Info: Starting run step-1-stage-ED 2020-01-01T19:00:00
# └ @ PowerSimulations /Users/cbarrows/.julia/packages/PowerSimulations/TTXVL/src/core/simulation.jl:615
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Oct  7 2019
#
# command line - Cbc_C_Interface -ratioGap 0.5 -logLevel 1 -solve -quit (default strategy 1)
# ratioGap was changed from 0 to 0.5
# Presolve 264 (-3048) rows, 1153 (-3863) columns and 1405 (-6911) elements
# Perturbing problem by 0.001% of 878.06035 - largest nonzero change 9.6554028e-05 ( 1.8194211e-05%) - largest zero change 9.5884587e-05
# 0  Obj 827.83469 Primal inf 316.84811 (264)
# 80  Obj 19088.831 Primal inf 256.88183 (218)
# 160  Obj 37200.221 Primal inf 150.31207 (156)
# 240  Obj 48084.634 Primal inf 67.671119 (97)
# 320  Obj 54868.428 Primal inf 22.802083 (34)
# 358  Obj 55880.588
# Optimal - objective value 55880.559
# After Postsolve, objective 55880.559, infeasibilities - dual 55871.746 (288), primal 0 (0)
# Presolved model was optimal, full model needs cleaning up
# 0  Obj 55880.559
# Optimal - objective value 55880.559
# Optimal objective 55880.55946 - 358 iterations time 0.012, Presolve 0.00
# Total time (CPU seconds):       0.01   (Wallclock seconds):       0.01
#
# ┌ Info: JuMP.optimize! completed
# │   timed_log = Dict{Symbol,Any}(:timed_solve_time => 0.112864246,:solve_bytes_alloc => 15463856,:sec_in_gc => 0.0)
# └ @ PowerSimulations /Users/cbarrows/.julia/packages/PowerSimulations/TTXVL/src/core/simulation_stages.jl:105
# ┌ Warning: SolveTime() property not supported by the Solver
# └ @ PowerSimulations /Users/cbarrows/.julia/packages/PowerSimulations/TTXVL/src/core/psi_container.jl:526
# ┌ Info: Starting run step-1-stage-ED 2020-01-01T20:00:00
# └ @ PowerSimulations /Users/cbarrows/.julia/packages/PowerSimulations/TTXVL/src/core/simulation.jl:615
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Oct  7 2019
#
# command line - Cbc_C_Interface -ratioGap 0.5 -logLevel 1 -solve -quit (default strategy 1)
# ratioGap was changed from 0 to 0.5
# Presolve 204 (-3108) rows, 877 (-4139) columns and 1069 (-7247) elements
# Perturbing problem by 0.001% of 301.0328 - largest nonzero change 3.3303458e-05 ( 1.3335254e-05%) - largest zero change 3.2943149e-05
# 0  Obj 827.82601 Primal inf 286.19437 (204)
# 79  Obj 16979.427 Primal inf 254.31819 (166)
# 158  Obj 36808.916 Primal inf 110.88303 (109)
# 237  Obj 46932.943 Primal inf 39.288512 (45)
# 286  Obj 49755.791
# Optimal - objective value 49755.78
# After Postsolve, objective 49755.78, infeasibilities - dual 56027.986 (288), primal 0 (0)
# Presolved model was optimal, full model needs cleaning up
# 0  Obj 49755.78
# Optimal - objective value 49755.78
# Optimal objective 49755.77972 - 286 iterations time 0.012, Presolve 0.00
# Total time (CPU seconds):       0.01   (Wallclock seconds):       0.01
#
# ┌ Info: JuMP.optimize! completed
# │   timed_log = Dict{Symbol,Any}(:timed_solve_time => 0.081076029,:solve_bytes_alloc => 15470800,:sec_in_gc => 0.0)
# └ @ PowerSimulations /Users/cbarrows/.julia/packages/PowerSimulations/TTXVL/src/core/simulation_stages.jl:105
# ┌ Warning: SolveTime() property not supported by the Solver
# └ @ PowerSimulations /Users/cbarrows/.julia/packages/PowerSimulations/TTXVL/src/core/psi_container.jl:526
# ┌ Info: Starting run step-1-stage-ED 2020-01-01T21:00:00
# └ @ PowerSimulations /Users/cbarrows/.julia/packages/PowerSimulations/TTXVL/src/core/simulation.jl:615
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Oct  7 2019
#
# command line - Cbc_C_Interface -ratioGap 0.5 -logLevel 1 -solve -quit (default strategy 1)
# ratioGap was changed from 0 to 0.5
# Presolve 192 (-3120) rows, 816 (-4200) columns and 996 (-7320) elements
# Perturbing problem by 0.001% of 301.0328 - largest nonzero change 3.3279764e-05 ( 1.327102e-05%) - largest zero change 3.2943149e-05
# 0  Obj 827.82586 Primal inf 250.08021 (192)
# 78  Obj 17157.438 Primal inf 206.00426 (149)
# 156  Obj 36184.767 Primal inf 77.254455 (84)
# 234  Obj 43162.891 Primal inf 5.5925194 (10)
# 247  Obj 43172.19
# Optimal - objective value 43172.18
# After Postsolve, objective 43172.18, infeasibilities - dual 54730.441 (288), primal 0 (0)
# Presolved model was optimal, full model needs cleaning up
# 0  Obj 43172.18
# Optimal - objective value 43172.18
# Optimal objective 43172.18034 - 247 iterations time 0.012, Presolve 0.00
# Total time (CPU seconds):       0.01   (Wallclock seconds):       0.01
#
# ┌ Info: JuMP.optimize! completed
# │   timed_log = Dict{Symbol,Any}(:timed_solve_time => 0.074281791,:solve_bytes_alloc => 15459376,:sec_in_gc => 0.0)
# └ @ PowerSimulations /Users/cbarrows/.julia/packages/PowerSimulations/TTXVL/src/core/simulation_stages.jl:105
# ┌ Warning: SolveTime() property not supported by the Solver
# └ @ PowerSimulations /Users/cbarrows/.julia/packages/PowerSimulations/TTXVL/src/core/psi_container.jl:526
# ┌ Info: Starting run step-1-stage-ED 2020-01-01T22:00:00
# └ @ PowerSimulations /Users/cbarrows/.julia/packages/PowerSimulations/TTXVL/src/core/simulation.jl:615
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Oct  7 2019
#
# command line - Cbc_C_Interface -ratioGap 0.5 -logLevel 1 -solve -quit (default strategy 1)
# ratioGap was changed from 0 to 0.5
# Presolve 168 (-3144) rows, 708 (-4308) columns and 864 (-7452) elements
# Perturbing problem by 0.001% of 301.0328 - largest nonzero change 3.3279764e-05 ( 1.2783425e-05%) - largest zero change 3.2943149e-05
# 0  Obj 827.82542 Primal inf 236.36625 (168)
# 78  Obj 22472.227 Primal inf 151.86291 (121)
# 156  Obj 37047.843 Primal inf 48.075533 (59)
# 214  Obj 41494.543
# Optimal - objective value 41494.534
# After Postsolve, objective 41494.534, infeasibilities - dual 58490.683 (288), primal 0 (0)
# Presolved model was optimal, full model needs cleaning up
# 0  Obj 41494.534
# Optimal - objective value 41494.534
# Optimal objective 41494.53388 - 214 iterations time 0.012, Presolve 0.00
# Total time (CPU seconds):       0.01   (Wallclock seconds):       0.01
#
# ┌ Info: JuMP.optimize! completed
# │   timed_log = Dict{Symbol,Any}(:timed_solve_time => 0.076156237,:solve_bytes_alloc => 15455792,:sec_in_gc => 0.0)
# └ @ PowerSimulations /Users/cbarrows/.julia/packages/PowerSimulations/TTXVL/src/core/simulation_stages.jl:105
# ┌ Warning: SolveTime() property not supported by the Solver
# └ @ PowerSimulations /Users/cbarrows/.julia/packages/PowerSimulations/TTXVL/src/core/psi_container.jl:526
# ┌ Info: Starting run step-1-stage-ED 2020-01-01T23:00:00
# └ @ PowerSimulations /Users/cbarrows/.julia/packages/PowerSimulations/TTXVL/src/core/simulation.jl:615
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Oct  7 2019
#
# command line - Cbc_C_Interface -ratioGap 0.5 -logLevel 1 -solve -quit (default strategy 1)
# ratioGap was changed from 0 to 0.5
# Presolve 156 (-3156) rows, 660 (-4356) columns and 804 (-7512) elements
# Perturbing problem by 0.001% of 301.0328 - largest nonzero change 3.2148362e-05 ( 1.3073088e-05%) - largest zero change 3.2099551e-05
# 0  Obj 0.0024413301 Primal inf 201.05558 (156)
# 78  Obj 18258.319 Primal inf 114.02449 (103)
# 156  Obj 31835.189 Primal inf 25.679364 (34)
# 189  Obj 33892.419
# Optimal - objective value 33892.411
# After Postsolve, objective 33892.411, infeasibilities - dual 56154.232 (287), primal 0 (0)
# Presolved model was optimal, full model needs cleaning up
# 0  Obj 33892.411
# Optimal - objective value 33892.411
# Optimal objective 33892.41145 - 189 iterations time 0.012, Presolve 0.00
# Total time (CPU seconds):       0.01   (Wallclock seconds):       0.01
#
# ┌ Info: JuMP.optimize! completed
# │   timed_log = Dict{Symbol,Any}(:timed_solve_time => 0.233718993,:solve_bytes_alloc => 15451984,:sec_in_gc => 0.106902086)
# └ @ PowerSimulations /Users/cbarrows/.julia/packages/PowerSimulations/TTXVL/src/core/simulation_stages.jl:105
# ┌ Warning: SolveTime() property not supported by the Solver
# └ @ PowerSimulations /Users/cbarrows/.julia/packages/PowerSimulations/TTXVL/src/core/psi_container.jl:526
# ┌ Info:
# │  ──────────────────────────────────────────────────────────────────────────────
# │                                        Time                   Allocations
# │                                ──────────────────────   ───────────────────────
# │        Tot / % measured:            53.8s / 100%            2.32GiB / 100%
# │
# │  Section               ncalls     time   %tot     avg     alloc   %tot      avg
# │  ──────────────────────────────────────────────────────────────────────────────
# │  Execute Simulation         1    53.8s   100%   53.8s   2.32GiB  100%   2.32GiB
# │    Execution Step 1         1    31.8s  59.2%   31.8s    942MiB  39.7%   942MiB
# │      Execution Stage 1      1    24.2s  45.0%   24.2s    394MiB  16.6%   394MiB
# │        Run Stage 1          1    24.1s  44.8%   24.1s    385MiB  16.2%   385MiB
# │        Update Stage 1       1    244ns  0.00%   244ns     0.00B  0.00%    0.00B
# │      Execution Stage 2     24    7.63s  14.2%   318ms    548MiB  23.1%  22.8MiB
# │        Run Stage 2         24    3.83s  7.11%   159ms    454MiB  19.1%  18.9MiB
# │        Update Stage 2      24    3.80s  7.07%   158ms   94.1MiB  3.97%  3.92MiB
# │  ──────────────────────────────────────────────────────────────────────────────
# └ @ PowerSimulations /Users/cbarrows/.julia/packages/PowerSimulations/TTXVL/src/core/simulation.jl:645
# Simulation Results Reference
#
# Results Folder: /var/folders/27/2jr8c7gn4j72fvrg4qt81zrw8w_711/T/rts-test/2020-02-27T14-20-00/results
#
# Reference Tables
#
# stage-UC
#
# Spin_Up_R1_VariableReserve{ReserveUp}: dataframe size (1, 3)
#
# P_HydroDispatch: dataframe size (1, 3)
#
# Start_ThermalStandard: dataframe size (1, 3)
#
# Flex_Up_VariableReserve{ReserveUp}: dataframe size (1, 3)
#
# Stop_ThermalStandard: dataframe size (1, 3)
#
# Flex_Down_VariableReserve{ReserveDown}: dataframe size (1, 3)
#
# Spin_Up_R3_VariableReserve{ReserveUp}: dataframe size (1, 3)
#
# P_RenewableDispatch: dataframe size (1, 3)
#
# Reg_Down_VariableReserve{ReserveDown}: dataframe size (1, 3)
#
# Spin_Up_R2_VariableReserve{ReserveUp}: dataframe size (1, 3)
#
# P_ThermalStandard: dataframe size (1, 3)
#
# On_ThermalStandard: dataframe size (1, 3)
#
# Reg_Up_VariableReserve{ReserveUp}: dataframe size (1, 3)
#
# stage-ED
#
# P_ThermalStandard: dataframe size (24, 3)
#
# P_HydroDispatch: dataframe size (24, 3)
#
# P_RenewableDispatch: dataframe size (24, 3)
#
# stage-UC
#
# time length: 24
#
# stage-ED
#
# time length: 12

# %% [markdown]
# ## Results

# %%
uc_results = load_simulation_results(sim_results, "UC");
ed_results = load_simulation_results(sim_results, "ED");

# %% [markdown]
# ---
#
# *This notebook was generated using [Literate.jl](https://github.com/fredrikekre/Literate.jl).*
