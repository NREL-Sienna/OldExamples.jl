# %% [markdown]
# # 5-bus Market simulation with [PowerSimulations.jl](https://github.com/NREL/PowerSimulations.jl)

# %% [markdown]
# **Originally Contributed by**: Clayton Barrows

# %% [markdown]
# ## Introduction

# %% [markdown]
# PowerSimulations.jl supports simulations that consist of sequential optimization problems
# where results from previous problems inform subsequent problems in a variety of ways. This
# example demonstrates some of these capabilities to represent electricity market clearing.

# %% [markdown]
# ## Dependencies and Data
# First, let's create `System`s to represent the Day-Ahead and Real-Time market clearing
# process with hourly, and 5-minute forecast data, respectively.

# %%
using SIIPExamples
pkgpath = dirname(dirname(pathof(SIIPExamples)))
# Out:
# "/Users/cbarrows/Documents/repos/SIIPExamples.jl"

# %% [markdown]
# ### Modeling Packages

# %%
using InfrastructureSystems
const IS = InfrastructureSystems
using PowerSystems
const PSY = PowerSystems
using PowerSimulations
const PSI = PowerSimulations
# Out:
# PowerSimulations

# %% [markdown]
# ### Data management packages

# %%
using Dates
using DataFrames

# %% [markdown]
# ### Optimization packages

# %%
using JuMP
using Cbc #solver
solver = optimizer_with_attributes(Cbc.Optimizer, "logLevel" => 1, "ratioGap" => 0.5)
# Out:
# MathOptInterface.OptimizerWithAttributes(Cbc.Optimizer, Pair{MathOptInterface.AbstractOptimizerAttribute,Any}[MathOptInterface.RawParameter("logLevel") => 1, MathOptInterface.RawParameter("ratioGap") => 0.5])

# %% [markdown]
# ### 5-bus Data
# The five bus system data here includes hourly day-ahead data, 5-minute real-time market
# data, and 6-second actual data.

# %%
base_dir = PSY.download(PSY.TestData; branch = "master");
pm_data = PSY.PowerModelsData(joinpath(base_dir, "matpower", "case5_re_uc.m"))

FORECASTS_DIR = joinpath(base_dir,"forecasts","5bus_ts","7day")

tsp_da = IS.read_time_series_metadata(joinpath(FORECASTS_DIR,"timeseries_pointers_da_7day.json"))
tsp_rt = IS.read_time_series_metadata(joinpath(FORECASTS_DIR,"timeseries_pointers_rt_7day.json"))
tsp_agc = IS.read_time_series_metadata(joinpath(FORECASTS_DIR,"timeseries_pointers_agc_7day.json"))

sys_DA = System(pm_data)
reserves = [VariableReserve{ReserveUp}("REG1", 5.0, 0.1),
            VariableReserve{ReserveUp}("REG2", 5.0, 0.06),
            VariableReserve{ReserveUp}("REG3", 5.0, 0.03),
            VariableReserve{ReserveUp}("REG4", 5.0, 0.02)]
contributing_devices = get_components(Generator, sys_DA)
for r in reserves
    add_service!(sys_DA, r, contributing_devices)
end

add_forecasts!(sys_DA, tsp_da)

sys_RT = System(pm_data)
add_forecasts!(sys_RT, tsp_rt)

sys_AGC = System(pm_data)
add_forecasts!(sys_AGC, tsp_agc)
# Out:
# ┌ Info: extending matpower format with data: areas 1x3
# └ @ PowerSystems /Users/cbarrows/.julia/packages/PowerSystems/N15Uk/src/parsers/pm_io/matpower.jl:332
# ┌ Info: extending matpower format with data: gen_name 5x4
# └ @ PowerSystems /Users/cbarrows/.julia/packages/PowerSystems/N15Uk/src/parsers/pm_io/matpower.jl:332
# ┌ Info: extending matpower format by appending matrix "gen_name" in to "gen"
# └ @ PowerSystems /Users/cbarrows/.julia/packages/PowerSystems/N15Uk/src/parsers/pm_io/matpower.jl:664
# ┌ Info: reversing the orientation of branch 6 (4, 3) to be consistent with other parallel branches
# └ @ PowerSystems /Users/cbarrows/.julia/packages/PowerSystems/N15Uk/src/parsers/pm_io/data.jl:1218
# ┌ Info: the voltage setpoint on generator 4 does not match the value at bus 4
# └ @ PowerSystems /Users/cbarrows/.julia/packages/PowerSystems/N15Uk/src/parsers/pm_io/data.jl:1686
# ┌ Info: the voltage setpoint on generator 1 does not match the value at bus 1
# └ @ PowerSystems /Users/cbarrows/.julia/packages/PowerSystems/N15Uk/src/parsers/pm_io/data.jl:1686
# ┌ Info: the voltage setpoint on generator 5 does not match the value at bus 10
# └ @ PowerSystems /Users/cbarrows/.julia/packages/PowerSystems/N15Uk/src/parsers/pm_io/data.jl:1686
# ┌ Info: the voltage setpoint on generator 2 does not match the value at bus 1
# └ @ PowerSystems /Users/cbarrows/.julia/packages/PowerSystems/N15Uk/src/parsers/pm_io/data.jl:1686
# ┌ Info: the voltage setpoint on generator 3 does not match the value at bus 3
# └ @ PowerSystems /Users/cbarrows/.julia/packages/PowerSystems/N15Uk/src/parsers/pm_io/data.jl:1686
# ┌ Info: removing 1 cost terms from generator 4: [4000.0, 0.0]
# └ @ PowerSystems /Users/cbarrows/.julia/packages/PowerSystems/N15Uk/src/parsers/pm_io/data.jl:1867
# ┌ Info: removing 1 cost terms from generator 1: [1400.0, 0.0]
# └ @ PowerSystems /Users/cbarrows/.julia/packages/PowerSystems/N15Uk/src/parsers/pm_io/data.jl:1867
# ┌ Info: removing 1 cost terms from generator 5: [1000.0, 0.0]
# └ @ PowerSystems /Users/cbarrows/.julia/packages/PowerSystems/N15Uk/src/parsers/pm_io/data.jl:1867
# ┌ Info: removing 1 cost terms from generator 2: [1500.0, 0.0]
# └ @ PowerSystems /Users/cbarrows/.julia/packages/PowerSystems/N15Uk/src/parsers/pm_io/data.jl:1867
# ┌ Info: removing 1 cost terms from generator 3: [3000.0, 0.0]
# └ @ PowerSystems /Users/cbarrows/.julia/packages/PowerSystems/N15Uk/src/parsers/pm_io/data.jl:1867
# ┌ Info: Constructing System from Power Models
# │   data["name"] = nesta_case5_pjm
# │   data["source_type"] = matpower
# └ @ PowerSystems /Users/cbarrows/.julia/packages/PowerSystems/N15Uk/src/parsers/power_models_data.jl:33
# ┌ Info: Reading bus data
# └ @ PowerSystems /Users/cbarrows/.julia/packages/PowerSystems/N15Uk/src/parsers/power_models_data.jl:122
# ┌ Info: Reading generator data
# └ @ PowerSystems /Users/cbarrows/.julia/packages/PowerSystems/N15Uk/src/parsers/power_models_data.jl:382
# ┌ Info: Reading branch data
# └ @ PowerSystems /Users/cbarrows/.julia/packages/PowerSystems/N15Uk/src/parsers/power_models_data.jl:534
# ┌ Info: Reading branch data
# └ @ PowerSystems /Users/cbarrows/.julia/packages/PowerSystems/N15Uk/src/parsers/power_models_data.jl:597
# ┌ Info: Reading DC Line data
# └ @ PowerSystems /Users/cbarrows/.julia/packages/PowerSystems/N15Uk/src/parsers/power_models_data.jl:568
# ┌ Warning: no component category=Generator name=SolarBusC
# └ @ InfrastructureSystems /Users/cbarrows/.julia/packages/InfrastructureSystems/qvTbP/src/system_data.jl:538
# ┌ Warning: no component category=Generator name=WindBusA
# └ @ InfrastructureSystems /Users/cbarrows/.julia/packages/InfrastructureSystems/qvTbP/src/system_data.jl:538
# ┌ Info: Constructing System from Power Models
# │   data["name"] = nesta_case5_pjm
# │   data["source_type"] = matpower
# └ @ PowerSystems /Users/cbarrows/.julia/packages/PowerSystems/N15Uk/src/parsers/power_models_data.jl:33
# ┌ Info: Reading bus data
# └ @ PowerSystems /Users/cbarrows/.julia/packages/PowerSystems/N15Uk/src/parsers/power_models_data.jl:122
# ┌ Info: Reading generator data
# └ @ PowerSystems /Users/cbarrows/.julia/packages/PowerSystems/N15Uk/src/parsers/power_models_data.jl:382
# ┌ Info: Reading branch data
# └ @ PowerSystems /Users/cbarrows/.julia/packages/PowerSystems/N15Uk/src/parsers/power_models_data.jl:534
# ┌ Info: Reading branch data
# └ @ PowerSystems /Users/cbarrows/.julia/packages/PowerSystems/N15Uk/src/parsers/power_models_data.jl:597
# ┌ Info: Reading DC Line data
# └ @ PowerSystems /Users/cbarrows/.julia/packages/PowerSystems/N15Uk/src/parsers/power_models_data.jl:568
# ┌ Warning: no component category=Generator name=SolarBusC
# └ @ InfrastructureSystems /Users/cbarrows/.julia/packages/InfrastructureSystems/qvTbP/src/system_data.jl:538
# ┌ Warning: no component category=Generator name=WindBusA
# └ @ InfrastructureSystems /Users/cbarrows/.julia/packages/InfrastructureSystems/qvTbP/src/system_data.jl:538
# ┌ Info: Constructing System from Power Models
# │   data["name"] = nesta_case5_pjm
# │   data["source_type"] = matpower
# └ @ PowerSystems /Users/cbarrows/.julia/packages/PowerSystems/N15Uk/src/parsers/power_models_data.jl:33
# ┌ Info: Reading bus data
# └ @ PowerSystems /Users/cbarrows/.julia/packages/PowerSystems/N15Uk/src/parsers/power_models_data.jl:122
# ┌ Info: Reading generator data
# └ @ PowerSystems /Users/cbarrows/.julia/packages/PowerSystems/N15Uk/src/parsers/power_models_data.jl:382
# ┌ Info: Reading branch data
# └ @ PowerSystems /Users/cbarrows/.julia/packages/PowerSystems/N15Uk/src/parsers/power_models_data.jl:534
# ┌ Info: Reading branch data
# └ @ PowerSystems /Users/cbarrows/.julia/packages/PowerSystems/N15Uk/src/parsers/power_models_data.jl:597
# ┌ Info: Reading DC Line data
# └ @ PowerSystems /Users/cbarrows/.julia/packages/PowerSystems/N15Uk/src/parsers/power_models_data.jl:568
# ┌ Warning: no component category=Generator name=SolarBusC
# └ @ InfrastructureSystems /Users/cbarrows/.julia/packages/InfrastructureSystems/qvTbP/src/system_data.jl:538
# ┌ Warning: no component category=Generator name=WindBusA
# └ @ InfrastructureSystems /Users/cbarrows/.julia/packages/InfrastructureSystems/qvTbP/src/system_data.jl:538

# %% [markdown]
# ## `OperationsProblemTemplate`s

# %%
template_uc = template_unit_commitment()
devices = Dict(
    :Generators => DeviceModel(ThermalStandard, ThermalDispatch),
    :Ren => DeviceModel(RenewableDispatch, RenewableFullDispatch),
    :Loads => DeviceModel(PowerLoad, StaticPowerLoad),
    :HydroROR => DeviceModel(HydroDispatch, HydroDispatchRunOfRiver),
    :RenFx => DeviceModel(RenewableFix, RenewableFixed),
)
template_ed = template_economic_dispatch(devices = devices)
# Out:
# Operations Problem Specification
# ============================================
#
#   transmission:  CopperPlatePowerModel
# ============================================
#   devices:
#       HydroROR:
#         device_type = HydroDispatch
#         formulation = HydroDispatchRunOfRiver
#       Generators:
#         device_type = ThermalStandard
#         formulation = ThermalDispatch
#       Ren:
#         device_type = RenewableDispatch
#         formulation = RenewableFullDispatch
#       Loads:
#         device_type = PowerLoad
#         formulation = StaticPowerLoad
#       RenFx:
#         device_type = RenewableFix
#         formulation = RenewableFixed
# ============================================
#   branches:
#       T:
#         device_type = Transformer2W
#         formulation = StaticTransformer
#       TT:
#         device_type = TapTransformer
#         formulation = StaticTransformer
#       L:
#         device_type = Line
#         formulation = StaticLine
#       DC:
#         device_type = HVDCLine
#         formulation = HVDCDispatch
# ============================================
#   services:
# ============================================

# %% [markdown]
# ### Define the Simulation Sequence

# %%
stages_definition = Dict("UC" => Stage(GenericOpProblem, template_uc, sys_DA, solver),
                         "ED" => Stage(GenericOpProblem, template_ed, sys_RT, solver))


feedforward_chronologies = Dict(("UC" => "ED") => Synchronize(periods = 24))

feedforward = Dict(("ED", :devices, :Generators) => SemiContinuousFF(binary_from_stage = PSI.ON,
                                                         affected_variables = [PSI.ACTIVE_POWER]))

cache = Dict("UC" => [TimeStatusChange(PSY.ThermalStandard, PSI.ON)])

order = Dict(1 => "UC", 2 => "ED")
horizons = Dict("UC" => 24, "ED" =>12)
intervals = Dict("UC" => (Hour(24), Consecutive()),
                 "ED" => (Hour(1), Consecutive()))

DA_RT_sequence = SimulationSequence(step_resolution = Hour(24),
                                    order = order,
                                    horizons = horizons,
                                    intervals = intervals,
                                    ini_cond_chronology = InterStageChronology(),
                                    feedforward_chronologies = feedforward_chronologies,
                                    feedforward = feedforward,
                                    #cache = cache,
                                    )
# Out:
# Feed Forward Chronology
# -----------------------
#
# ED: SemiContinuousFF -> Generators
#
#                      UC--┐ from : On
#                          |
# ┌----┬----┬----┬----┬----┼----┬----┬----┬----┬----┬----┐
# |    |    |    |    |    |    |    |    |    |    |    |
# |    |    |    |    |    |    |    |    |    |    |    |
# └─ED └─ED └─ED └─ED └─ED └─ED └─ED └─ED └─ED └─ED └─ED └─ED ... (x24) to : ["P"]
#
# Initial Condition Chronology
# ----------------------------
#
# 1
# |
# |
# 2 --> 2 ... (x24)

# %% [markdown]
# ## `Simulation`

# %%
file_path = tempdir()
sim = Simulation(name = "5bus-test",
                steps = 1,
                stages = stages_definition,
                stages_sequence = DA_RT_sequence,
                simulation_folder = file_path)
# Out:
# Simulation()

# %% [markdown]
# ### Build simulation

# %%
build!(sim)
# Out:
# ┌ Info: Building Stage 2-ED
# └ @ PowerSimulations /Users/cbarrows/.julia/packages/PowerSimulations/TTXVL/src/core/simulation.jl:317
# ┌ Warning: The data doesn't include devices of type HydroDispatch, consider changing the device models
# └ @ PowerSimulations /Users/cbarrows/.julia/packages/PowerSimulations/TTXVL/src/devices_models/device_constructors/common/constructor_validations.jl:4
# ┌ Warning: The data doesn't include devices of type RenewableDispatch, consider changing the device models
# └ @ PowerSimulations /Users/cbarrows/.julia/packages/PowerSimulations/TTXVL/src/devices_models/device_constructors/common/constructor_validations.jl:4
# ┌ Warning: The data doesn't include devices of type RenewableFix, consider changing the device models
# └ @ PowerSimulations /Users/cbarrows/.julia/packages/PowerSimulations/TTXVL/src/devices_models/device_constructors/common/constructor_validations.jl:4
# ┌ Info: Building Stage 1-UC
# └ @ PowerSimulations /Users/cbarrows/.julia/packages/PowerSimulations/TTXVL/src/core/simulation.jl:317
# ┌ Warning: The data doesn't include devices of type InterruptibleLoad, consider changing the device models
# └ @ PowerSimulations /Users/cbarrows/.julia/packages/PowerSimulations/TTXVL/src/devices_models/device_constructors/common/constructor_validations.jl:4
# ┌ Warning: The data doesn't include devices of type HydroDispatch, consider changing the device models
# └ @ PowerSimulations /Users/cbarrows/.julia/packages/PowerSimulations/TTXVL/src/devices_models/device_constructors/common/constructor_validations.jl:4
# ┌ Warning: The data doesn't include devices of type RenewableFix, consider changing the device models
# └ @ PowerSimulations /Users/cbarrows/.julia/packages/PowerSimulations/TTXVL/src/devices_models/device_constructors/common/constructor_validations.jl:4
# ┌ Warning: The data doesn't include devices of type HydroEnergyReservoir, consider changing the device models
# └ @ PowerSimulations /Users/cbarrows/.julia/packages/PowerSimulations/TTXVL/src/devices_models/device_constructors/common/constructor_validations.jl:4
# ┌ Warning: The data doesn't include devices of type RenewableDispatch, consider changing the device models
# └ @ PowerSimulations /Users/cbarrows/.julia/packages/PowerSimulations/TTXVL/src/devices_models/device_constructors/common/constructor_validations.jl:4
# ┌ Info:
# │  ───────────────────────────────────────────────────────────────────────────
# │                                     Time                   Allocations
# │                             ──────────────────────   ───────────────────────
# │       Tot / % measured:         25.9ms / 100%            3.79MiB / 100%
# │
# │  Section            ncalls     time   %tot     avg     alloc   %tot      avg
# │  ───────────────────────────────────────────────────────────────────────────
# │  Build Simulation        1   25.9ms   100%  25.9ms   3.79MiB  100%   3.79MiB
# │    Build Stage UC        1   13.9ms  53.8%  13.9ms   2.86MiB  75.5%  2.86MiB
# │    Build Stage ED        1   7.66ms  29.6%  7.66ms    873KiB  22.5%   873KiB
# │  ───────────────────────────────────────────────────────────────────────────
# └ @ PowerSimulations /Users/cbarrows/.julia/packages/PowerSimulations/TTXVL/src/core/simulation.jl:388

# %% [markdown]
# ### Execute simulation

# %%
sim_results = execute!(sim)
# Out:
# ┌ Info: Serialized time series data to /var/folders/27/2jr8c7gn4j72fvrg4qt81zrw8w_711/T/5bus-test/2020-03-05T08-16-00/models_json/stage_ED_model/ED_sys_data_time_series_storage.h5.
# └ @ InfrastructureSystems /Users/cbarrows/.julia/packages/InfrastructureSystems/qvTbP/src/time_series_storage.jl:47
# ┌ Info: Serialized System to /var/folders/27/2jr8c7gn4j72fvrg4qt81zrw8w_711/T/5bus-test/2020-03-05T08-16-00/models_json/stage_ED_model/ED_sys_data.json
# └ @ InfrastructureSystems /Users/cbarrows/.julia/packages/InfrastructureSystems/qvTbP/src/serialization.jl:8
# ┌ Info: Serialized time series data to /var/folders/27/2jr8c7gn4j72fvrg4qt81zrw8w_711/T/5bus-test/2020-03-05T08-16-00/models_json/stage_UC_model/UC_sys_data_time_series_storage.h5.
# └ @ InfrastructureSystems /Users/cbarrows/.julia/packages/InfrastructureSystems/qvTbP/src/time_series_storage.jl:47
# ┌ Info: Serialized System to /var/folders/27/2jr8c7gn4j72fvrg4qt81zrw8w_711/T/5bus-test/2020-03-05T08-16-00/models_json/stage_UC_model/UC_sys_data.json
# └ @ InfrastructureSystems /Users/cbarrows/.julia/packages/InfrastructureSystems/qvTbP/src/serialization.jl:8
# Executing Step 1
# ┌ Info: Starting run step-1-stage-UC 2020-01-01T00:00:00
# └ @ PowerSimulations /Users/cbarrows/.julia/packages/PowerSimulations/TTXVL/src/core/simulation.jl:615
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Oct  7 2019
#
# command line - Cbc_C_Interface -ratioGap 0.5 -logLevel 1 -solve -quit (default strategy 1)
# ratioGap was changed from 0 to 0.5
# Continuous objective value is 193679 - 0.00 seconds
# Cgl0003I 0 fixed, 0 tightened bounds, 45 strengthened rows, 26 substitutions
# Cgl0004I processed model has 561 rows, 910 columns (334 integer (334 of which binary)) and 2309 elements
# Cbc0012I Integer solution of 240490.23 found by DiveCoefficient after 0 iterations and 0 nodes (0.02 seconds)
# Cbc0011I Exiting as integer gap of 46811.445 less than 1e-10 or 50%
# Cbc0001I Search completed - best objective 240490.2265107201, took 0 iterations and 0 nodes (0.03 seconds)
# Cbc0035I Maximum depth 0, 0 variables fixed on reduced cost
# Cuts at root node changed objective from 193679 to 193679
# Probing was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found (within gap tolerance)
#
# Objective value:                240490.22651072
# Lower bound:                    193678.782
# Gap:                            0.24
# Enumerated nodes:               0
# Total iterations:               0
# Time (CPU seconds):             0.03
# Time (Wallclock seconds):       0.03
#
# Total time (CPU seconds):       0.03   (Wallclock seconds):       0.03
#
# ┌ Info: JuMP.optimize! completed
# │   timed_log = Dict{Symbol,Any}(:timed_solve_time => 0.047480695,:solve_bytes_alloc => 4005584,:sec_in_gc => 0.0)
# └ @ PowerSimulations /Users/cbarrows/.julia/packages/PowerSimulations/TTXVL/src/core/simulation_stages.jl:105
# ┌ Warning: SolveTime() property not supported by the Solver
# └ @ PowerSimulations /Users/cbarrows/.julia/packages/PowerSimulations/TTXVL/src/core/psi_container.jl:526
# ┌ Info: Starting run step-1-stage-ED 2020-01-01T00:00:00
# └ @ PowerSimulations /Users/cbarrows/.julia/packages/PowerSimulations/TTXVL/src/core/simulation.jl:615
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Oct  7 2019
#
# command line - Cbc_C_Interface -ratioGap 0.5 -logLevel 1 -solve -quit (default strategy 1)
# ratioGap was changed from 0 to 0.5
# Presolve 0 (-132) rows, 0 (-60) columns and 0 (-180) elements
# Empty problem - 0 rows, 0 columns and 0 elements
# Optimal - objective value 5827.8548
# After Postsolve, objective 5827.8548, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 5827.854755 - 0 iterations time 0.002, Presolve 0.00
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# ┌ Info: JuMP.optimize! completed
# │   timed_log = Dict{Symbol,Any}(:timed_solve_time => 0.005020915,:solve_bytes_alloc => 702128,:sec_in_gc => 0.0)
# └ @ PowerSimulations /Users/cbarrows/.julia/packages/PowerSimulations/TTXVL/src/core/simulation_stages.jl:105
# ┌ Warning: SolveTime() property not supported by the Solver
# └ @ PowerSimulations /Users/cbarrows/.julia/packages/PowerSimulations/TTXVL/src/core/psi_container.jl:526
# ┌ Info: Starting run step-1-stage-ED 2020-01-01T01:00:00
# └ @ PowerSimulations /Users/cbarrows/.julia/packages/PowerSimulations/TTXVL/src/core/simulation.jl:615
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Oct  7 2019
#
# command line - Cbc_C_Interface -ratioGap 0.5 -logLevel 1 -solve -quit (default strategy 1)
# ratioGap was changed from 0 to 0.5
# Presolve 0 (-132) rows, 0 (-60) columns and 0 (-180) elements
# Empty problem - 0 rows, 0 columns and 0 elements
# Optimal - objective value 5336.3444
# After Postsolve, objective 5336.3444, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 5336.344449 - 0 iterations time 0.002, Presolve 0.00
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# ┌ Info: JuMP.optimize! completed
# │   timed_log = Dict{Symbol,Any}(:timed_solve_time => 0.003922374,:solve_bytes_alloc => 400544,:sec_in_gc => 0.0)
# └ @ PowerSimulations /Users/cbarrows/.julia/packages/PowerSimulations/TTXVL/src/core/simulation_stages.jl:105
# ┌ Warning: SolveTime() property not supported by the Solver
# └ @ PowerSimulations /Users/cbarrows/.julia/packages/PowerSimulations/TTXVL/src/core/psi_container.jl:526
# ┌ Info: Starting run step-1-stage-ED 2020-01-01T02:00:00
# └ @ PowerSimulations /Users/cbarrows/.julia/packages/PowerSimulations/TTXVL/src/core/simulation.jl:615
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Oct  7 2019
#
# command line - Cbc_C_Interface -ratioGap 0.5 -logLevel 1 -solve -quit (default strategy 1)
# ratioGap was changed from 0 to 0.5
# Presolve 0 (-132) rows, 0 (-60) columns and 0 (-180) elements
# Empty problem - 0 rows, 0 columns and 0 elements
# Optimal - objective value 4989.6088
# After Postsolve, objective 4989.6088, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 4989.608845 - 0 iterations time 0.002, Presolve 0.00
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# ┌ Info: JuMP.optimize! completed
# │   timed_log = Dict{Symbol,Any}(:timed_solve_time => 0.003638044,:solve_bytes_alloc => 397856,:sec_in_gc => 0.0)
# └ @ PowerSimulations /Users/cbarrows/.julia/packages/PowerSimulations/TTXVL/src/core/simulation_stages.jl:105
# ┌ Warning: SolveTime() property not supported by the Solver
# └ @ PowerSimulations /Users/cbarrows/.julia/packages/PowerSimulations/TTXVL/src/core/psi_container.jl:526
# ┌ Info: Starting run step-1-stage-ED 2020-01-01T03:00:00
# └ @ PowerSimulations /Users/cbarrows/.julia/packages/PowerSimulations/TTXVL/src/core/simulation.jl:615
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Oct  7 2019
#
# command line - Cbc_C_Interface -ratioGap 0.5 -logLevel 1 -solve -quit (default strategy 1)
# ratioGap was changed from 0 to 0.5
# Presolve 0 (-132) rows, 0 (-60) columns and 0 (-180) elements
# Empty problem - 0 rows, 0 columns and 0 elements
# Optimal - objective value 4780.6261
# After Postsolve, objective 4780.6261, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 4780.626138 - 0 iterations time 0.002, Presolve 0.00
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# ┌ Info: JuMP.optimize! completed
# │   timed_log = Dict{Symbol,Any}(:timed_solve_time => 0.003544428,:solve_bytes_alloc => 397856,:sec_in_gc => 0.0)
# └ @ PowerSimulations /Users/cbarrows/.julia/packages/PowerSimulations/TTXVL/src/core/simulation_stages.jl:105
# ┌ Warning: SolveTime() property not supported by the Solver
# └ @ PowerSimulations /Users/cbarrows/.julia/packages/PowerSimulations/TTXVL/src/core/psi_container.jl:526
# ┌ Info: Starting run step-1-stage-ED 2020-01-01T04:00:00
# └ @ PowerSimulations /Users/cbarrows/.julia/packages/PowerSimulations/TTXVL/src/core/simulation.jl:615
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Oct  7 2019
#
# command line - Cbc_C_Interface -ratioGap 0.5 -logLevel 1 -solve -quit (default strategy 1)
# ratioGap was changed from 0 to 0.5
# Presolve 0 (-132) rows, 0 (-60) columns and 0 (-180) elements
# Empty problem - 0 rows, 0 columns and 0 elements
# Optimal - objective value 4744.834
# After Postsolve, objective 4744.834, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 4744.834028 - 0 iterations time 0.002, Presolve 0.00
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# ┌ Info: JuMP.optimize! completed
# │   timed_log = Dict{Symbol,Any}(:timed_solve_time => 0.003400117,:solve_bytes_alloc => 397856,:sec_in_gc => 0.0)
# └ @ PowerSimulations /Users/cbarrows/.julia/packages/PowerSimulations/TTXVL/src/core/simulation_stages.jl:105
# ┌ Warning: SolveTime() property not supported by the Solver
# └ @ PowerSimulations /Users/cbarrows/.julia/packages/PowerSimulations/TTXVL/src/core/psi_container.jl:526
# ┌ Info: Starting run step-1-stage-ED 2020-01-01T05:00:00
# └ @ PowerSimulations /Users/cbarrows/.julia/packages/PowerSimulations/TTXVL/src/core/simulation.jl:615
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Oct  7 2019
#
# command line - Cbc_C_Interface -ratioGap 0.5 -logLevel 1 -solve -quit (default strategy 1)
# ratioGap was changed from 0 to 0.5
# Presolve 0 (-132) rows, 0 (-60) columns and 0 (-180) elements
# Empty problem - 0 rows, 0 columns and 0 elements
# Optimal - objective value 4877.6002
# After Postsolve, objective 4877.6002, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 4877.600196 - 0 iterations time 0.002, Presolve 0.00
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# ┌ Info: JuMP.optimize! completed
# │   timed_log = Dict{Symbol,Any}(:timed_solve_time => 0.003298223,:solve_bytes_alloc => 397856,:sec_in_gc => 0.0)
# └ @ PowerSimulations /Users/cbarrows/.julia/packages/PowerSimulations/TTXVL/src/core/simulation_stages.jl:105
# ┌ Warning: SolveTime() property not supported by the Solver
# └ @ PowerSimulations /Users/cbarrows/.julia/packages/PowerSimulations/TTXVL/src/core/psi_container.jl:526
# ┌ Info: Starting run step-1-stage-ED 2020-01-01T06:00:00
# └ @ PowerSimulations /Users/cbarrows/.julia/packages/PowerSimulations/TTXVL/src/core/simulation.jl:615
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Oct  7 2019
#
# command line - Cbc_C_Interface -ratioGap 0.5 -logLevel 1 -solve -quit (default strategy 1)
# ratioGap was changed from 0 to 0.5
# Presolve 0 (-132) rows, 0 (-60) columns and 0 (-180) elements
# Empty problem - 0 rows, 0 columns and 0 elements
# Optimal - objective value 5460.4402
# After Postsolve, objective 5460.4402, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 5460.440206 - 0 iterations time 0.002, Presolve 0.00
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# ┌ Info: JuMP.optimize! completed
# │   timed_log = Dict{Symbol,Any}(:timed_solve_time => 0.003347442,:solve_bytes_alloc => 397856,:sec_in_gc => 0.0)
# └ @ PowerSimulations /Users/cbarrows/.julia/packages/PowerSimulations/TTXVL/src/core/simulation_stages.jl:105
# ┌ Warning: SolveTime() property not supported by the Solver
# └ @ PowerSimulations /Users/cbarrows/.julia/packages/PowerSimulations/TTXVL/src/core/psi_container.jl:526
# ┌ Info: Starting run step-1-stage-ED 2020-01-01T07:00:00
# └ @ PowerSimulations /Users/cbarrows/.julia/packages/PowerSimulations/TTXVL/src/core/simulation.jl:615
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Oct  7 2019
#
# command line - Cbc_C_Interface -ratioGap 0.5 -logLevel 1 -solve -quit (default strategy 1)
# ratioGap was changed from 0 to 0.5
# Presolve 5 (-127) rows, 15 (-45) columns and 15 (-165) elements
# Perturbing problem by 0.001% of 125 - largest nonzero change 1.2504351e-05 ( 1.1710216e-05%) - largest zero change 0
# 0  Obj 6077.3788 Primal inf 8.210645 (5)
# 5  Obj 6805.2224
# Optimal - objective value 6805.2221
# After Postsolve, objective 6805.2221, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 6805.222138 - 5 iterations time 0.002, Presolve 0.00
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# ┌ Info: JuMP.optimize! completed
# │   timed_log = Dict{Symbol,Any}(:timed_solve_time => 0.003685195,:solve_bytes_alloc => 403232,:sec_in_gc => 0.0)
# └ @ PowerSimulations /Users/cbarrows/.julia/packages/PowerSimulations/TTXVL/src/core/simulation_stages.jl:105
# ┌ Warning: SolveTime() property not supported by the Solver
# └ @ PowerSimulations /Users/cbarrows/.julia/packages/PowerSimulations/TTXVL/src/core/psi_container.jl:526
# ┌ Info: Starting run step-1-stage-ED 2020-01-01T08:00:00
# └ @ PowerSimulations /Users/cbarrows/.julia/packages/PowerSimulations/TTXVL/src/core/simulation.jl:615
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Oct  7 2019
#
# command line - Cbc_C_Interface -ratioGap 0.5 -logLevel 1 -solve -quit (default strategy 1)
# ratioGap was changed from 0 to 0.5
# Presolve 12 (-120) rows, 36 (-24) columns and 36 (-144) elements
# Perturbing problem by 0.001% of 125 - largest nonzero change 1.3300338e-05 ( 1.1710216e-05%) - largest zero change 0
# 0  Obj 6977.0039 Primal inf 13.286373 (12)
# 12  Obj 8274.2029
# Optimal - objective value 8274.2021
# After Postsolve, objective 8274.2021, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 8274.202063 - 12 iterations time 0.002, Presolve 0.00
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# ┌ Info: JuMP.optimize! completed
# │   timed_log = Dict{Symbol,Any}(:timed_solve_time => 0.003584448,:solve_bytes_alloc => 397856,:sec_in_gc => 0.0)
# └ @ PowerSimulations /Users/cbarrows/.julia/packages/PowerSimulations/TTXVL/src/core/simulation_stages.jl:105
# ┌ Warning: SolveTime() property not supported by the Solver
# └ @ PowerSimulations /Users/cbarrows/.julia/packages/PowerSimulations/TTXVL/src/core/psi_container.jl:526
# ┌ Info: Starting run step-1-stage-ED 2020-01-01T09:00:00
# └ @ PowerSimulations /Users/cbarrows/.julia/packages/PowerSimulations/TTXVL/src/core/simulation.jl:615
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Oct  7 2019
#
# command line - Cbc_C_Interface -ratioGap 0.5 -logLevel 1 -solve -quit (default strategy 1)
# ratioGap was changed from 0 to 0.5
# Presolve 12 (-120) rows, 48 (-12) columns and 48 (-132) elements
# Perturbing problem by 0.001% of 250 - largest nonzero change 2.7237818e-05 ( 1.3777078e-05%) - largest zero change 0
# 0  Obj 11620.001 Primal inf 22.108325 (12)
# 12  Obj 13462.363
# Optimal - objective value 13462.361
# After Postsolve, objective 13462.361, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 13462.36139 - 12 iterations time 0.002, Presolve 0.00
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# ┌ Info: JuMP.optimize! completed
# │   timed_log = Dict{Symbol,Any}(:timed_solve_time => 0.003989141,:solve_bytes_alloc => 400544,:sec_in_gc => 0.0)
# └ @ PowerSimulations /Users/cbarrows/.julia/packages/PowerSimulations/TTXVL/src/core/simulation_stages.jl:105
# ┌ Warning: SolveTime() property not supported by the Solver
# └ @ PowerSimulations /Users/cbarrows/.julia/packages/PowerSimulations/TTXVL/src/core/psi_container.jl:526
# ┌ Info: Starting run step-1-stage-ED 2020-01-01T10:00:00
# └ @ PowerSimulations /Users/cbarrows/.julia/packages/PowerSimulations/TTXVL/src/core/simulation.jl:615
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Oct  7 2019
#
# command line - Cbc_C_Interface -ratioGap 0.5 -logLevel 1 -solve -quit (default strategy 1)
# ratioGap was changed from 0 to 0.5
# Presolve 12 (-120) rows, 48 (-12) columns and 48 (-132) elements
# Perturbing problem by 0.001% of 250 - largest nonzero change 2.7237818e-05 ( 1.3777078e-05%) - largest zero change 0
# 0  Obj 11620.001 Primal inf 24.573564 (12)
# 12  Obj 13667.799
# Optimal - objective value 13667.798
# After Postsolve, objective 13667.798, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 13667.79797 - 12 iterations time 0.002, Presolve 0.00
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# ┌ Info: JuMP.optimize! completed
# │   timed_log = Dict{Symbol,Any}(:timed_solve_time => 0.079968062,:solve_bytes_alloc => 397856,:sec_in_gc => 0.07271872)
# └ @ PowerSimulations /Users/cbarrows/.julia/packages/PowerSimulations/TTXVL/src/core/simulation_stages.jl:105
# ┌ Warning: SolveTime() property not supported by the Solver
# └ @ PowerSimulations /Users/cbarrows/.julia/packages/PowerSimulations/TTXVL/src/core/psi_container.jl:526
# ┌ Info: Starting run step-1-stage-ED 2020-01-01T11:00:00
# └ @ PowerSimulations /Users/cbarrows/.julia/packages/PowerSimulations/TTXVL/src/core/simulation.jl:615
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Oct  7 2019
#
# command line - Cbc_C_Interface -ratioGap 0.5 -logLevel 1 -solve -quit (default strategy 1)
# ratioGap was changed from 0 to 0.5
# Presolve 12 (-120) rows, 48 (-12) columns and 48 (-132) elements
# Perturbing problem by 0.001% of 250 - largest nonzero change 2.7237818e-05 ( 1.3777078e-05%) - largest zero change 0
# 0  Obj 11620.001 Primal inf 26.051688 (12)
# 12  Obj 13790.976
# Optimal - objective value 13790.975
# After Postsolve, objective 13790.975, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 13790.975 - 12 iterations time 0.002, Presolve 0.00
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# ┌ Info: JuMP.optimize! completed
# │   timed_log = Dict{Symbol,Any}(:timed_solve_time => 0.004218875,:solve_bytes_alloc => 397856,:sec_in_gc => 0.0)
# └ @ PowerSimulations /Users/cbarrows/.julia/packages/PowerSimulations/TTXVL/src/core/simulation_stages.jl:105
# ┌ Warning: SolveTime() property not supported by the Solver
# └ @ PowerSimulations /Users/cbarrows/.julia/packages/PowerSimulations/TTXVL/src/core/psi_container.jl:526
# ┌ Info: Starting run step-1-stage-ED 2020-01-01T12:00:00
# └ @ PowerSimulations /Users/cbarrows/.julia/packages/PowerSimulations/TTXVL/src/core/simulation.jl:615
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Oct  7 2019
#
# command line - Cbc_C_Interface -ratioGap 0.5 -logLevel 1 -solve -quit (default strategy 1)
# ratioGap was changed from 0 to 0.5
# Presolve 12 (-120) rows, 48 (-12) columns and 48 (-132) elements
# Perturbing problem by 0.001% of 250 - largest nonzero change 2.7237818e-05 ( 1.3777078e-05%) - largest zero change 0
# 0  Obj 11620.001 Primal inf 27.316786 (12)
# 12  Obj 13896.401
# Optimal - objective value 13896.4
# After Postsolve, objective 13896.4, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 13896.39983 - 12 iterations time 0.002, Presolve 0.00
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# ┌ Info: JuMP.optimize! completed
# │   timed_log = Dict{Symbol,Any}(:timed_solve_time => 0.003862085,:solve_bytes_alloc => 397856,:sec_in_gc => 0.0)
# └ @ PowerSimulations /Users/cbarrows/.julia/packages/PowerSimulations/TTXVL/src/core/simulation_stages.jl:105
# ┌ Warning: SolveTime() property not supported by the Solver
# └ @ PowerSimulations /Users/cbarrows/.julia/packages/PowerSimulations/TTXVL/src/core/psi_container.jl:526
# ┌ Info: Starting run step-1-stage-ED 2020-01-01T13:00:00
# └ @ PowerSimulations /Users/cbarrows/.julia/packages/PowerSimulations/TTXVL/src/core/simulation.jl:615
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Oct  7 2019
#
# command line - Cbc_C_Interface -ratioGap 0.5 -logLevel 1 -solve -quit (default strategy 1)
# ratioGap was changed from 0 to 0.5
# Presolve 12 (-120) rows, 48 (-12) columns and 48 (-132) elements
# Perturbing problem by 0.001% of 250 - largest nonzero change 2.7237818e-05 ( 1.3777078e-05%) - largest zero change 0
# 0  Obj 11620.001 Primal inf 24.826546 (12)
# 12  Obj 13688.881
# Optimal - objective value 13688.88
# After Postsolve, objective 13688.88, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 13688.87984 - 12 iterations time 0.002, Presolve 0.00
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# ┌ Info: JuMP.optimize! completed
# │   timed_log = Dict{Symbol,Any}(:timed_solve_time => 0.00349624,:solve_bytes_alloc => 397856,:sec_in_gc => 0.0)
# └ @ PowerSimulations /Users/cbarrows/.julia/packages/PowerSimulations/TTXVL/src/core/simulation_stages.jl:105
# ┌ Warning: SolveTime() property not supported by the Solver
# └ @ PowerSimulations /Users/cbarrows/.julia/packages/PowerSimulations/TTXVL/src/core/psi_container.jl:526
# ┌ Info: Starting run step-1-stage-ED 2020-01-01T14:00:00
# └ @ PowerSimulations /Users/cbarrows/.julia/packages/PowerSimulations/TTXVL/src/core/simulation.jl:615
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Oct  7 2019
#
# command line - Cbc_C_Interface -ratioGap 0.5 -logLevel 1 -solve -quit (default strategy 1)
# ratioGap was changed from 0 to 0.5
# Presolve 12 (-120) rows, 48 (-12) columns and 48 (-132) elements
# Perturbing problem by 0.001% of 250 - largest nonzero change 2.7237818e-05 ( 1.3777078e-05%) - largest zero change 0
# 0  Obj 11620.001 Primal inf 22.383745 (12)
# 12  Obj 13485.314
# Optimal - objective value 13485.313
# After Postsolve, objective 13485.313, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 13485.31311 - 12 iterations time 0.002, Presolve 0.00
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# ┌ Info: JuMP.optimize! completed
# │   timed_log = Dict{Symbol,Any}(:timed_solve_time => 0.003564902,:solve_bytes_alloc => 397856,:sec_in_gc => 0.0)
# └ @ PowerSimulations /Users/cbarrows/.julia/packages/PowerSimulations/TTXVL/src/core/simulation_stages.jl:105
# ┌ Warning: SolveTime() property not supported by the Solver
# └ @ PowerSimulations /Users/cbarrows/.julia/packages/PowerSimulations/TTXVL/src/core/psi_container.jl:526
# ┌ Info: Starting run step-1-stage-ED 2020-01-01T15:00:00
# └ @ PowerSimulations /Users/cbarrows/.julia/packages/PowerSimulations/TTXVL/src/core/simulation.jl:615
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Oct  7 2019
#
# command line - Cbc_C_Interface -ratioGap 0.5 -logLevel 1 -solve -quit (default strategy 1)
# ratioGap was changed from 0 to 0.5
# Presolve 12 (-120) rows, 48 (-12) columns and 48 (-132) elements
# Perturbing problem by 0.001% of 250 - largest nonzero change 2.7237818e-05 ( 1.3777078e-05%) - largest zero change 0
# 0  Obj 11620.001 Primal inf 20.804354 (12)
# 12  Obj 13353.698
# Optimal - objective value 13353.697
# After Postsolve, objective 13353.697, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 13353.69716 - 12 iterations time 0.002, Presolve 0.00
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# ┌ Info: JuMP.optimize! completed
# │   timed_log = Dict{Symbol,Any}(:timed_solve_time => 0.003519913,:solve_bytes_alloc => 397856,:sec_in_gc => 0.0)
# └ @ PowerSimulations /Users/cbarrows/.julia/packages/PowerSimulations/TTXVL/src/core/simulation_stages.jl:105
# ┌ Warning: SolveTime() property not supported by the Solver
# └ @ PowerSimulations /Users/cbarrows/.julia/packages/PowerSimulations/TTXVL/src/core/psi_container.jl:526
# ┌ Info: Starting run step-1-stage-ED 2020-01-01T16:00:00
# └ @ PowerSimulations /Users/cbarrows/.julia/packages/PowerSimulations/TTXVL/src/core/simulation.jl:615
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Oct  7 2019
#
# command line - Cbc_C_Interface -ratioGap 0.5 -logLevel 1 -solve -quit (default strategy 1)
# ratioGap was changed from 0 to 0.5
# Presolve 12 (-120) rows, 48 (-12) columns and 48 (-132) elements
# Perturbing problem by 0.001% of 250 - largest nonzero change 2.7237818e-05 ( 1.3777078e-05%) - largest zero change 0
# 0  Obj 11620.001 Primal inf 20.430398 (12)
# 12  Obj 13322.535
# Optimal - objective value 13322.534
# After Postsolve, objective 13322.534, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 13322.53415 - 12 iterations time 0.002, Presolve 0.00
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# ┌ Info: JuMP.optimize! completed
# │   timed_log = Dict{Symbol,Any}(:timed_solve_time => 0.003605155,:solve_bytes_alloc => 397856,:sec_in_gc => 0.0)
# └ @ PowerSimulations /Users/cbarrows/.julia/packages/PowerSimulations/TTXVL/src/core/simulation_stages.jl:105
# ┌ Warning: SolveTime() property not supported by the Solver
# └ @ PowerSimulations /Users/cbarrows/.julia/packages/PowerSimulations/TTXVL/src/core/psi_container.jl:526
# ┌ Info: Starting run step-1-stage-ED 2020-01-01T17:00:00
# └ @ PowerSimulations /Users/cbarrows/.julia/packages/PowerSimulations/TTXVL/src/core/simulation.jl:615
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Oct  7 2019
#
# command line - Cbc_C_Interface -ratioGap 0.5 -logLevel 1 -solve -quit (default strategy 1)
# ratioGap was changed from 0 to 0.5
# Presolve 12 (-120) rows, 48 (-12) columns and 48 (-132) elements
# Perturbing problem by 0.001% of 250 - largest nonzero change 2.7237818e-05 ( 1.3777078e-05%) - largest zero change 0
# 0  Obj 11620.001 Primal inf 23.579452 (12)
# 12  Obj 13584.957
# Optimal - objective value 13584.955
# After Postsolve, objective 13584.955, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 13584.95531 - 12 iterations time 0.002, Presolve 0.00
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# ┌ Info: JuMP.optimize! completed
# │   timed_log = Dict{Symbol,Any}(:timed_solve_time => 0.003640666,:solve_bytes_alloc => 397856,:sec_in_gc => 0.0)
# └ @ PowerSimulations /Users/cbarrows/.julia/packages/PowerSimulations/TTXVL/src/core/simulation_stages.jl:105
# ┌ Warning: SolveTime() property not supported by the Solver
# └ @ PowerSimulations /Users/cbarrows/.julia/packages/PowerSimulations/TTXVL/src/core/psi_container.jl:526
# ┌ Info: Starting run step-1-stage-ED 2020-01-01T18:00:00
# └ @ PowerSimulations /Users/cbarrows/.julia/packages/PowerSimulations/TTXVL/src/core/simulation.jl:615
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Oct  7 2019
#
# command line - Cbc_C_Interface -ratioGap 0.5 -logLevel 1 -solve -quit (default strategy 1)
# ratioGap was changed from 0 to 0.5
# Presolve 12 (-120) rows, 48 (-12) columns and 48 (-132) elements
# Perturbing problem by 0.001% of 250 - largest nonzero change 2.7237818e-05 ( 1.3777078e-05%) - largest zero change 0
# 0  Obj 11620.001 Primal inf 30.746813 (12)
# 12  Obj 14182.237
# Optimal - objective value 14182.235
# After Postsolve, objective 14182.235, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 14182.23539 - 12 iterations time 0.002, Presolve 0.00
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# ┌ Info: JuMP.optimize! completed
# │   timed_log = Dict{Symbol,Any}(:timed_solve_time => 0.003708444,:solve_bytes_alloc => 397856,:sec_in_gc => 0.0)
# └ @ PowerSimulations /Users/cbarrows/.julia/packages/PowerSimulations/TTXVL/src/core/simulation_stages.jl:105
# ┌ Warning: SolveTime() property not supported by the Solver
# └ @ PowerSimulations /Users/cbarrows/.julia/packages/PowerSimulations/TTXVL/src/core/psi_container.jl:526
# ┌ Info: Starting run step-1-stage-ED 2020-01-01T19:00:00
# └ @ PowerSimulations /Users/cbarrows/.julia/packages/PowerSimulations/TTXVL/src/core/simulation.jl:615
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Oct  7 2019
#
# command line - Cbc_C_Interface -ratioGap 0.5 -logLevel 1 -solve -quit (default strategy 1)
# ratioGap was changed from 0 to 0.5
# Presolve 12 (-120) rows, 48 (-12) columns and 48 (-132) elements
# Perturbing problem by 0.001% of 250 - largest nonzero change 2.7237818e-05 ( 1.3777078e-05%) - largest zero change 0
# 0  Obj 11620.001 Primal inf 29.997821 (12)
# 12  Obj 14119.821
# Optimal - objective value 14119.819
# After Postsolve, objective 14119.819, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 14119.81943 - 12 iterations time 0.002, Presolve 0.00
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# ┌ Info: JuMP.optimize! completed
# │   timed_log = Dict{Symbol,Any}(:timed_solve_time => 0.003385461,:solve_bytes_alloc => 397856,:sec_in_gc => 0.0)
# └ @ PowerSimulations /Users/cbarrows/.julia/packages/PowerSimulations/TTXVL/src/core/simulation_stages.jl:105
# ┌ Warning: SolveTime() property not supported by the Solver
# └ @ PowerSimulations /Users/cbarrows/.julia/packages/PowerSimulations/TTXVL/src/core/psi_container.jl:526
# ┌ Info: Starting run step-1-stage-ED 2020-01-01T20:00:00
# └ @ PowerSimulations /Users/cbarrows/.julia/packages/PowerSimulations/TTXVL/src/core/simulation.jl:615
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Oct  7 2019
#
# command line - Cbc_C_Interface -ratioGap 0.5 -logLevel 1 -solve -quit (default strategy 1)
# ratioGap was changed from 0 to 0.5
# Presolve 12 (-120) rows, 48 (-12) columns and 48 (-132) elements
# Perturbing problem by 0.001% of 250 - largest nonzero change 2.7237818e-05 ( 1.3777078e-05%) - largest zero change 0
# 0  Obj 11620.001 Primal inf 23.17816 (12)
# 12  Obj 13551.516
# Optimal - objective value 13551.514
# After Postsolve, objective 13551.514, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 13551.51433 - 12 iterations time 0.002, Presolve 0.00
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# ┌ Info: JuMP.optimize! completed
# │   timed_log = Dict{Symbol,Any}(:timed_solve_time => 0.003470886,:solve_bytes_alloc => 397856,:sec_in_gc => 0.0)
# └ @ PowerSimulations /Users/cbarrows/.julia/packages/PowerSimulations/TTXVL/src/core/simulation_stages.jl:105
# ┌ Warning: SolveTime() property not supported by the Solver
# └ @ PowerSimulations /Users/cbarrows/.julia/packages/PowerSimulations/TTXVL/src/core/psi_container.jl:526
# ┌ Info: Starting run step-1-stage-ED 2020-01-01T21:00:00
# └ @ PowerSimulations /Users/cbarrows/.julia/packages/PowerSimulations/TTXVL/src/core/simulation.jl:615
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Oct  7 2019
#
# command line - Cbc_C_Interface -ratioGap 0.5 -logLevel 1 -solve -quit (default strategy 1)
# ratioGap was changed from 0 to 0.5
# Presolve 12 (-120) rows, 36 (-24) columns and 36 (-144) elements
# Perturbing problem by 0.001% of 125 - largest nonzero change 1.3300338e-05 ( 1.1710216e-05%) - largest zero change 0
# 0  Obj 6816.2876 Primal inf 14.057812 (12)
# 12  Obj 8177.7731
# Optimal - objective value 8177.7723
# After Postsolve, objective 8177.7723, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 8177.772304 - 12 iterations time 0.002, Presolve 0.00
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# ┌ Info: JuMP.optimize! completed
# │   timed_log = Dict{Symbol,Any}(:timed_solve_time => 0.003630488,:solve_bytes_alloc => 400544,:sec_in_gc => 0.0)
# └ @ PowerSimulations /Users/cbarrows/.julia/packages/PowerSimulations/TTXVL/src/core/simulation_stages.jl:105
# ┌ Warning: SolveTime() property not supported by the Solver
# └ @ PowerSimulations /Users/cbarrows/.julia/packages/PowerSimulations/TTXVL/src/core/psi_container.jl:526
# ┌ Info: Starting run step-1-stage-ED 2020-01-01T22:00:00
# └ @ PowerSimulations /Users/cbarrows/.julia/packages/PowerSimulations/TTXVL/src/core/simulation.jl:615
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Oct  7 2019
#
# command line - Cbc_C_Interface -ratioGap 0.5 -logLevel 1 -solve -quit (default strategy 1)
# ratioGap was changed from 0 to 0.5
# Presolve 11 (-121) rows, 33 (-27) columns and 33 (-147) elements
# Perturbing problem by 0.001% of 125 - largest nonzero change 1.3300338e-05 ( 1.1710216e-05%) - largest zero change 0
# 0  Obj 5577.4219 Primal inf 18.001456 (11)
# 11  Obj 7176.5468
# Optimal - objective value 7176.5462
# After Postsolve, objective 7176.5462, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 7176.546156 - 11 iterations time 0.002, Presolve 0.00
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# ┌ Info: JuMP.optimize! completed
# │   timed_log = Dict{Symbol,Any}(:timed_solve_time => 0.003409274,:solve_bytes_alloc => 397856,:sec_in_gc => 0.0)
# └ @ PowerSimulations /Users/cbarrows/.julia/packages/PowerSimulations/TTXVL/src/core/simulation_stages.jl:105
# ┌ Warning: SolveTime() property not supported by the Solver
# └ @ PowerSimulations /Users/cbarrows/.julia/packages/PowerSimulations/TTXVL/src/core/psi_container.jl:526
# ┌ Info: Starting run step-1-stage-ED 2020-01-01T23:00:00
# └ @ PowerSimulations /Users/cbarrows/.julia/packages/PowerSimulations/TTXVL/src/core/simulation.jl:615
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Oct  7 2019
#
# command line - Cbc_C_Interface -ratioGap 0.5 -logLevel 1 -solve -quit (default strategy 1)
# ratioGap was changed from 0 to 0.5
# Presolve 0 (-132) rows, 0 (-60) columns and 0 (-180) elements
# Empty problem - 0 rows, 0 columns and 0 elements
# Optimal - objective value 6525.094
# After Postsolve, objective 6525.094, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 6525.094023 - 0 iterations time 0.002, Presolve 0.00
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# ┌ Info: JuMP.optimize! completed
# │   timed_log = Dict{Symbol,Any}(:timed_solve_time => 0.003507714,:solve_bytes_alloc => 397856,:sec_in_gc => 0.0)
# └ @ PowerSimulations /Users/cbarrows/.julia/packages/PowerSimulations/TTXVL/src/core/simulation_stages.jl:105
# ┌ Warning: SolveTime() property not supported by the Solver
# └ @ PowerSimulations /Users/cbarrows/.julia/packages/PowerSimulations/TTXVL/src/core/psi_container.jl:526
# ┌ Info:
# │  ──────────────────────────────────────────────────────────────────────────────
# │                                        Time                   Allocations
# │                                ──────────────────────   ───────────────────────
# │        Tot / % measured:            465ms / 100%            33.7MiB / 100%
# │
# │  Section               ncalls     time   %tot     avg     alloc   %tot      avg
# │  ──────────────────────────────────────────────────────────────────────────────
# │  Execute Simulation         1    465ms   100%   465ms   33.7MiB  100%   33.7MiB
# │    Execution Step 1         1    418ms  89.9%   418ms   19.1MiB  56.8%  19.1MiB
# │      Execution Stage 2     24    352ms  75.7%  14.7ms   14.2MiB  42.3%   608KiB
# │        Run Stage 2         24    285ms  61.3%  11.9ms   12.8MiB  38.2%   548KiB
# │        Update Stage 2      24   62.0ms  13.3%  2.58ms   1.24MiB  3.68%  52.8KiB
# │      Execution Stage 1      1   65.6ms  14.1%  65.6ms   4.84MiB  14.4%  4.84MiB
# │        Run Stage 1          1   65.3ms  14.1%  65.3ms   4.83MiB  14.4%  4.83MiB
# │        Update Stage 1       1    195ns  0.00%   195ns     0.00B  0.00%    0.00B
# │  ──────────────────────────────────────────────────────────────────────────────
# └ @ PowerSimulations /Users/cbarrows/.julia/packages/PowerSimulations/TTXVL/src/core/simulation.jl:645
# Simulation Results Reference
#
# Results Folder: /var/folders/27/2jr8c7gn4j72fvrg4qt81zrw8w_711/T/5bus-test/2020-03-05T08-16-00/results
#
# Reference Tables
#
# stage-UC
#
# Stop_ThermalStandard: dataframe size (1, 3)
#
# REG3_VariableReserve{ReserveUp}: dataframe size (1, 3)
#
# P_ThermalStandard: dataframe size (1, 3)
#
# REG1_VariableReserve{ReserveUp}: dataframe size (1, 3)
#
# On_ThermalStandard: dataframe size (1, 3)
#
# Start_ThermalStandard: dataframe size (1, 3)
#
# REG2_VariableReserve{ReserveUp}: dataframe size (1, 3)
#
# REG4_VariableReserve{ReserveUp}: dataframe size (1, 3)
#
# stage-ED
#
# P_ThermalStandard: dataframe size (24, 3)
#
# stage-UC
#
# time length: 24
#
# stage-ED
#
# time length: 12

# %% [markdown]
# ## Results

# %%
uc_results = load_simulation_results(sim_results, "UC");
ed_results = load_simulation_results(sim_results, "ED");

# %% [markdown]
# ---
#
# *This notebook was generated using [Literate.jl](https://github.com/fredrikekre/Literate.jl).*
